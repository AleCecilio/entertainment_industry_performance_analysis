# %% [markdown]
# #  Análise Exploratória de Dados - Análise Bivariada: The Movies Dataset

# %%
# Configuração do Jupyter (Autoreload)
# %load_ext autoreload
# %autoreload 2

# Configuração de Caminho (Path Setup)
import sys
import os

# Adiciona a pasta raiz do projeto (..) ao sistema para liberar os imports locais
sys.path.append(os.path.abspath(os.path.join('..')))

# Importação de Bibliotecas e Módulos
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Módulos customizados da pasta src/
import src.io.data_loader as dl
import src.utils.data_quality as dq
import src.utils.metrics as mt
import src.view.plots as graf
import src.view.tables as tb
import src.utils.reshaping as rsh

# %% [markdown]
# ---
#
# ## Carregando Dados

# %%
caminho = '../data/interim/movies/movies_enriched.parquet'
df_movies = dl.load_data(file_path=caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (41091, 22)

# %% [markdown]
# ---
# ## Numérica VS Numérica

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='pearson')['total_votes']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='spearman')['total_votes']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_8b475 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_8b475 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_8b475 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_8b475 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_8b475 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_8b475 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_8b475_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_8b475_row1_col0 {
#   background-color: #00493e;
#   color: #f1f1f1;
# }
# #T_8b475_row2_col0 {
#   background-color: #046961;
#   color: #f1f1f1;
# }
# #T_8b475_row3_col0 {
#   background-color: #2f9189;
#   color: #f1f1f1;
# }
# #T_8b475_row4_col0 {
#   background-color: #44a299;
#   color: #f1f1f1;
# }
# #T_8b475_row5_col0, #T_8b475_row6_col0 {
#   background-color: #d9eeeb;
#   color: #000000;
# }
# #T_8b475_row7_col0, #T_8b475_row8_col0 {
#   background-color: #dbefec;
#   color: #000000;
# }
# #T_8b475_row9_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_8b475_row10_col0 {
#   background-color: #f5f2e8;
#   color: #000000;
# }
# #T_8b475_row11_col0 {
#   background-color: #f6eed9;
#   color: #000000;
# }
# </style>
# <table id="T_8b475">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b475_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b475_level0_row0" class="row_heading level0 row0" >total_votes</th>
#       <td id="T_8b475_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row1" class="row_heading level0 row1" >votes_per_year</th>
#       <td id="T_8b475_row1_col0" class="data row1 col0" >0.934958</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row2" class="row_heading level0 row2" >revenue</th>
#       <td id="T_8b475_row2_col0" class="data row2 col0" >0.781428</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row3" class="row_heading level0 row3" >budget</th>
#       <td id="T_8b475_row3_col0" class="data row3 col0" >0.618293</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row4" class="row_heading level0 row4" >popularity</th>
#       <td id="T_8b475_row4_col0" class="data row4 col0" >0.557913</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row5" class="row_heading level0 row5" >average_rating</th>
#       <td id="T_8b475_row5_col0" class="data row5 col0" >0.124841</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row6" class="row_heading level0 row6" >global_score</th>
#       <td id="T_8b475_row6_col0" class="data row6 col0" >0.124841</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row7" class="row_heading level0 row7" >decade</th>
#       <td id="T_8b475_row7_col0" class="data row7 col0" >0.111625</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row8" class="row_heading level0 row8" >release_year</th>
#       <td id="T_8b475_row8_col0" class="data row8 col0" >0.111589</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row9" class="row_heading level0 row9" >runtime</th>
#       <td id="T_8b475_row9_col0" class="data row9 col0" >0.107405</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row10" class="row_heading level0 row10" >id</th>
#       <td id="T_8b475_row10_col0" class="data row10 col0" >-0.052231</td>
#     </tr>
#     <tr>
#       <th id="T_8b475_level0_row11" class="row_heading level0 row11" >age_years</th>
#       <td id="T_8b475_row11_col0" class="data row11 col0" >-0.111589</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7eafd th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_7eafd td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_7eafd caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_7eafd table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_7eafd th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_7eafd td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_7eafd_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_7eafd_row1_col0 {
#   background-color: #00493e;
#   color: #f1f1f1;
# }
# #T_7eafd_row2_col0 {
#   background-color: #015349;
#   color: #f1f1f1;
# }
# #T_7eafd_row3_col0 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_7eafd_row4_col0 {
#   background-color: #258880;
#   color: #f1f1f1;
# }
# #T_7eafd_row5_col0 {
#   background-color: #b9e4de;
#   color: #000000;
# }
# #T_7eafd_row6_col0, #T_7eafd_row7_col0 {
#   background-color: #c4e9e4;
#   color: #000000;
# }
# #T_7eafd_row8_col0, #T_7eafd_row9_col0 {
#   background-color: #ccebe7;
#   color: #000000;
# }
# #T_7eafd_row10_col0 {
#   background-color: #f5e7c0;
#   color: #000000;
# }
# #T_7eafd_row11_col0 {
#   background-color: #dfc37e;
#   color: #000000;
# }
# </style>
# <table id="T_7eafd">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eafd_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eafd_level0_row0" class="row_heading level0 row0" >total_votes</th>
#       <td id="T_7eafd_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row1" class="row_heading level0 row1" >votes_per_year</th>
#       <td id="T_7eafd_row1_col0" class="data row1 col0" >0.929844</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row2" class="row_heading level0 row2" >popularity</th>
#       <td id="T_7eafd_row2_col0" class="data row2 col0" >0.885722</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row3" class="row_heading level0 row3" >revenue</th>
#       <td id="T_7eafd_row3_col0" class="data row3 col0" >0.726973</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row4" class="row_heading level0 row4" >budget</th>
#       <td id="T_7eafd_row4_col0" class="data row4 col0" >0.657671</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <td id="T_7eafd_row5_col0" class="data row5 col0" >0.240864</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row6" class="row_heading level0 row6" >release_year</th>
#       <td id="T_7eafd_row6_col0" class="data row6 col0" >0.209672</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row7" class="row_heading level0 row7" >decade</th>
#       <td id="T_7eafd_row7_col0" class="data row7 col0" >0.209585</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row8" class="row_heading level0 row8" >global_score</th>
#       <td id="T_7eafd_row8_col0" class="data row8 col0" >0.173598</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row9" class="row_heading level0 row9" >average_rating</th>
#       <td id="T_7eafd_row9_col0" class="data row9 col0" >0.173598</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row10" class="row_heading level0 row10" >age_years</th>
#       <td id="T_7eafd_row10_col0" class="data row10 col0" >-0.209672</td>
#     </tr>
#     <tr>
#       <th id="T_7eafd_level0_row11" class="row_heading level0 row11" >id</th>
#       <td id="T_7eafd_row11_col0" class="data row11 col0" >-0.395972</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Passa a lista direto no eixo X
colunas_numericas = df_movies.select_dtypes(include='number').columns

graf.grafico_corr_scatter(
    df_plot=df_movies,
    coluna_x=colunas_numericas.drop(['total_votes', 'id']), 
    coluna_y='total_votes',
    titulo='Painel de Variáveis e sua correlação com o Número de Votos',
    quant_grafs=len(colunas_numericas.drop(['total_votes', 'id']))
)

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='pearson')['average_rating']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='spearman')['average_rating']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_4061a th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_4061a td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_4061a caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_4061a table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_4061a th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_4061a td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_4061a_row0_col0, #T_4061a_row1_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_4061a_row2_col0 {
#   background-color: #d2ede9;
#   color: #000000;
# }
# #T_4061a_row3_col0 {
#   background-color: #d9eeeb;
#   color: #000000;
# }
# #T_4061a_row4_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_4061a_row5_col0, #T_4061a_row6_col0 {
#   background-color: #def0ed;
#   color: #000000;
# }
# #T_4061a_row7_col0 {
#   background-color: #e4f1ef;
#   color: #000000;
# }
# #T_4061a_row8_col0 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_4061a_row9_col0 {
#   background-color: #f5f5f4;
#   color: #000000;
# }
# #T_4061a_row10_col0, #T_4061a_row11_col0 {
#   background-color: #f5f3ee;
#   color: #000000;
# }
# </style>
# <table id="T_4061a">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4061a_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4061a_level0_row0" class="row_heading level0 row0" >global_score</th>
#       <td id="T_4061a_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row1" class="row_heading level0 row1" >average_rating</th>
#       <td id="T_4061a_row1_col0" class="data row1 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row2" class="row_heading level0 row2" >revenue</th>
#       <td id="T_4061a_row2_col0" class="data row2 col0" >0.149229</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row3" class="row_heading level0 row3" >total_votes</th>
#       <td id="T_4061a_row3_col0" class="data row3 col0" >0.124841</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row4" class="row_heading level0 row4" >runtime</th>
#       <td id="T_4061a_row4_col0" class="data row4 col0" >0.102999</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row5" class="row_heading level0 row5" >popularity</th>
#       <td id="T_4061a_row5_col0" class="data row5 col0" >0.098950</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row6" class="row_heading level0 row6" >votes_per_year</th>
#       <td id="T_4061a_row6_col0" class="data row6 col0" >0.096860</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row7" class="row_heading level0 row7" >budget</th>
#       <td id="T_4061a_row7_col0" class="data row7 col0" >0.074281</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row8" class="row_heading level0 row8" >age_years</th>
#       <td id="T_4061a_row8_col0" class="data row8 col0" >0.028220</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row9" class="row_heading level0 row9" >id</th>
#       <td id="T_4061a_row9_col0" class="data row9 col0" >-0.004505</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row10" class="row_heading level0 row10" >release_year</th>
#       <td id="T_4061a_row10_col0" class="data row10 col0" >-0.028220</td>
#     </tr>
#     <tr>
#       <th id="T_4061a_level0_row11" class="row_heading level0 row11" >decade</th>
#       <td id="T_4061a_row11_col0" class="data row11 col0" >-0.028954</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6612f th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_6612f td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_6612f caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_6612f table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_6612f th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_6612f td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_6612f_row0_col0, #T_6612f_row1_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_6612f_row2_col0 {
#   background-color: #ccebe7;
#   color: #000000;
# }
# #T_6612f_row3_col0 {
#   background-color: #d2ede9;
#   color: #000000;
# }
# #T_6612f_row4_col0 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_6612f_row5_col0, #T_6612f_row6_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_6612f_row7_col0 {
#   background-color: #edf3f2;
#   color: #000000;
# }
# #T_6612f_row8_col0 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_6612f_row9_col0 {
#   background-color: #f5f3ec;
#   color: #000000;
# }
# #T_6612f_row10_col0 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_6612f_row11_col0 {
#   background-color: #f5f1e4;
#   color: #000000;
# }
# </style>
# <table id="T_6612f">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6612f_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6612f_level0_row0" class="row_heading level0 row0" >global_score</th>
#       <td id="T_6612f_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row1" class="row_heading level0 row1" >average_rating</th>
#       <td id="T_6612f_row1_col0" class="data row1 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row2" class="row_heading level0 row2" >total_votes</th>
#       <td id="T_6612f_row2_col0" class="data row2 col0" >0.173598</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row3" class="row_heading level0 row3" >runtime</th>
#       <td id="T_6612f_row3_col0" class="data row3 col0" >0.156225</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row4" class="row_heading level0 row4" >votes_per_year</th>
#       <td id="T_6612f_row4_col0" class="data row4 col0" >0.139815</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row5" class="row_heading level0 row5" >popularity</th>
#       <td id="T_6612f_row5_col0" class="data row5 col0" >0.109147</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row6" class="row_heading level0 row6" >revenue</th>
#       <td id="T_6612f_row6_col0" class="data row6 col0" >0.108567</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row7" class="row_heading level0 row7" >age_years</th>
#       <td id="T_6612f_row7_col0" class="data row7 col0" >0.034601</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row8" class="row_heading level0 row8" >budget</th>
#       <td id="T_6612f_row8_col0" class="data row8 col0" >0.030421</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row9" class="row_heading level0 row9" >release_year</th>
#       <td id="T_6612f_row9_col0" class="data row9 col0" >-0.034601</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row10" class="row_heading level0 row10" >decade</th>
#       <td id="T_6612f_row10_col0" class="data row10 col0" >-0.040878</td>
#     </tr>
#     <tr>
#       <th id="T_6612f_level0_row11" class="row_heading level0 row11" >id</th>
#       <td id="T_6612f_row11_col0" class="data row11 col0" >-0.068177</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_corr_scatter(
    df_plot=df_movies,
    coluna_x=colunas_numericas.drop(['average_rating', 'id']), 
    coluna_y='average_rating',
    titulo='Painel de Variáveis e sua correlação com a Nota Média',
    quant_grafs=len(colunas_numericas.drop(['average_rating', 'id']))
)

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='pearson')['popularity']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='spearman')['popularity']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_ea268 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_ea268 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_ea268 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_ea268 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_ea268 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_ea268 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_ea268_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_ea268_row1_col0 {
#   background-color: #419f97;
#   color: #f1f1f1;
# }
# #T_ea268_row2_col0 {
#   background-color: #44a299;
#   color: #f1f1f1;
# }
# #T_ea268_row3_col0 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_ea268_row4_col0 {
#   background-color: #8dd2c7;
#   color: #000000;
# }
# #T_ea268_row5_col0, #T_ea268_row6_col0 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_ea268_row7_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_ea268_row8_col0, #T_ea268_row9_col0 {
#   background-color: #def0ed;
#   color: #000000;
# }
# #T_ea268_row10_col0 {
#   background-color: #f5f1e6;
#   color: #000000;
# }
# #T_ea268_row11_col0 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# </style>
# <table id="T_ea268">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea268_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea268_level0_row0" class="row_heading level0 row0" >popularity</th>
#       <td id="T_ea268_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row1" class="row_heading level0 row1" >votes_per_year</th>
#       <td id="T_ea268_row1_col0" class="data row1 col0" >0.563442</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row2" class="row_heading level0 row2" >total_votes</th>
#       <td id="T_ea268_row2_col0" class="data row2 col0" >0.557913</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row3" class="row_heading level0 row3" >revenue</th>
#       <td id="T_ea268_row3_col0" class="data row3 col0" >0.456920</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row4" class="row_heading level0 row4" >budget</th>
#       <td id="T_ea268_row4_col0" class="data row4 col0" >0.364791</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row5" class="row_heading level0 row5" >release_year</th>
#       <td id="T_ea268_row5_col0" class="data row5 col0" >0.136178</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row6" class="row_heading level0 row6" >decade</th>
#       <td id="T_ea268_row6_col0" class="data row6 col0" >0.133065</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row7" class="row_heading level0 row7" >runtime</th>
#       <td id="T_ea268_row7_col0" class="data row7 col0" >0.105987</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row8" class="row_heading level0 row8" >average_rating</th>
#       <td id="T_ea268_row8_col0" class="data row8 col0" >0.098950</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row9" class="row_heading level0 row9" >global_score</th>
#       <td id="T_ea268_row9_col0" class="data row9 col0" >0.098950</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row10" class="row_heading level0 row10" >id</th>
#       <td id="T_ea268_row10_col0" class="data row10 col0" >-0.055626</td>
#     </tr>
#     <tr>
#       <th id="T_ea268_level0_row11" class="row_heading level0 row11" >age_years</th>
#       <td id="T_ea268_row11_col0" class="data row11 col0" >-0.136178</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_e54a2 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_e54a2 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_e54a2 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_e54a2 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_e54a2 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_e54a2 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_e54a2_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_e54a2_row1_col0 {
#   background-color: #015349;
#   color: #f1f1f1;
# }
# #T_e54a2_row2_col0 {
#   background-color: #015f56;
#   color: #f1f1f1;
# }
# #T_e54a2_row3_col0 {
#   background-color: #33958d;
#   color: #f1f1f1;
# }
# #T_e54a2_row4_col0 {
#   background-color: #35978f;
#   color: #f1f1f1;
# }
# #T_e54a2_row5_col0 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_e54a2_row6_col0, #T_e54a2_row7_col0 {
#   background-color: #c9eae6;
#   color: #000000;
# }
# #T_e54a2_row8_col0, #T_e54a2_row9_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_e54a2_row10_col0 {
#   background-color: #f6e9c5;
#   color: #000000;
# }
# #T_e54a2_row11_col0 {
#   background-color: #e1c684;
#   color: #000000;
# }
# </style>
# <table id="T_e54a2">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e54a2_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e54a2_level0_row0" class="row_heading level0 row0" >popularity</th>
#       <td id="T_e54a2_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row1" class="row_heading level0 row1" >total_votes</th>
#       <td id="T_e54a2_row1_col0" class="data row1 col0" >0.885722</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row2" class="row_heading level0 row2" >votes_per_year</th>
#       <td id="T_e54a2_row2_col0" class="data row2 col0" >0.831342</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row3" class="row_heading level0 row3" >budget</th>
#       <td id="T_e54a2_row3_col0" class="data row3 col0" >0.604398</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row4" class="row_heading level0 row4" >revenue</th>
#       <td id="T_e54a2_row4_col0" class="data row4 col0" >0.595985</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <td id="T_e54a2_row5_col0" class="data row5 col0" >0.260465</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row6" class="row_heading level0 row6" >release_year</th>
#       <td id="T_e54a2_row6_col0" class="data row6 col0" >0.194599</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row7" class="row_heading level0 row7" >decade</th>
#       <td id="T_e54a2_row7_col0" class="data row7 col0" >0.190585</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row8" class="row_heading level0 row8" >global_score</th>
#       <td id="T_e54a2_row8_col0" class="data row8 col0" >0.109147</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row9" class="row_heading level0 row9" >average_rating</th>
#       <td id="T_e54a2_row9_col0" class="data row9 col0" >0.109147</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row10" class="row_heading level0 row10" >age_years</th>
#       <td id="T_e54a2_row10_col0" class="data row10 col0" >-0.194599</td>
#     </tr>
#     <tr>
#       <th id="T_e54a2_level0_row11" class="row_heading level0 row11" >id</th>
#       <td id="T_e54a2_row11_col0" class="data row11 col0" >-0.380278</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_corr_scatter(
    df_plot=df_movies,
    coluna_x=colunas_numericas.drop(['popularity', 'id']), 
    coluna_y='popularity',
    titulo='Painel de Variáveis e sua correlação com a Popularidade',
    quant_grafs=len(colunas_numericas.drop(['popularity', 'id']))
)

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='pearson')['revenue']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_movies.select_dtypes(include='number')
        .corr(method='spearman')['revenue']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_0d12d th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_0d12d td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_0d12d caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_0d12d table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_0d12d th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_0d12d td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_0d12d_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_0d12d_row1_col0 {
#   background-color: #046961;
#   color: #f1f1f1;
# }
# #T_0d12d_row2_col0 {
#   background-color: #10746c;
#   color: #f1f1f1;
# }
# #T_0d12d_row3_col0 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_0d12d_row4_col0 {
#   background-color: #6abdb2;
#   color: #000000;
# }
# #T_0d12d_row5_col0 {
#   background-color: #c4e9e4;
#   color: #000000;
# }
# #T_0d12d_row6_col0, #T_0d12d_row7_col0 {
#   background-color: #d2ede9;
#   color: #000000;
# }
# #T_0d12d_row8_col0 {
#   background-color: #d5edea;
#   color: #000000;
# }
# #T_0d12d_row9_col0 {
#   background-color: #d7eeeb;
#   color: #000000;
# }
# #T_0d12d_row10_col0 {
#   background-color: #f5f4f0;
#   color: #000000;
# }
# #T_0d12d_row11_col0 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# </style>
# <table id="T_0d12d">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d12d_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d12d_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_0d12d_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row1" class="row_heading level0 row1" >total_votes</th>
#       <td id="T_0d12d_row1_col0" class="data row1 col0" >0.781428</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row2" class="row_heading level0 row2" >votes_per_year</th>
#       <td id="T_0d12d_row2_col0" class="data row2 col0" >0.742088</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row3" class="row_heading level0 row3" >budget</th>
#       <td id="T_0d12d_row3_col0" class="data row3 col0" >0.729991</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row4" class="row_heading level0 row4" >popularity</th>
#       <td id="T_0d12d_row4_col0" class="data row4 col0" >0.456920</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <td id="T_0d12d_row5_col0" class="data row5 col0" >0.203714</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row6" class="row_heading level0 row6" >average_rating</th>
#       <td id="T_0d12d_row6_col0" class="data row6 col0" >0.149229</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row7" class="row_heading level0 row7" >global_score</th>
#       <td id="T_0d12d_row7_col0" class="data row7 col0" >0.149229</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row8" class="row_heading level0 row8" >release_year</th>
#       <td id="T_0d12d_row8_col0" class="data row8 col0" >0.135640</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row9" class="row_heading level0 row9" >decade</th>
#       <td id="T_0d12d_row9_col0" class="data row9 col0" >0.132514</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row10" class="row_heading level0 row10" >id</th>
#       <td id="T_0d12d_row10_col0" class="data row10 col0" >-0.018880</td>
#     </tr>
#     <tr>
#       <th id="T_0d12d_level0_row11" class="row_heading level0 row11" >age_years</th>
#       <td id="T_0d12d_row11_col0" class="data row11 col0" >-0.135640</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6de4c th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_6de4c td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_6de4c caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_6de4c table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_6de4c th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_6de4c td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_6de4c_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_6de4c_row1_col0 {
#   background-color: #12766e;
#   color: #f1f1f1;
# }
# #T_6de4c_row2_col0 {
#   background-color: #187c74;
#   color: #f1f1f1;
# }
# #T_6de4c_row3_col0 {
#   background-color: #23867e;
#   color: #f1f1f1;
# }
# #T_6de4c_row4_col0 {
#   background-color: #35978f;
#   color: #f1f1f1;
# }
# #T_6de4c_row5_col0 {
#   background-color: #b1e1da;
#   color: #000000;
# }
# #T_6de4c_row6_col0, #T_6de4c_row7_col0 {
#   background-color: #ddefed;
#   color: #000000;
# }
# #T_6de4c_row8_col0, #T_6de4c_row9_col0 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_6de4c_row10_col0 {
#   background-color: #f5f3ee;
#   color: #000000;
# }
# #T_6de4c_row11_col0 {
#   background-color: #e8d29a;
#   color: #000000;
# }
# </style>
# <table id="T_6de4c">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6de4c_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6de4c_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_6de4c_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row1" class="row_heading level0 row1" >total_votes</th>
#       <td id="T_6de4c_row1_col0" class="data row1 col0" >0.726973</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row2" class="row_heading level0 row2" >budget</th>
#       <td id="T_6de4c_row2_col0" class="data row2 col0" >0.709392</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row3" class="row_heading level0 row3" >votes_per_year</th>
#       <td id="T_6de4c_row3_col0" class="data row3 col0" >0.664700</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row4" class="row_heading level0 row4" >popularity</th>
#       <td id="T_6de4c_row4_col0" class="data row4 col0" >0.595985</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row5" class="row_heading level0 row5" >runtime</th>
#       <td id="T_6de4c_row5_col0" class="data row5 col0" >0.260934</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row6" class="row_heading level0 row6" >global_score</th>
#       <td id="T_6de4c_row6_col0" class="data row6 col0" >0.108567</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row7" class="row_heading level0 row7" >average_rating</th>
#       <td id="T_6de4c_row7_col0" class="data row7 col0" >0.108567</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row8" class="row_heading level0 row8" >decade</th>
#       <td id="T_6de4c_row8_col0" class="data row8 col0" >0.026446</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row9" class="row_heading level0 row9" >release_year</th>
#       <td id="T_6de4c_row9_col0" class="data row9 col0" >0.025167</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row10" class="row_heading level0 row10" >age_years</th>
#       <td id="T_6de4c_row10_col0" class="data row10 col0" >-0.025167</td>
#     </tr>
#     <tr>
#       <th id="T_6de4c_level0_row11" class="row_heading level0 row11" >id</th>
#       <td id="T_6de4c_row11_col0" class="data row11 col0" >-0.317994</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_corr_scatter(
    df_plot=df_movies,
    coluna_x=colunas_numericas.drop(['revenue', 'id']), 
    coluna_y='revenue',
    titulo='Painel de Variáveis e sua correlação com a Receita',
    quant_grafs=len(colunas_numericas.drop(['revenue', 'id']))
)

# %% [markdown]
# ## Categorica VS Categorica

# %% [markdown]
# ### `genres` vs `producer_company`

# %%
contingencia_genres_companies = rsh.gerar_contingencia(
    df=df_movies, 
    coluna_linha='producer_company', 
    coluna_coluna='genres', 
    top_n_linhas=20, 
    top_n_colunas=20
)


display(tb.estilizar_tabela(
    df=contingencia_genres_companies,
    caption='Tabela de Contingência: Top 20 Produtoras vs Top 20 Gêneros'
))
# Out:
# <style type="text/css">
# #T_cd0fb th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_cd0fb td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_cd0fb caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_cd0fb table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_cd0fb th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_cd0fb td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_cd0fb_row0_col0, #T_cd0fb_row0_col1, #T_cd0fb_row0_col2, #T_cd0fb_row0_col3, #T_cd0fb_row0_col4, #T_cd0fb_row0_col5, #T_cd0fb_row0_col6, #T_cd0fb_row0_col7, #T_cd0fb_row0_col8, #T_cd0fb_row0_col9, #T_cd0fb_row0_col10, #T_cd0fb_row0_col11, #T_cd0fb_row0_col12, #T_cd0fb_row0_col13, #T_cd0fb_row0_col14, #T_cd0fb_row0_col15, #T_cd0fb_row0_col16, #T_cd0fb_row0_col17, #T_cd0fb_row0_col18, #T_cd0fb_row0_col19, #T_cd0fb_row1_col0, #T_cd0fb_row1_col1, #T_cd0fb_row1_col2, #T_cd0fb_row1_col3, #T_cd0fb_row1_col4, #T_cd0fb_row1_col5, #T_cd0fb_row1_col6, #T_cd0fb_row1_col7, #T_cd0fb_row1_col8, #T_cd0fb_row1_col9, #T_cd0fb_row1_col10, #T_cd0fb_row1_col11, #T_cd0fb_row1_col12, #T_cd0fb_row1_col13, #T_cd0fb_row1_col14, #T_cd0fb_row1_col15, #T_cd0fb_row1_col16, #T_cd0fb_row1_col17, #T_cd0fb_row1_col18, #T_cd0fb_row1_col19, #T_cd0fb_row2_col0, #T_cd0fb_row2_col1, #T_cd0fb_row2_col2, #T_cd0fb_row2_col3, #T_cd0fb_row2_col4, #T_cd0fb_row2_col5, #T_cd0fb_row2_col6, #T_cd0fb_row2_col7, #T_cd0fb_row2_col8, #T_cd0fb_row2_col9, #T_cd0fb_row2_col10, #T_cd0fb_row2_col11, #T_cd0fb_row2_col12, #T_cd0fb_row2_col13, #T_cd0fb_row2_col14, #T_cd0fb_row2_col15, #T_cd0fb_row2_col16, #T_cd0fb_row2_col17, #T_cd0fb_row2_col18, #T_cd0fb_row2_col19, #T_cd0fb_row3_col0, #T_cd0fb_row3_col1, #T_cd0fb_row3_col2, #T_cd0fb_row3_col3, #T_cd0fb_row3_col4, #T_cd0fb_row3_col5, #T_cd0fb_row3_col6, #T_cd0fb_row3_col7, #T_cd0fb_row3_col8, #T_cd0fb_row3_col9, #T_cd0fb_row3_col10, #T_cd0fb_row3_col11, #T_cd0fb_row3_col12, #T_cd0fb_row3_col13, #T_cd0fb_row3_col14, #T_cd0fb_row3_col15, #T_cd0fb_row3_col16, #T_cd0fb_row3_col17, #T_cd0fb_row3_col18, #T_cd0fb_row3_col19, #T_cd0fb_row4_col0, #T_cd0fb_row4_col1, #T_cd0fb_row4_col2, #T_cd0fb_row4_col3, #T_cd0fb_row4_col4, #T_cd0fb_row4_col5, #T_cd0fb_row4_col6, #T_cd0fb_row4_col7, #T_cd0fb_row4_col8, #T_cd0fb_row4_col9, #T_cd0fb_row4_col10, #T_cd0fb_row4_col11, #T_cd0fb_row4_col12, #T_cd0fb_row4_col13, #T_cd0fb_row4_col14, #T_cd0fb_row4_col15, #T_cd0fb_row4_col16, #T_cd0fb_row4_col17, #T_cd0fb_row4_col18, #T_cd0fb_row4_col19, #T_cd0fb_row5_col0, #T_cd0fb_row5_col1, #T_cd0fb_row5_col2, #T_cd0fb_row5_col3, #T_cd0fb_row5_col4, #T_cd0fb_row5_col5, #T_cd0fb_row5_col6, #T_cd0fb_row5_col7, #T_cd0fb_row5_col8, #T_cd0fb_row5_col9, #T_cd0fb_row5_col10, #T_cd0fb_row5_col11, #T_cd0fb_row5_col12, #T_cd0fb_row5_col13, #T_cd0fb_row5_col14, #T_cd0fb_row5_col15, #T_cd0fb_row5_col16, #T_cd0fb_row5_col17, #T_cd0fb_row5_col18, #T_cd0fb_row5_col19, #T_cd0fb_row6_col0, #T_cd0fb_row6_col1, #T_cd0fb_row6_col2, #T_cd0fb_row6_col3, #T_cd0fb_row6_col4, #T_cd0fb_row6_col5, #T_cd0fb_row6_col6, #T_cd0fb_row6_col7, #T_cd0fb_row6_col8, #T_cd0fb_row6_col9, #T_cd0fb_row6_col10, #T_cd0fb_row6_col11, #T_cd0fb_row6_col12, #T_cd0fb_row6_col13, #T_cd0fb_row6_col14, #T_cd0fb_row6_col15, #T_cd0fb_row6_col16, #T_cd0fb_row6_col17, #T_cd0fb_row6_col18, #T_cd0fb_row6_col19, #T_cd0fb_row7_col0, #T_cd0fb_row7_col1, #T_cd0fb_row7_col2, #T_cd0fb_row7_col3, #T_cd0fb_row7_col4, #T_cd0fb_row7_col5, #T_cd0fb_row7_col6, #T_cd0fb_row7_col7, #T_cd0fb_row7_col8, #T_cd0fb_row7_col9, #T_cd0fb_row7_col10, #T_cd0fb_row7_col11, #T_cd0fb_row7_col12, #T_cd0fb_row7_col13, #T_cd0fb_row7_col14, #T_cd0fb_row7_col15, #T_cd0fb_row7_col16, #T_cd0fb_row7_col17, #T_cd0fb_row7_col18, #T_cd0fb_row7_col19, #T_cd0fb_row8_col0, #T_cd0fb_row8_col1, #T_cd0fb_row8_col2, #T_cd0fb_row8_col3, #T_cd0fb_row8_col4, #T_cd0fb_row8_col5, #T_cd0fb_row8_col6, #T_cd0fb_row8_col7, #T_cd0fb_row8_col8, #T_cd0fb_row8_col9, #T_cd0fb_row8_col10, #T_cd0fb_row8_col11, #T_cd0fb_row8_col12, #T_cd0fb_row8_col13, #T_cd0fb_row8_col14, #T_cd0fb_row8_col15, #T_cd0fb_row8_col16, #T_cd0fb_row8_col17, #T_cd0fb_row8_col18, #T_cd0fb_row8_col19, #T_cd0fb_row9_col0, #T_cd0fb_row9_col1, #T_cd0fb_row9_col2, #T_cd0fb_row9_col3, #T_cd0fb_row9_col4, #T_cd0fb_row9_col5, #T_cd0fb_row9_col6, #T_cd0fb_row9_col7, #T_cd0fb_row9_col8, #T_cd0fb_row9_col9, #T_cd0fb_row9_col10, #T_cd0fb_row9_col11, #T_cd0fb_row9_col12, #T_cd0fb_row9_col13, #T_cd0fb_row9_col14, #T_cd ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_genres_companies = mt.testar_dependencia_categorica(
    contingencia_genres_companies
)

display(tb.estilizar_tabela(
    df=resultado_genres_companies,
    caption='Relatório: genres vs production_companies'
))
# Out:
# <style type="text/css">
# #T_548b1 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_548b1 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_548b1 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_548b1 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_548b1 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_548b1 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_548b1_row0_col0, #T_548b1_row0_col1, #T_548b1_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_548b1">
#   <caption>Relatório: genres vs production_companies</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_548b1_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_548b1_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_548b1_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_548b1_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_548b1_row0_col0" class="data row0 col0" >9645.981036</td>
#       <td id="T_548b1_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_548b1_row0_col2" class="data row0 col2" >361</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_genres_companies,
    chi2=resultado_genres_companies['Qui-Quadrado'].iloc[0],
    p_valor=resultado_genres_companies['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ### `genres` vs `production_countries`

# %%
contingencia_genres_countries = rsh.gerar_contingencia(
    df=df_movies, 
    coluna_linha='production_countries', 
    coluna_coluna='genres', 
    top_n_linhas=20, 
    top_n_colunas=20
)


display(tb.estilizar_tabela(
    df=contingencia_genres_countries,
    caption='Tabela de Contingência: Top 20 Países vs Top 20 Gêneros'
))
# Out:
# <style type="text/css">
# #T_c9fbe th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_c9fbe td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_c9fbe caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_c9fbe table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_c9fbe th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_c9fbe td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_c9fbe_row0_col0, #T_c9fbe_row0_col1, #T_c9fbe_row0_col2, #T_c9fbe_row0_col3, #T_c9fbe_row0_col4, #T_c9fbe_row0_col5, #T_c9fbe_row0_col6, #T_c9fbe_row0_col7, #T_c9fbe_row0_col8, #T_c9fbe_row0_col9, #T_c9fbe_row0_col10, #T_c9fbe_row0_col11, #T_c9fbe_row0_col12, #T_c9fbe_row0_col13, #T_c9fbe_row0_col14, #T_c9fbe_row0_col15, #T_c9fbe_row0_col16, #T_c9fbe_row0_col17, #T_c9fbe_row0_col18, #T_c9fbe_row0_col19, #T_c9fbe_row1_col0, #T_c9fbe_row1_col1, #T_c9fbe_row1_col2, #T_c9fbe_row1_col3, #T_c9fbe_row1_col4, #T_c9fbe_row1_col5, #T_c9fbe_row1_col6, #T_c9fbe_row1_col7, #T_c9fbe_row1_col8, #T_c9fbe_row1_col9, #T_c9fbe_row1_col10, #T_c9fbe_row1_col11, #T_c9fbe_row1_col12, #T_c9fbe_row1_col13, #T_c9fbe_row1_col14, #T_c9fbe_row1_col15, #T_c9fbe_row1_col16, #T_c9fbe_row1_col17, #T_c9fbe_row1_col18, #T_c9fbe_row1_col19, #T_c9fbe_row2_col0, #T_c9fbe_row2_col1, #T_c9fbe_row2_col2, #T_c9fbe_row2_col3, #T_c9fbe_row2_col4, #T_c9fbe_row2_col5, #T_c9fbe_row2_col6, #T_c9fbe_row2_col7, #T_c9fbe_row2_col8, #T_c9fbe_row2_col9, #T_c9fbe_row2_col10, #T_c9fbe_row2_col11, #T_c9fbe_row2_col12, #T_c9fbe_row2_col13, #T_c9fbe_row2_col14, #T_c9fbe_row2_col15, #T_c9fbe_row2_col16, #T_c9fbe_row2_col17, #T_c9fbe_row2_col18, #T_c9fbe_row2_col19, #T_c9fbe_row3_col0, #T_c9fbe_row3_col1, #T_c9fbe_row3_col2, #T_c9fbe_row3_col3, #T_c9fbe_row3_col4, #T_c9fbe_row3_col5, #T_c9fbe_row3_col6, #T_c9fbe_row3_col7, #T_c9fbe_row3_col8, #T_c9fbe_row3_col9, #T_c9fbe_row3_col10, #T_c9fbe_row3_col11, #T_c9fbe_row3_col12, #T_c9fbe_row3_col13, #T_c9fbe_row3_col14, #T_c9fbe_row3_col15, #T_c9fbe_row3_col16, #T_c9fbe_row3_col17, #T_c9fbe_row3_col18, #T_c9fbe_row3_col19, #T_c9fbe_row4_col0, #T_c9fbe_row4_col1, #T_c9fbe_row4_col2, #T_c9fbe_row4_col3, #T_c9fbe_row4_col4, #T_c9fbe_row4_col5, #T_c9fbe_row4_col6, #T_c9fbe_row4_col7, #T_c9fbe_row4_col8, #T_c9fbe_row4_col9, #T_c9fbe_row4_col10, #T_c9fbe_row4_col11, #T_c9fbe_row4_col12, #T_c9fbe_row4_col13, #T_c9fbe_row4_col14, #T_c9fbe_row4_col15, #T_c9fbe_row4_col16, #T_c9fbe_row4_col17, #T_c9fbe_row4_col18, #T_c9fbe_row4_col19, #T_c9fbe_row5_col0, #T_c9fbe_row5_col1, #T_c9fbe_row5_col2, #T_c9fbe_row5_col3, #T_c9fbe_row5_col4, #T_c9fbe_row5_col5, #T_c9fbe_row5_col6, #T_c9fbe_row5_col7, #T_c9fbe_row5_col8, #T_c9fbe_row5_col9, #T_c9fbe_row5_col10, #T_c9fbe_row5_col11, #T_c9fbe_row5_col12, #T_c9fbe_row5_col13, #T_c9fbe_row5_col14, #T_c9fbe_row5_col15, #T_c9fbe_row5_col16, #T_c9fbe_row5_col17, #T_c9fbe_row5_col18, #T_c9fbe_row5_col19, #T_c9fbe_row6_col0, #T_c9fbe_row6_col1, #T_c9fbe_row6_col2, #T_c9fbe_row6_col3, #T_c9fbe_row6_col4, #T_c9fbe_row6_col5, #T_c9fbe_row6_col6, #T_c9fbe_row6_col7, #T_c9fbe_row6_col8, #T_c9fbe_row6_col9, #T_c9fbe_row6_col10, #T_c9fbe_row6_col11, #T_c9fbe_row6_col12, #T_c9fbe_row6_col13, #T_c9fbe_row6_col14, #T_c9fbe_row6_col15, #T_c9fbe_row6_col16, #T_c9fbe_row6_col17, #T_c9fbe_row6_col18, #T_c9fbe_row6_col19, #T_c9fbe_row7_col0, #T_c9fbe_row7_col1, #T_c9fbe_row7_col2, #T_c9fbe_row7_col3, #T_c9fbe_row7_col4, #T_c9fbe_row7_col5, #T_c9fbe_row7_col6, #T_c9fbe_row7_col7, #T_c9fbe_row7_col8, #T_c9fbe_row7_col9, #T_c9fbe_row7_col10, #T_c9fbe_row7_col11, #T_c9fbe_row7_col12, #T_c9fbe_row7_col13, #T_c9fbe_row7_col14, #T_c9fbe_row7_col15, #T_c9fbe_row7_col16, #T_c9fbe_row7_col17, #T_c9fbe_row7_col18, #T_c9fbe_row7_col19, #T_c9fbe_row8_col0, #T_c9fbe_row8_col1, #T_c9fbe_row8_col2, #T_c9fbe_row8_col3, #T_c9fbe_row8_col4, #T_c9fbe_row8_col5, #T_c9fbe_row8_col6, #T_c9fbe_row8_col7, #T_c9fbe_row8_col8, #T_c9fbe_row8_col9, #T_c9fbe_row8_col10, #T_c9fbe_row8_col11, #T_c9fbe_row8_col12, #T_c9fbe_row8_col13, #T_c9fbe_row8_col14, #T_c9fbe_row8_col15, #T_c9fbe_row8_col16, #T_c9fbe_row8_col17, #T_c9fbe_row8_col18, #T_c9fbe_row8_col19, #T_c9fbe_row9_col0, #T_c9fbe_row9_col1, #T_c9fbe_row9_col2, #T_c9fbe_row9_col3, #T_c9fbe_row9_col4, #T_c9fbe_row9_col5, #T_c9fbe_row9_col6, #T_c9fbe_row9_col7, #T_c9fbe_row9_col8, #T_c9fbe_row9_col9, #T_c9fbe_row9_col10, #T_c9fbe_row9_col11, #T_c9fbe_row9_col12, #T_c9fbe_row9_col13, #T_c9fbe_row9_col14, #T_c9 ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_genres_countries = mt.testar_dependencia_categorica(
    contingencia_genres_countries
)

display(tb.estilizar_tabela(
    df=resultado_genres_countries,
    caption='Relatório: genres vs production_countries'
))
# Out:
# <style type="text/css">
# #T_a422d th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_a422d td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_a422d caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_a422d table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_a422d th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_a422d td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_a422d_row0_col0, #T_a422d_row0_col1, #T_a422d_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_a422d">
#   <caption>Relatório: genres vs production_countries</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a422d_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_a422d_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_a422d_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a422d_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_a422d_row0_col0" class="data row0 col0" >17591.280320</td>
#       <td id="T_a422d_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_a422d_row0_col2" class="data row0 col2" >361</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_genres_countries,
    chi2=resultado_genres_countries['Qui-Quadrado'].iloc[0],
    p_valor=resultado_genres_countries['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ### `genres` vs `original_language	`

# %%
contingencia_genres_language = rsh.gerar_contingencia(
    df=df_movies, 
    coluna_linha='original_language', 
    coluna_coluna='genres', 
    top_n_linhas=20, 
    top_n_colunas=20
)


display(tb.estilizar_tabela(
    df=contingencia_genres_language,
    caption='Tabela de Contingência: Top 20 Idiomas vs Top 20 Gêneros'
))
# Out:
# <style type="text/css">
# #T_41b77 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_41b77 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_41b77 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_41b77 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_41b77 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_41b77 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_41b77_row0_col0, #T_41b77_row0_col1, #T_41b77_row0_col2, #T_41b77_row0_col3, #T_41b77_row0_col4, #T_41b77_row0_col5, #T_41b77_row0_col6, #T_41b77_row0_col7, #T_41b77_row0_col8, #T_41b77_row0_col9, #T_41b77_row0_col10, #T_41b77_row0_col11, #T_41b77_row0_col12, #T_41b77_row0_col13, #T_41b77_row0_col14, #T_41b77_row0_col15, #T_41b77_row0_col16, #T_41b77_row0_col17, #T_41b77_row0_col18, #T_41b77_row0_col19, #T_41b77_row1_col0, #T_41b77_row1_col1, #T_41b77_row1_col2, #T_41b77_row1_col3, #T_41b77_row1_col4, #T_41b77_row1_col5, #T_41b77_row1_col6, #T_41b77_row1_col7, #T_41b77_row1_col8, #T_41b77_row1_col9, #T_41b77_row1_col10, #T_41b77_row1_col11, #T_41b77_row1_col12, #T_41b77_row1_col13, #T_41b77_row1_col14, #T_41b77_row1_col15, #T_41b77_row1_col16, #T_41b77_row1_col17, #T_41b77_row1_col18, #T_41b77_row1_col19, #T_41b77_row2_col0, #T_41b77_row2_col1, #T_41b77_row2_col2, #T_41b77_row2_col3, #T_41b77_row2_col4, #T_41b77_row2_col5, #T_41b77_row2_col6, #T_41b77_row2_col7, #T_41b77_row2_col8, #T_41b77_row2_col9, #T_41b77_row2_col10, #T_41b77_row2_col11, #T_41b77_row2_col12, #T_41b77_row2_col13, #T_41b77_row2_col14, #T_41b77_row2_col15, #T_41b77_row2_col16, #T_41b77_row2_col17, #T_41b77_row2_col18, #T_41b77_row2_col19, #T_41b77_row3_col0, #T_41b77_row3_col1, #T_41b77_row3_col2, #T_41b77_row3_col3, #T_41b77_row3_col4, #T_41b77_row3_col5, #T_41b77_row3_col6, #T_41b77_row3_col7, #T_41b77_row3_col8, #T_41b77_row3_col9, #T_41b77_row3_col10, #T_41b77_row3_col11, #T_41b77_row3_col12, #T_41b77_row3_col13, #T_41b77_row3_col14, #T_41b77_row3_col15, #T_41b77_row3_col16, #T_41b77_row3_col17, #T_41b77_row3_col18, #T_41b77_row3_col19, #T_41b77_row4_col0, #T_41b77_row4_col1, #T_41b77_row4_col2, #T_41b77_row4_col3, #T_41b77_row4_col4, #T_41b77_row4_col5, #T_41b77_row4_col6, #T_41b77_row4_col7, #T_41b77_row4_col8, #T_41b77_row4_col9, #T_41b77_row4_col10, #T_41b77_row4_col11, #T_41b77_row4_col12, #T_41b77_row4_col13, #T_41b77_row4_col14, #T_41b77_row4_col15, #T_41b77_row4_col16, #T_41b77_row4_col17, #T_41b77_row4_col18, #T_41b77_row4_col19, #T_41b77_row5_col0, #T_41b77_row5_col1, #T_41b77_row5_col2, #T_41b77_row5_col3, #T_41b77_row5_col4, #T_41b77_row5_col5, #T_41b77_row5_col6, #T_41b77_row5_col7, #T_41b77_row5_col8, #T_41b77_row5_col9, #T_41b77_row5_col10, #T_41b77_row5_col11, #T_41b77_row5_col12, #T_41b77_row5_col13, #T_41b77_row5_col14, #T_41b77_row5_col15, #T_41b77_row5_col16, #T_41b77_row5_col17, #T_41b77_row5_col18, #T_41b77_row5_col19, #T_41b77_row6_col0, #T_41b77_row6_col1, #T_41b77_row6_col2, #T_41b77_row6_col3, #T_41b77_row6_col4, #T_41b77_row6_col5, #T_41b77_row6_col6, #T_41b77_row6_col7, #T_41b77_row6_col8, #T_41b77_row6_col9, #T_41b77_row6_col10, #T_41b77_row6_col11, #T_41b77_row6_col12, #T_41b77_row6_col13, #T_41b77_row6_col14, #T_41b77_row6_col15, #T_41b77_row6_col16, #T_41b77_row6_col17, #T_41b77_row6_col18, #T_41b77_row6_col19, #T_41b77_row7_col0, #T_41b77_row7_col1, #T_41b77_row7_col2, #T_41b77_row7_col3, #T_41b77_row7_col4, #T_41b77_row7_col5, #T_41b77_row7_col6, #T_41b77_row7_col7, #T_41b77_row7_col8, #T_41b77_row7_col9, #T_41b77_row7_col10, #T_41b77_row7_col11, #T_41b77_row7_col12, #T_41b77_row7_col13, #T_41b77_row7_col14, #T_41b77_row7_col15, #T_41b77_row7_col16, #T_41b77_row7_col17, #T_41b77_row7_col18, #T_41b77_row7_col19, #T_41b77_row8_col0, #T_41b77_row8_col1, #T_41b77_row8_col2, #T_41b77_row8_col3, #T_41b77_row8_col4, #T_41b77_row8_col5, #T_41b77_row8_col6, #T_41b77_row8_col7, #T_41b77_row8_col8, #T_41b77_row8_col9, #T_41b77_row8_col10, #T_41b77_row8_col11, #T_41b77_row8_col12, #T_41b77_row8_col13, #T_41b77_row8_col14, #T_41b77_row8_col15, #T_41b77_row8_col16, #T_41b77_row8_col17, #T_41b77_row8_col18, #T_41b77_row8_col19, #T_41b77_row9_col0, #T_41b77_row9_col1, #T_41b77_row9_col2, #T_41b77_row9_col3, #T_41b77_row9_col4, #T_41b77_row9_col5, #T_41b77_row9_col6, #T_41b77_row9_col7, #T_41b77_row9_col8, #T_41b77_row9_col9, #T_41b77_row9_col10, #T_41b77_row9_col11, #T_41b77_row9_col12, #T_41b77_row9_col13, #T_41b77_row9_col14, #T_41 ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_genres_language = mt.testar_dependencia_categorica(
    contingencia_genres_language
)

display(tb.estilizar_tabela(
    df=resultado_genres_language,
    caption='Relatório: genres vs original_language'
))
# Out:
# <style type="text/css">
# #T_db0e0 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_db0e0 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_db0e0 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_db0e0 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_db0e0 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_db0e0 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_db0e0_row0_col0, #T_db0e0_row0_col1, #T_db0e0_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_db0e0">
#   <caption>Relatório: genres vs original_language</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db0e0_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_db0e0_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_db0e0_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db0e0_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_db0e0_row0_col0" class="data row0 col0" >7928.605381</td>
#       <td id="T_db0e0_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_db0e0_row0_col2" class="data row0 col2" >361</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_genres_language,
    chi2=resultado_genres_language['Qui-Quadrado'].iloc[0],
    p_valor=resultado_genres_language['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ### `production_countries` vs `original_language`

# %%
contingencia_countries_language = rsh.gerar_contingencia(
    df=df_movies, 
    coluna_linha='original_language', 
    coluna_coluna='production_countries', 
    top_n_linhas=20, 
    top_n_colunas=20
)


display(tb.estilizar_tabela(
    df=contingencia_countries_language,
    caption='Tabela de Contingência: Top 20 Idiomas vs Top 20 Produtoras'
))
# Out:
# <style type="text/css">
# #T_8f11c th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_8f11c td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_8f11c caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_8f11c table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_8f11c th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_8f11c td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_8f11c_row0_col0, #T_8f11c_row0_col1, #T_8f11c_row0_col2, #T_8f11c_row0_col3, #T_8f11c_row0_col4, #T_8f11c_row0_col5, #T_8f11c_row0_col6, #T_8f11c_row0_col7, #T_8f11c_row0_col8, #T_8f11c_row0_col9, #T_8f11c_row0_col10, #T_8f11c_row0_col11, #T_8f11c_row0_col12, #T_8f11c_row0_col13, #T_8f11c_row0_col14, #T_8f11c_row0_col15, #T_8f11c_row0_col16, #T_8f11c_row0_col17, #T_8f11c_row0_col18, #T_8f11c_row0_col19, #T_8f11c_row1_col0, #T_8f11c_row1_col1, #T_8f11c_row1_col2, #T_8f11c_row1_col3, #T_8f11c_row1_col4, #T_8f11c_row1_col5, #T_8f11c_row1_col6, #T_8f11c_row1_col7, #T_8f11c_row1_col8, #T_8f11c_row1_col9, #T_8f11c_row1_col10, #T_8f11c_row1_col11, #T_8f11c_row1_col12, #T_8f11c_row1_col13, #T_8f11c_row1_col14, #T_8f11c_row1_col15, #T_8f11c_row1_col16, #T_8f11c_row1_col17, #T_8f11c_row1_col18, #T_8f11c_row1_col19, #T_8f11c_row2_col0, #T_8f11c_row2_col1, #T_8f11c_row2_col2, #T_8f11c_row2_col3, #T_8f11c_row2_col4, #T_8f11c_row2_col5, #T_8f11c_row2_col6, #T_8f11c_row2_col7, #T_8f11c_row2_col8, #T_8f11c_row2_col9, #T_8f11c_row2_col10, #T_8f11c_row2_col11, #T_8f11c_row2_col12, #T_8f11c_row2_col13, #T_8f11c_row2_col14, #T_8f11c_row2_col15, #T_8f11c_row2_col16, #T_8f11c_row2_col17, #T_8f11c_row2_col18, #T_8f11c_row2_col19, #T_8f11c_row3_col0, #T_8f11c_row3_col1, #T_8f11c_row3_col2, #T_8f11c_row3_col3, #T_8f11c_row3_col4, #T_8f11c_row3_col5, #T_8f11c_row3_col6, #T_8f11c_row3_col7, #T_8f11c_row3_col8, #T_8f11c_row3_col9, #T_8f11c_row3_col10, #T_8f11c_row3_col11, #T_8f11c_row3_col12, #T_8f11c_row3_col13, #T_8f11c_row3_col14, #T_8f11c_row3_col15, #T_8f11c_row3_col16, #T_8f11c_row3_col17, #T_8f11c_row3_col18, #T_8f11c_row3_col19, #T_8f11c_row4_col0, #T_8f11c_row4_col1, #T_8f11c_row4_col2, #T_8f11c_row4_col3, #T_8f11c_row4_col4, #T_8f11c_row4_col5, #T_8f11c_row4_col6, #T_8f11c_row4_col7, #T_8f11c_row4_col8, #T_8f11c_row4_col9, #T_8f11c_row4_col10, #T_8f11c_row4_col11, #T_8f11c_row4_col12, #T_8f11c_row4_col13, #T_8f11c_row4_col14, #T_8f11c_row4_col15, #T_8f11c_row4_col16, #T_8f11c_row4_col17, #T_8f11c_row4_col18, #T_8f11c_row4_col19, #T_8f11c_row5_col0, #T_8f11c_row5_col1, #T_8f11c_row5_col2, #T_8f11c_row5_col3, #T_8f11c_row5_col4, #T_8f11c_row5_col5, #T_8f11c_row5_col6, #T_8f11c_row5_col7, #T_8f11c_row5_col8, #T_8f11c_row5_col9, #T_8f11c_row5_col10, #T_8f11c_row5_col11, #T_8f11c_row5_col12, #T_8f11c_row5_col13, #T_8f11c_row5_col14, #T_8f11c_row5_col15, #T_8f11c_row5_col16, #T_8f11c_row5_col17, #T_8f11c_row5_col18, #T_8f11c_row5_col19, #T_8f11c_row6_col0, #T_8f11c_row6_col1, #T_8f11c_row6_col2, #T_8f11c_row6_col3, #T_8f11c_row6_col4, #T_8f11c_row6_col5, #T_8f11c_row6_col6, #T_8f11c_row6_col7, #T_8f11c_row6_col8, #T_8f11c_row6_col9, #T_8f11c_row6_col10, #T_8f11c_row6_col11, #T_8f11c_row6_col12, #T_8f11c_row6_col13, #T_8f11c_row6_col14, #T_8f11c_row6_col15, #T_8f11c_row6_col16, #T_8f11c_row6_col17, #T_8f11c_row6_col18, #T_8f11c_row6_col19, #T_8f11c_row7_col0, #T_8f11c_row7_col1, #T_8f11c_row7_col2, #T_8f11c_row7_col3, #T_8f11c_row7_col4, #T_8f11c_row7_col5, #T_8f11c_row7_col6, #T_8f11c_row7_col7, #T_8f11c_row7_col8, #T_8f11c_row7_col9, #T_8f11c_row7_col10, #T_8f11c_row7_col11, #T_8f11c_row7_col12, #T_8f11c_row7_col13, #T_8f11c_row7_col14, #T_8f11c_row7_col15, #T_8f11c_row7_col16, #T_8f11c_row7_col17, #T_8f11c_row7_col18, #T_8f11c_row7_col19, #T_8f11c_row8_col0, #T_8f11c_row8_col1, #T_8f11c_row8_col2, #T_8f11c_row8_col3, #T_8f11c_row8_col4, #T_8f11c_row8_col5, #T_8f11c_row8_col6, #T_8f11c_row8_col7, #T_8f11c_row8_col8, #T_8f11c_row8_col9, #T_8f11c_row8_col10, #T_8f11c_row8_col11, #T_8f11c_row8_col12, #T_8f11c_row8_col13, #T_8f11c_row8_col14, #T_8f11c_row8_col15, #T_8f11c_row8_col16, #T_8f11c_row8_col17, #T_8f11c_row8_col18, #T_8f11c_row8_col19, #T_8f11c_row9_col0, #T_8f11c_row9_col1, #T_8f11c_row9_col2, #T_8f11c_row9_col3, #T_8f11c_row9_col4, #T_8f11c_row9_col5, #T_8f11c_row9_col6, #T_8f11c_row9_col7, #T_8f11c_row9_col8, #T_8f11c_row9_col9, #T_8f11c_row9_col10, #T_8f11c_row9_col11, #T_8f11c_row9_col12, #T_8f11c_row9_col13, #T_8f11c_row9_col14, #T_8f ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_countries_language = mt.testar_dependencia_categorica(
    contingencia_countries_language
)

display(tb.estilizar_tabela(
    df=resultado_countries_language,
    caption='Relatório: production_countries vs original_language'
))
# Out:
# <style type="text/css">
# #T_17dc7 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_17dc7 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_17dc7 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_17dc7 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_17dc7 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_17dc7 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_17dc7_row0_col0, #T_17dc7_row0_col1, #T_17dc7_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_17dc7">
#   <caption>Relatório: production_countries vs original_language</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17dc7_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_17dc7_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_17dc7_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17dc7_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_17dc7_row0_col0" class="data row0 col0" >274657.197187</td>
#       <td id="T_17dc7_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_17dc7_row0_col2" class="data row0 col2" >361</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_countries_language,
    chi2=resultado_countries_language['Qui-Quadrado'].iloc[0],
    p_valor=resultado_countries_language['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ---
# ## Categorica VS Numérica
