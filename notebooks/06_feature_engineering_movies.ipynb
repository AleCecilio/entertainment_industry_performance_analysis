# %% [markdown]
# # Engenharia de Freatures: The Movies Dataset
# Esta etapa é a mais complexa do pipeline de dados de filmes. Ela transforma colunas armazenadas em formato JSON serializado em estruturas Python nativas, aplica uma **regra de negócio baseada no Princípio de Pareto** para correção de franquias ausentes, e cria features derivadas que habilitam análises comparativas entre filmes independentes e propriedades intelectuais de franquia.
#
# - **Escopo:** Deserialização de colunas JSON, correção de franquias por mapeamento explícito e criação de features binárias e de granularidade
# - **Produto final desta etapa:** `movies_feature_master.parquet` e `movies_feature_master.csv` — datasets analiticamente completos para os notebooks de análise e visualizações futuras.

# %%
# Configuração do Jupyter (Autoreload)
# %load_ext autoreload
# %autoreload 2

# Configuração de Caminho (Path Setup)
import sys
import os

# Adiciona a pasta raiz do projeto (..) ao sistema para liberar os imports locais
sys.path.append(os.path.abspath(os.path.join('..')))


# Importação de Bibliotecas e Módulos
import ast
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Nossos módulos customizados da pasta src/
import src.io.data_loader as dl
import src.io.data_save as ds
import src.view.tables as tb
import src.utils.features as feat
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---
# ## Carregando Dados

# %%
caminho = '../data/interim/movies/movies_cleaned.parquet'
df_movies = dl.load_data(caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (41091, 16)

# %% [markdown]
# ---
# ## Correção de Franquias: Aplicação da Regra de Pareto ao Enriquecimento de Dados
#
# A coluna `belongs_to_collection` do dataset original apresenta ausências para filmes de grandes franquias — não por ausência de vínculo, mas por limitações de cobertura da base de dados na época de sua criação. Como o pertencimento a uma franquia é uma das dimensões analíticas mais relevantes deste projeto, a ausência desses vínculos introduziria viés sistemático nas comparações entre filmes independentes e de franquia.
#
# A correção prioriza as **franquias de maior impacto comercial e cultural**, seguindo o princípio de que um subconjunto reduzido de propriedades intelectuais representa a maior parte da receita de bilheteria global. O mapeamento explícito por palavra-chave no título garante que os filmes mais analiticamente relevantes estejam corretamente classificados.
#
# - **Regra de negócio:** Somente registros com `belongs_to_collection` ausente recebem a correção — vínculos existentes no dataset original nunca são sobrescritos
# - **Escopo da correção:** Franquias do universo Marvel, DC, grandes sagas de animação, ação e aventura que compõem o topo da distribuição de bilheteria histórica

# %%
# Dicionário Expandido: Mapeamento das Maiores Franquias do Cinema 
correcoes_franquias = {
    # 🦸‍♂️ Heróis (Marvel & DC)
    'Avengers': 'The Avengers Collection',
    'Vingadores': 'The Avengers Collection',
    'Spider-Man': 'Spider-Man Collection',
    'Homem-Aranha': 'Spider-Man Collection',
    'Iron Man': 'Iron Man Collection',
    'Homem de Ferro': 'Iron Man Collection',
    'Captain America': 'Captain America Collection',
    'Thor': 'Thor Collection',
    'X-Men': 'X-Men Collection',
    'Batman': 'Batman Collection',
    'Dark Knight': 'Batman Collection',
    'Cavaleiro das Trevas': 'Batman Collection',
    'Superman': 'Superman Collection',
    
    # 🧙‍♂️ Sci-Fi & Fantasia
    'Star Wars': 'Star Wars Collection',
    'Harry Potter': 'Harry Potter Collection',
    'Lord of the Rings': 'The Lord of the Rings Collection',
    'Senhor dos Anéis': 'The Lord of the Rings Collection',
    'Hobbit': 'The Hobbit Collection',
    'Matrix': 'The Matrix Collection',
    'Hunger Games': 'The Hunger Games Collection',
    'Jogos Vorazes': 'The Hunger Games Collection',
    'Twilight': 'The Twilight Saga Collection',
    'Crepúsculo': 'The Twilight Saga Collection',
    'Jumanji': 'Jumanji Collection',

    # 💥 Ação, Aventura & Sci-Fi
    'James Bond': 'James Bond Collection',
    '007': 'James Bond Collection',
    'Fast and Furious': 'The Fast and the Furious Collection',
    'Velozes e Furiosos': 'The Fast and the Furious Collection',
    'Mission: Impossible': 'Mission: Impossible Collection',
    'Missão: Impossível': 'Mission: Impossible Collection',
    'Indiana Jones': 'Indiana Jones Collection',
    'Pirates of the Caribbean': 'Pirates of the Caribbean Collection',
    'Piratas do Caribe': 'Pirates of the Caribbean Collection',
    'Jurassic': 'Jurassic Park Collection', 
    'Terminator': 'The Terminator Collection',
    'Exterminador do Futuro': 'The Terminator Collection',
    'Transformers': 'Transformers Collection',
    'Mad Max': 'Mad Max Collection',

    # 🎬 Animações Gigantes
    'Toy Story': 'Toy Story Collection',
    'Shrek': 'Shrek Collection',
    'Despicable Me': 'Despicable Me Collection',
    'Meu Malvado Favorito': 'Despicable Me Collection',
    'Minions': 'Despicable Me Collection',
    'Ice Age': 'Ice Age Collection',
    'A Era do Gelo': 'Ice Age Collection'
}

# %%
# Varrer o dicionário e aplicar a regra
sucessos = 0
for palavra_chave, nome_franquia in correcoes_franquias.items():
    # Encontra os filmes pelo padrão de texto no título
    filtro = df_movies['original_title'].str.contains(palavra_chave, case=False, na=False)
    
    # Conta quantos vão ser alterados para o log
    qtd_alterar = (filtro & (df_movies['belongs_to_collection'] == 'Filme Isolado')).sum()
    sucessos += qtd_alterar
    
    # Aplica a regra de negócio
    df_movies.loc[filtro & (df_movies['belongs_to_collection'] == 'Filme Isolado'), 
                  'belongs_to_collection'] = nome_franquia

print(f"Dicionário de {len(correcoes_franquias)} chaves processado.")
print(f"Total de filmes realocados para franquias: {sucessos}")
# Out:
# Dicionário de 45 chaves processado.
# Total de filmes realocados para franquias: 0

# %% [markdown]
# ---
# ## Harmonização e Padronização de Notas

# %%
# Harmonização do esquema de dados para o domínio de livros
df_movies = feat.harmonizar_esquema_dados(df_movies, 'filme')

# %%
# Criação de features globais para o domínio de filmes
df_movies = feat.criar_features_globais(df_movies, 10)

# %%
display(tb.estilizar_tabela(df_movies, qtd_linhas=10))
# Out:
# <style type="text/css">
# #T_603ef th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_603ef td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_603ef caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_603ef table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_603ef th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_603ef td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_603ef_row0_col0, #T_603ef_row0_col2, #T_603ef_row0_col21, #T_603ef_row1_col0, #T_603ef_row1_col2, #T_603ef_row1_col21, #T_603ef_row2_col0, #T_603ef_row2_col2, #T_603ef_row2_col21, #T_603ef_row3_col0, #T_603ef_row3_col2, #T_603ef_row3_col21, #T_603ef_row4_col0, #T_603ef_row4_col2, #T_603ef_row4_col21, #T_603ef_row5_col0, #T_603ef_row5_col2, #T_603ef_row5_col21, #T_603ef_row6_col0, #T_603ef_row6_col2, #T_603ef_row6_col21, #T_603ef_row7_col0, #T_603ef_row7_col2, #T_603ef_row7_col21, #T_603ef_row8_col0, #T_603ef_row8_col2, #T_603ef_row8_col21, #T_603ef_row9_col0, #T_603ef_row9_col2, #T_603ef_row9_col21 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #6D597A;
#   color: white;
# }
# #T_603ef_row0_col1, #T_603ef_row0_col10, #T_603ef_row1_col1, #T_603ef_row1_col10, #T_603ef_row3_col1, #T_603ef_row3_col10, #T_603ef_row4_col10, #T_603ef_row5_col1, #T_603ef_row5_col10, #T_603ef_row6_col1, #T_603ef_row8_col1, #T_603ef_row8_col10, #T_603ef_row9_col1, #T_603ef_row9_col10 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #588157;
#   color: white;
# }
# #T_603ef_row0_col3, #T_603ef_row0_col5, #T_603ef_row0_col13, #T_603ef_row1_col3, #T_603ef_row1_col5, #T_603ef_row1_col13, #T_603ef_row2_col3, #T_603ef_row2_col5, #T_603ef_row2_col13, #T_603ef_row3_col3, #T_603ef_row3_col5, #T_603ef_row3_col13, #T_603ef_row4_col3, #T_603ef_row4_col5, #T_603ef_row4_col13, #T_603ef_row5_col3, #T_603ef_row5_col5, #T_603ef_row5_col13, #T_603ef_row6_col3, #T_603ef_row6_col5, #T_603ef_row6_col13, #T_603ef_row7_col3, #T_603ef_row7_col5, #T_603ef_row7_col13, #T_603ef_row8_col3, #T_603ef_row8_col5, #T_603ef_row8_col13, #T_603ef_row9_col3, #T_603ef_row9_col5, #T_603ef_row9_col13 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #2B2D42;
#   color: white;
# }
# #T_603ef_row0_col4, #T_603ef_row0_col8, #T_603ef_row0_col12, #T_603ef_row1_col4, #T_603ef_row1_col8, #T_603ef_row1_col12, #T_603ef_row2_col4, #T_603ef_row2_col8, #T_603ef_row2_col12, #T_603ef_row3_col4, #T_603ef_row3_col8, #T_603ef_row3_col12, #T_603ef_row4_col4, #T_603ef_row4_col8, #T_603ef_row4_col12, #T_603ef_row5_col4, #T_603ef_row5_col8, #T_603ef_row5_col12, #T_603ef_row6_col4, #T_603ef_row6_col8, #T_603ef_row6_col12, #T_603ef_row7_col4, #T_603ef_row7_col8, #T_603ef_row7_col12, #T_603ef_row8_col4, #T_603ef_row8_col8, #T_603ef_row8_col12, #T_603ef_row9_col4, #T_603ef_row9_col8, #T_603ef_row9_col12 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #3D5A80;
#   color: white;
# }
# #T_603ef_row0_col6, #T_603ef_row0_col11, #T_603ef_row0_col14, #T_603ef_row0_col15, #T_603ef_row0_col16, #T_603ef_row0_col20, #T_603ef_row1_col6, #T_603ef_row1_col11, #T_603ef_row1_col14, #T_603ef_row1_col15, #T_603ef_row1_col16, #T_603ef_row1_col20, #T_603ef_row2_col6, #T_603ef_row2_col11, #T_603ef_row2_col14, #T_603ef_row2_col15, #T_603ef_row2_col16, #T_603ef_row2_col20, #T_603ef_row3_col6, #T_603ef_row3_col11, #T_603ef_row3_col14, #T_603ef_row3_col15, #T_603ef_row3_col16, #T_603ef_row3_col20, #T_603ef_row4_col6, #T_603ef_row4_col11, #T_603ef_row4_col14, #T_603ef_row4_col15, #T_603ef_row4_col16, #T_603ef_row4_col20, #T_603ef_row5_col6, #T_603ef_row5_col11, #T_603ef_row5_col14, #T_603ef_row5_col15, #T_603ef_row5_col16, #T_603ef_row5_col20, #T_603ef_row6_col6, #T_603ef_row6_col11, #T_603ef_row6_col14, #T_603ef_row6_col15, #T_603ef_row6_col16, #T_603ef_row6_col20, #T_603ef_row7_col6, #T_603ef_row7_col11, #T_603ef_row7_col14, #T_603ef_row7_col15, #T_603ef_row7_col16, #T_603ef_row7_col20, #T_603ef_row8_col6, #T_603ef_row8_col11, #T_603ef_row8_col14, #T_603ef_row8_col15, #T_603ef_row8_col16, #T_603ef_row8_col20, #T_603ef_row9_col6, #T_603ef_row9_col11, #T_603ef_row9_col14, #T_603ef_row9_col15, #T_603ef_row9_col16, #T_603ef_row9_col20 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #D4A373;
#   color: black;
# }
# #T_603ef_row0_col7, #T_603ef_row1_col7, #T_603ef_row2_col7, #T_603ef_row3_col7, #T_603ef_row4_col7, #T_603ef_row5_col7, #T_603ef_row6_col7, #T_603ef_row7_col7, #T_603ef_row8_col7, #T_603ef_row9_col7 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #4A4E69;
#   color: white;
# }
# #T_603ef_row0_col9, #T_603ef_row0_col17, #T_603ef_row0_col18, #T_603ef_row0_col19, #T_603ef_row1_col9, #T_603ef_row1_col17, #T_603ef_row1_col18, #T_603ef_row1_col19, #T_603ef_row2_col9, #T_603ef_row2_col17, #T_603ef_row2_col18, #T_603ef_row2_col19, #T_603ef_row3_col9, #T_603ef_row3_col17, #T_603ef_row3_col18, #T_603ef_row3_col19, #T_603ef_row4_col9, #T_603ef_row4_col17, #T_603ef_row4_col18, #T_603ef_row4_col19, #T_603ef_row5_col9, #T_603ef_row5_col17, #T_603ef_row5_col18, #T_603ef_row5_col19, #T_603ef_row6_col9, #T_603ef_row6_col17, #T_603ef_row6_col18, #T_603ef_row6_col19, #T_603ef_row7_col9, #T_603ef_row7_col17, #T_603ef_row7_col18, #T_603ef_row7_col19, #T_603ef_row8_col9, #T_603ef_row8_col17, #T_603ef_row8_col18, #T_603ef_row8_col19, #T_603ef_row9_col9, #T_603ef_row9_col17, #T_603ef_row9_col18, #T_603ef_row9_col19 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #9A8C98;
#   color: white;
# }
# #T_603ef_row2_col1, #T_603ef_row2_col10, #T_603ef_row4_col1, #T_603ef_row6_col10, #T_603ef_row7_col1, #T_603ef_row7_col10 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #588157;
#   color: white;
#   color: #888888;
#   font-style: italic;
# }
# </style>
# <table id="T_603ef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_603ef_level0_col0" class="col_heading level0 col0" >belongs_to_collection</th>
#       <th id="T_603ef_level0_col1" class="col_heading level0 col1" >budget</th>
#       <th id="T_603ef_level0_col2" class="col_heading level0 col2" >genres</th>
#       <th id="T_603ef_level0_col3" class="col_heading level0 col3" >id</th>
#       <th id="T_603ef_level0_col4" class="col_heading level0 col4" >original_language</th>
#       <th id="T_603ef_level0_col5" class="col_heading level0 col5" >original_title</th>
#       <th id="T_603ef_level0_col6" class="col_heading level0 col6" >popularity</th>
#       <th id="T_603ef_level0_col7" class="col_heading level0 col7" >producer_company</th>
#       <th id="T_603ef_level0_col8" class="col_heading level0 col8" >production_countries</th>
#       <th id="T_603ef_level0_col9" class="col_heading level0 col9" >release_date</th>
#       <th id="T_603ef_level0_col10" class="col_heading level0 col10" >revenue</th>
#       <th id="T_603ef_level0_col11" class="col_heading level0 col11" >runtime</th>
#       <th id="T_603ef_level0_col12" class="col_heading level0 col12" >spoken_languages</th>
#       <th id="T_603ef_level0_col13" class="col_heading level0 col13" >title</th>
#       <th id="T_603ef_level0_col14" class="col_heading level0 col14" >average_rating</th>
#       <th id="T_603ef_level0_col15" class="col_heading level0 col15" >total_votes</th>
#       <th id="T_603ef_level0_col16" class="col_heading level0 col16" >global_score</th>
#       <th id="T_603ef_level0_col17" class="col_heading level0 col17" >release_year</th>
#       <th id="T_603ef_level0_col18" class="col_heading level0 col18" >decade</th>
#       <th id="T_603ef_level0_col19" class="col_heading level0 col19" >age_years</th>
#       <th id="T_603ef_level0_col20" class="col_heading level0 col20" >votes_per_year</th>
#       <th id="T_603ef_level0_col21" class="col_heading level0 col21" >popularity_tier</th>
#     </tr>
#   </thead>

# %% [markdown]
# ---
# ## Checkpoint de Persistência: Separação entre Enriquecimento e Desnormalização
#
# O dataset é salvo neste ponto — após o enriquecimento de features e antes de qualquer operação de explosão de colunas — para preservar a estrutura **um-filme-por-linha**. Essa separação é uma decisão arquitetural deliberada: análises financeiras e de atributos agregados do filme (orçamento, receita) consomem este artefato; análises por gênero ou país consumirão versões explodidas derivadas dele, mantendo a rastreabilidade entre as camadas do pipeline.

# %%
# Salvando o DataFrame processado para a próxima etapa de análise
ds.save_dataset(
    df=df_movies, 
    pasta='../data/interim/movies',
    nome_arquivo='movies_enriched', 
    tipo_arquivo='parquet'
)
# Out:
# Sucesso! Ficheiro guardado em '..\data\interim\movies\movies_enriched.parquet'

# %% [markdown]
# ---
# ##  Modelagem Dimensional: Atomização de Listas Complexas
#
# O dataset enriquecido armazena informações cruciais (gêneros, países de produção e idiomas) no formato de listas dentro de uma única célula. Embora eficiente para armazenamento, essa estrutura **inviabiliza análises categóricas isoladas**. Para responder a perguntas de negócio como "qual país produz os filmes mais rentáveis?" ou "qual o ROI médio do gênero terror?", é imperativo normalizar essas variáveis para um modelo *one-to-many*.
#
# - **Decisão arquitetural (Prevenção de Produto Cartesiano):** Optou-se por **não** explodir múltiplas colunas no mesmo *dataframe*. Fazer isso geraria uma multiplicação exponencial das linhas (ex: Gênero $\times$ País $\times$ Idioma), o que corromperia gravemente o cálculo de métricas financeiras como `revenue` e `budget`. Em vez disso, adotamos a criação de **tabelas dimensão independentes** para cada categoria.
# - **Trade-off aceito:** O projeto passará a gerenciar múltiplos arquivos `.csv` (uma base principal estática e bases dimensionais explodidas) em detrimento de uma tabela única universal. Essa fragmentação intencional blinda a integridade estatística dos dados globais enquanto habilita mergulhos analíticos profundos em categorias específicas.
# ---

# %% [markdown]
# ### 1. Dimensão de Gêneros (`movies_genres`)
#
# Isolamento da variável `genres` para viabilizar análises de volume e performance financeira por categoria cinematográfica.
#
# * **Operação:** Fatiamento das listas e aplicação do `.explode()`.
# * **Validação:** Inspeção da nova granularidade (múltiplas linhas por filme) e integridade dos tipos.
# * **Persistência:** Exportação da tabela dimensão para `data/processed/movies_genres.csv`.

# %%
# Explodindo a coluna de gêneros para criar uma linha por gênero
df_genres_exploded = feat.explodir_dataset(df_movies, 'genres')

# %%
# Validação da granularidade atômica: uma linha por par filme-gênero
display(tb.estilizar_tabela(
    df=df_genres_exploded,
    colunas_selecionadas=['original_title', 'genres'],
    qtd_linhas=20,
    caption="DataFrame Movies Pós-Exploxão"
))
# Out:
# <style type="text/css">
# #T_7cf89 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_7cf89 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_7cf89 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_7cf89 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_7cf89 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_7cf89 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_7cf89_row0_col0, #T_7cf89_row1_col0, #T_7cf89_row2_col0, #T_7cf89_row3_col0, #T_7cf89_row4_col0, #T_7cf89_row5_col0, #T_7cf89_row6_col0, #T_7cf89_row7_col0, #T_7cf89_row8_col0, #T_7cf89_row9_col0, #T_7cf89_row10_col0, #T_7cf89_row11_col0, #T_7cf89_row12_col0, #T_7cf89_row13_col0, #T_7cf89_row14_col0, #T_7cf89_row15_col0, #T_7cf89_row16_col0, #T_7cf89_row17_col0, #T_7cf89_row18_col0, #T_7cf89_row19_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #2B2D42;
#   color: white;
# }
# #T_7cf89_row0_col1, #T_7cf89_row1_col1, #T_7cf89_row2_col1, #T_7cf89_row3_col1, #T_7cf89_row4_col1, #T_7cf89_row5_col1, #T_7cf89_row6_col1, #T_7cf89_row7_col1, #T_7cf89_row8_col1, #T_7cf89_row9_col1, #T_7cf89_row10_col1, #T_7cf89_row11_col1, #T_7cf89_row12_col1, #T_7cf89_row13_col1, #T_7cf89_row14_col1, #T_7cf89_row15_col1, #T_7cf89_row16_col1, #T_7cf89_row17_col1, #T_7cf89_row18_col1, #T_7cf89_row19_col1 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #6D597A;
#   color: white;
# }
# </style>
# <table id="T_7cf89">
#   <caption>DataFrame Movies Pós-Exploxão</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7cf89_level0_col0" class="col_heading level0 col0" >original_title</th>
#       <th id="T_7cf89_level0_col1" class="col_heading level0 col1" >genres</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7cf89_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7cf89_row0_col0" class="data row0 col0" >Toy Story</td>
#       <td id="T_7cf89_row0_col1" class="data row0 col1" >Animation</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7cf89_row1_col0" class="data row1 col0" >Toy Story</td>
#       <td id="T_7cf89_row1_col1" class="data row1 col1" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7cf89_row2_col0" class="data row2 col0" >Toy Story</td>
#       <td id="T_7cf89_row2_col1" class="data row2 col1" >Family</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7cf89_row3_col0" class="data row3 col0" >Jumanji</td>
#       <td id="T_7cf89_row3_col1" class="data row3 col1" >Adventure</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7cf89_row4_col0" class="data row4 col0" >Jumanji</td>
#       <td id="T_7cf89_row4_col1" class="data row4 col1" >Fantasy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7cf89_row5_col0" class="data row5 col0" >Jumanji</td>
#       <td id="T_7cf89_row5_col1" class="data row5 col1" >Family</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7cf89_row6_col0" class="data row6 col0" >Grumpier Old Men</td>
#       <td id="T_7cf89_row6_col1" class="data row6 col1" >Romance</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7cf89_row7_col0" class="data row7 col0" >Grumpier Old Men</td>
#       <td id="T_7cf89_row7_col1" class="data row7 col1" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7cf89_row8_col0" class="data row8 col0" >Waiting to Exhale</td>
#       <td id="T_7cf89_row8_col1" class="data row8 col1" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7cf89_row9_col0" class="data row9 col0" >Waiting to Exhale</td>
#       <td id="T_7cf89_row9_col1" class="data row9 col1" >Drama</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7cf89_row10_col0" class="data row10 col0" >Waiting to Exhale</td>
#       <td id="T_7cf89_row10_col1" class="data row10 col1" >Romance</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7cf89_row11_col0" class="data row11 col0" >Father of the Bride Part II</td>
#       <td id="T_7cf89_row11_col1" class="data row11 col1" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7cf89_row12_col0" class="data row12 col0" >Heat</td>
#       <td id="T_7cf89_row12_col1" class="data row12 col1" >Action</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7cf89_row13_col0" class="data row13 col0" >Heat</td>
#       <td id="T_7cf89_row13_col1" class="data row13 col1" >Crime</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7cf89_row14_col0" class="data row14 col0" >Heat</td>
#       <td id="T_7cf89_row14_col1" class="data row14 col1" >Drama</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7cf89_row15_col0" class="data row15 col0" >Heat</td>
#       <td id="T_7cf89_row15_col1" class="data row15 col1" >Thriller</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7cf89_row16_col0" class="data row16 col0" >Sabrina</td>
#       <td id="T_7cf89_row16_col1" class="data row16 col1" >Comedy</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7cf89_row17_col0" class="data row17 col0" >Sabrina</td>
#       <td id="T_7cf89_row17_col1" class="data row17 col1" >Romance</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7cf89_row18_col0" class="data row18 col0" >Tom and Huck</td>
#       <td id="T_7cf89_row18_col1" class="data row18 col1" >Action</td>
#     </tr>
#     <tr>
#       <th id="T_7cf89_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7cf89_row19_col0" class="data row19 col0" >Tom and Huck</td>
#       <td id="T_7cf89_row19_col1" class="data row19 col1" >Adventure</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Verificando o número de linhas após a explosão
display(f"Número de linhas após a explosão: {df_genres_exploded.shape[0]}")
# Out:
# 'Número de linhas após a explosão: 86933'

# %% [markdown]
# ### Salvando dados após a explosão da coluna `genres`

# %%
# Salvando o DataFrame explodido para análise de gêneros
ds.save_dataset(
    df=df_genres_exploded, 
    pasta='../data/processed/movies',
    nome_arquivo='movies_genres', 
    tipo_arquivo='parquet'
)
# Out:
# Sucesso! Ficheiro guardado em '..\data\processed\movies\movies_genres.parquet'

# %% [markdown]
# ### 2. Dimensão de Países de Produção (`movies_countries`)
#
# Extração da variável `production_countries` para viabilizar o mapeamento geográfico da indústria e análises comparativas de performance financeira por origem de produção — como a distinção entre Hollywood, Bollywood e cinematografias europeias.
#
# - **Motivação analítica:** A co-produção internacional é um fenômeno relevante no cinema moderno; a estrutura explodida permite quantificar com precisão a participação de cada país, inclusive em produções compartilhadas
# - **Persistência:** Exportação da tabela dimensão para `data/processed/movies_countries.csv`

# %%
# Explodindo a coluna de países para criar uma linha por país
df_countries_exploded = feat.explodir_dataset(df_movies, 'production_countries')

# %%
# Validação da granularidade atômica: uma linha por par filme-país
display(tb.estilizar_tabela(
    df=df_countries_exploded,
    colunas_selecionadas=['original_title', 'production_countries'],
    qtd_linhas=20,
    caption="DataFrame de Explosão Da coluna `production_countries` "
))
# Out:
# <style type="text/css">
# #T_d7113 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_d7113 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_d7113 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_d7113 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_d7113 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_d7113 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_d7113_row0_col0, #T_d7113_row1_col0, #T_d7113_row2_col0, #T_d7113_row3_col0, #T_d7113_row4_col0, #T_d7113_row5_col0, #T_d7113_row6_col0, #T_d7113_row7_col0, #T_d7113_row8_col0, #T_d7113_row9_col0, #T_d7113_row10_col0, #T_d7113_row11_col0, #T_d7113_row12_col0, #T_d7113_row13_col0, #T_d7113_row14_col0, #T_d7113_row15_col0, #T_d7113_row16_col0, #T_d7113_row17_col0, #T_d7113_row18_col0, #T_d7113_row19_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #2B2D42;
#   color: white;
# }
# #T_d7113_row0_col1, #T_d7113_row1_col1, #T_d7113_row2_col1, #T_d7113_row3_col1, #T_d7113_row4_col1, #T_d7113_row5_col1, #T_d7113_row6_col1, #T_d7113_row7_col1, #T_d7113_row8_col1, #T_d7113_row9_col1, #T_d7113_row10_col1, #T_d7113_row11_col1, #T_d7113_row12_col1, #T_d7113_row13_col1, #T_d7113_row14_col1, #T_d7113_row15_col1, #T_d7113_row16_col1, #T_d7113_row17_col1, #T_d7113_row18_col1, #T_d7113_row19_col1 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #3D5A80;
#   color: white;
# }
# </style>
# <table id="T_d7113">
#   <caption>DataFrame de Explosão Da coluna `production_countries` </caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d7113_level0_col0" class="col_heading level0 col0" >original_title</th>
#       <th id="T_d7113_level0_col1" class="col_heading level0 col1" >production_countries</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d7113_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d7113_row0_col0" class="data row0 col0" >Toy Story</td>
#       <td id="T_d7113_row0_col1" class="data row0 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d7113_row1_col0" class="data row1 col0" >Jumanji</td>
#       <td id="T_d7113_row1_col1" class="data row1 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d7113_row2_col0" class="data row2 col0" >Grumpier Old Men</td>
#       <td id="T_d7113_row2_col1" class="data row2 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d7113_row3_col0" class="data row3 col0" >Waiting to Exhale</td>
#       <td id="T_d7113_row3_col1" class="data row3 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d7113_row4_col0" class="data row4 col0" >Father of the Bride Part II</td>
#       <td id="T_d7113_row4_col1" class="data row4 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d7113_row5_col0" class="data row5 col0" >Heat</td>
#       <td id="T_d7113_row5_col1" class="data row5 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d7113_row6_col0" class="data row6 col0" >Sabrina</td>
#       <td id="T_d7113_row6_col1" class="data row6 col1" >Germany</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d7113_row7_col0" class="data row7 col0" >Sabrina</td>
#       <td id="T_d7113_row7_col1" class="data row7 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d7113_row8_col0" class="data row8 col0" >Tom and Huck</td>
#       <td id="T_d7113_row8_col1" class="data row8 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d7113_row9_col0" class="data row9 col0" >Sudden Death</td>
#       <td id="T_d7113_row9_col1" class="data row9 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d7113_row10_col0" class="data row10 col0" >GoldenEye</td>
#       <td id="T_d7113_row10_col1" class="data row10 col1" >United Kingdom</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d7113_row11_col0" class="data row11 col0" >GoldenEye</td>
#       <td id="T_d7113_row11_col1" class="data row11 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d7113_row12_col0" class="data row12 col0" >The American President</td>
#       <td id="T_d7113_row12_col1" class="data row12 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d7113_row13_col0" class="data row13 col0" >Dracula: Dead and Loving It</td>
#       <td id="T_d7113_row13_col1" class="data row13 col1" >France</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d7113_row14_col0" class="data row14 col0" >Dracula: Dead and Loving It</td>
#       <td id="T_d7113_row14_col1" class="data row14 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d7113_row15_col0" class="data row15 col0" >Balto</td>
#       <td id="T_d7113_row15_col1" class="data row15 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d7113_row16_col0" class="data row16 col0" >Nixon</td>
#       <td id="T_d7113_row16_col1" class="data row16 col1" >United States of America</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d7113_row17_col0" class="data row17 col0" >Cutthroat Island</td>
#       <td id="T_d7113_row17_col1" class="data row17 col1" >France</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d7113_row18_col0" class="data row18 col0" >Cutthroat Island</td>
#       <td id="T_d7113_row18_col1" class="data row18 col1" >Germany</td>
#     </tr>
#     <tr>
#       <th id="T_d7113_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d7113_row19_col0" class="data row19 col0" >Cutthroat Island</td>
#       <td id="T_d7113_row19_col1" class="data row19 col1" >Italy</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Verificando o número de linhas após a explosão
display(f"Número de linhas após a explosão: {df_countries_exploded.shape[0]}")
# Out:
# 'Número de linhas após a explosão: 50882'

# %% [markdown]
# ### Salvando dados após a explosão da coluna `production_countries`

# %%
# Salvando o DataFrame explodido para análise de países
ds.save_dataset(
    df=df_countries_exploded, 
    pasta='../data/processed/movies',
    nome_arquivo='movies_countries', 
    tipo_arquivo='parquet'
)
# Out:
# Sucesso! Ficheiro guardado em '..\data\processed\movies\movies_countries.parquet'

# %% [markdown]
# ### 3. Dimensão de Idiomas Falados (`movies_languages`)
#
# Separação da variável `spoken_languages` para habilitar análises de alcance geolinguístico e correlação entre diversidade de idiomas e performance de bilheteria internacional. Filmes multilíngues têm potencial de distribuição estruturalmente diferente dos produziods para mercados monolíngues.
#
# - **Motivação analítica:** O idioma é um proxy de mercado-alvo — identificar padrões entre o número de idiomas de um filme e sua receita global é uma hipótese central do projeto
# - **Persistência:** Exportação da tabela dimensão para `data/processed/movies_languages.csv`

# %%
# Explodindo a coluna de idiomas para criar uma linha por idioma
df_languages_exploded = feat.explodir_dataset(df_movies, 'spoken_languages')

# %%
# Validação da granularidade atômica: uma linha por par filme-idioma
display(tb.estilizar_tabela(
    df=df_languages_exploded,
    colunas_selecionadas=['original_title', 'spoken_languages'],
    qtd_linhas=20,
    caption="DataFrame de Explosão da Coluna ´spoken_languages`"
))
# Out:
# <style type="text/css">
# #T_26d8e th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_26d8e td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_26d8e caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_26d8e table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_26d8e th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_26d8e td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_26d8e_row0_col0, #T_26d8e_row1_col0, #T_26d8e_row2_col0, #T_26d8e_row3_col0, #T_26d8e_row4_col0, #T_26d8e_row5_col0, #T_26d8e_row6_col0, #T_26d8e_row7_col0, #T_26d8e_row8_col0, #T_26d8e_row9_col0, #T_26d8e_row10_col0, #T_26d8e_row11_col0, #T_26d8e_row12_col0, #T_26d8e_row13_col0, #T_26d8e_row14_col0, #T_26d8e_row15_col0, #T_26d8e_row16_col0, #T_26d8e_row17_col0, #T_26d8e_row18_col0, #T_26d8e_row19_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #2B2D42;
#   color: white;
# }
# #T_26d8e_row0_col1, #T_26d8e_row1_col1, #T_26d8e_row2_col1, #T_26d8e_row3_col1, #T_26d8e_row4_col1, #T_26d8e_row5_col1, #T_26d8e_row6_col1, #T_26d8e_row7_col1, #T_26d8e_row8_col1, #T_26d8e_row9_col1, #T_26d8e_row10_col1, #T_26d8e_row11_col1, #T_26d8e_row12_col1, #T_26d8e_row13_col1, #T_26d8e_row14_col1, #T_26d8e_row15_col1, #T_26d8e_row16_col1, #T_26d8e_row17_col1, #T_26d8e_row18_col1, #T_26d8e_row19_col1 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #3D5A80;
#   color: white;
# }
# </style>
# <table id="T_26d8e">
#   <caption>DataFrame de Explosão da Coluna ´spoken_languages`</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26d8e_level0_col0" class="col_heading level0 col0" >original_title</th>
#       <th id="T_26d8e_level0_col1" class="col_heading level0 col1" >spoken_languages</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26d8e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26d8e_row0_col0" class="data row0 col0" >Toy Story</td>
#       <td id="T_26d8e_row0_col1" class="data row0 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26d8e_row1_col0" class="data row1 col0" >Jumanji</td>
#       <td id="T_26d8e_row1_col1" class="data row1 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26d8e_row2_col0" class="data row2 col0" >Jumanji</td>
#       <td id="T_26d8e_row2_col1" class="data row2 col1" >Français</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26d8e_row3_col0" class="data row3 col0" >Grumpier Old Men</td>
#       <td id="T_26d8e_row3_col1" class="data row3 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_26d8e_row4_col0" class="data row4 col0" >Waiting to Exhale</td>
#       <td id="T_26d8e_row4_col1" class="data row4 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_26d8e_row5_col0" class="data row5 col0" >Father of the Bride Part II</td>
#       <td id="T_26d8e_row5_col1" class="data row5 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_26d8e_row6_col0" class="data row6 col0" >Heat</td>
#       <td id="T_26d8e_row6_col1" class="data row6 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_26d8e_row7_col0" class="data row7 col0" >Heat</td>
#       <td id="T_26d8e_row7_col1" class="data row7 col1" >Español</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_26d8e_row8_col0" class="data row8 col0" >Sabrina</td>
#       <td id="T_26d8e_row8_col1" class="data row8 col1" >Français</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_26d8e_row9_col0" class="data row9 col0" >Sabrina</td>
#       <td id="T_26d8e_row9_col1" class="data row9 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_26d8e_row10_col0" class="data row10 col0" >Tom and Huck</td>
#       <td id="T_26d8e_row10_col1" class="data row10 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_26d8e_row11_col0" class="data row11 col0" >Tom and Huck</td>
#       <td id="T_26d8e_row11_col1" class="data row11 col1" >Deutsch</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_26d8e_row12_col0" class="data row12 col0" >Sudden Death</td>
#       <td id="T_26d8e_row12_col1" class="data row12 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_26d8e_row13_col0" class="data row13 col0" >GoldenEye</td>
#       <td id="T_26d8e_row13_col1" class="data row13 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_26d8e_row14_col0" class="data row14 col0" >GoldenEye</td>
#       <td id="T_26d8e_row14_col1" class="data row14 col1" >Pусский</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_26d8e_row15_col0" class="data row15 col0" >GoldenEye</td>
#       <td id="T_26d8e_row15_col1" class="data row15 col1" >Español</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_26d8e_row16_col0" class="data row16 col0" >The American President</td>
#       <td id="T_26d8e_row16_col1" class="data row16 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_26d8e_row17_col0" class="data row17 col0" >Dracula: Dead and Loving It</td>
#       <td id="T_26d8e_row17_col1" class="data row17 col1" >English</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_26d8e_row18_col0" class="data row18 col0" >Dracula: Dead and Loving It</td>
#       <td id="T_26d8e_row18_col1" class="data row18 col1" >Deutsch</td>
#     </tr>
#     <tr>
#       <th id="T_26d8e_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_26d8e_row19_col0" class="data row19 col0" >Balto</td>
#       <td id="T_26d8e_row19_col1" class="data row19 col1" >English</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Verificando o número de linhas após a explosão
display(f"Número de linhas após a explosão: {df_languages_exploded.shape[0]}")
# Out:
# 'Número de linhas após a explosão: 52356'

# %% [markdown]
# ### Salvando dados após a explosão da coluna `spoken_languages`

# %%
# Salvando o DataFrame explodido para análise de idiomas
ds.save_dataset(
    df=df_languages_exploded, 
    pasta='../data/processed/movies',
    nome_arquivo='movies_languages', 
    tipo_arquivo='parquet'
)
# Out:
# Sucesso! Ficheiro guardado em '..\data\processed\movies\movies_languages.parquet'

# %% [markdown]
# ### 4. Dimensão de Produtoras (`movies_companies`)
#
# Separação da variável `production_companies` para habilitar análises de *market share*, poder de distribuição e correlação entre o selo do estúdio e o sucesso financeiro (bilheteria e ROI). Obras financiadas por grandes conglomerados da indústria (*Majors*) apresentam comportamentos de risco e escalabilidade estruturalmente diferentes de produções independentes.
#
# - **Motivação analítica:** O estúdio produtor é um forte indicativo da capacidade de investimento e alcance de marketing. Identificar quais empresas dominam gêneros específicos, possuem as maiores margens de lucro ou concentram o controle das grandes franquias é um dos pilares de inteligência de negócio deste projeto.
# - **Persistência:** Exportação da tabela dimensão para `data/processed/movies_companies.csv`.

# %%
# Explodindo a coluna de produtoras para criar uma linha por produtora
df_company_exploded = feat.explodir_dataset(df_movies, 'producer_company')

# %%
# Validação da granularidade atômica: uma linha por par filme-produtora
display(tb.estilizar_tabela(
    df=df_company_exploded,
    colunas_selecionadas=['original_title', 'producer_company'],
    qtd_linhas=20,
    caption="DtaFrame de Explosão da Coluna `producer_company`"
))
# Out:
# <style type="text/css">
# #T_315d1 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_315d1 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_315d1 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_315d1 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_315d1 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_315d1 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_315d1_row0_col0, #T_315d1_row1_col0, #T_315d1_row2_col0, #T_315d1_row3_col0, #T_315d1_row4_col0, #T_315d1_row5_col0, #T_315d1_row6_col0, #T_315d1_row7_col0, #T_315d1_row8_col0, #T_315d1_row9_col0, #T_315d1_row10_col0, #T_315d1_row11_col0, #T_315d1_row12_col0, #T_315d1_row13_col0, #T_315d1_row14_col0, #T_315d1_row15_col0, #T_315d1_row16_col0, #T_315d1_row17_col0, #T_315d1_row18_col0, #T_315d1_row19_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #2B2D42;
#   color: white;
# }
# #T_315d1_row0_col1, #T_315d1_row1_col1, #T_315d1_row2_col1, #T_315d1_row3_col1, #T_315d1_row4_col1, #T_315d1_row5_col1, #T_315d1_row6_col1, #T_315d1_row7_col1, #T_315d1_row8_col1, #T_315d1_row9_col1, #T_315d1_row10_col1, #T_315d1_row11_col1, #T_315d1_row12_col1, #T_315d1_row13_col1, #T_315d1_row14_col1, #T_315d1_row15_col1, #T_315d1_row16_col1, #T_315d1_row17_col1, #T_315d1_row18_col1, #T_315d1_row19_col1 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #4A4E69;
#   color: white;
# }
# </style>
# <table id="T_315d1">
#   <caption>DtaFrame de Explosão da Coluna `producer_company`</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_315d1_level0_col0" class="col_heading level0 col0" >original_title</th>
#       <th id="T_315d1_level0_col1" class="col_heading level0 col1" >producer_company</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_315d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_315d1_row0_col0" class="data row0 col0" >Toy Story</td>
#       <td id="T_315d1_row0_col1" class="data row0 col1" >Pixar Animation Studios</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_315d1_row1_col0" class="data row1 col0" >Jumanji</td>
#       <td id="T_315d1_row1_col1" class="data row1 col1" >TriStar Pictures</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_315d1_row2_col0" class="data row2 col0" >Jumanji</td>
#       <td id="T_315d1_row2_col1" class="data row2 col1" >Teitler Film</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_315d1_row3_col0" class="data row3 col0" >Jumanji</td>
#       <td id="T_315d1_row3_col1" class="data row3 col1" >Interscope Communications</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_315d1_row4_col0" class="data row4 col0" >Grumpier Old Men</td>
#       <td id="T_315d1_row4_col1" class="data row4 col1" >Warner Bros.</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_315d1_row5_col0" class="data row5 col0" >Grumpier Old Men</td>
#       <td id="T_315d1_row5_col1" class="data row5 col1" >Lancaster Gate</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_315d1_row6_col0" class="data row6 col0" >Waiting to Exhale</td>
#       <td id="T_315d1_row6_col1" class="data row6 col1" >Twentieth Century Fox Film Corporation</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_315d1_row7_col0" class="data row7 col0" >Father of the Bride Part II</td>
#       <td id="T_315d1_row7_col1" class="data row7 col1" >Sandollar Productions</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_315d1_row8_col0" class="data row8 col0" >Father of the Bride Part II</td>
#       <td id="T_315d1_row8_col1" class="data row8 col1" >Touchstone Pictures</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_315d1_row9_col0" class="data row9 col0" >Heat</td>
#       <td id="T_315d1_row9_col1" class="data row9 col1" >Regency Enterprises</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_315d1_row10_col0" class="data row10 col0" >Heat</td>
#       <td id="T_315d1_row10_col1" class="data row10 col1" >Forward Pass</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_315d1_row11_col0" class="data row11 col0" >Heat</td>
#       <td id="T_315d1_row11_col1" class="data row11 col1" >Warner Bros.</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_315d1_row12_col0" class="data row12 col0" >Sabrina</td>
#       <td id="T_315d1_row12_col1" class="data row12 col1" >Paramount Pictures</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_315d1_row13_col0" class="data row13 col0" >Sabrina</td>
#       <td id="T_315d1_row13_col1" class="data row13 col1" >Scott Rudin Productions</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_315d1_row14_col0" class="data row14 col0" >Sabrina</td>
#       <td id="T_315d1_row14_col1" class="data row14 col1" >Mirage Enterprises</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_315d1_row15_col0" class="data row15 col0" >Sabrina</td>
#       <td id="T_315d1_row15_col1" class="data row15 col1" >Sandollar Productions</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_315d1_row16_col0" class="data row16 col0" >Sabrina</td>
#       <td id="T_315d1_row16_col1" class="data row16 col1" >Constellation Entertainment</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_315d1_row17_col0" class="data row17 col0" >Sabrina</td>
#       <td id="T_315d1_row17_col1" class="data row17 col1" >Worldwide</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_315d1_row18_col0" class="data row18 col0" >Sabrina</td>
#       <td id="T_315d1_row18_col1" class="data row18 col1" >Mont Blanc Entertainment GmbH</td>
#     </tr>
#     <tr>
#       <th id="T_315d1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_315d1_row19_col0" class="data row19 col0" >Tom and Huck</td>
#       <td id="T_315d1_row19_col1" class="data row19 col1" >Walt Disney Pictures</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Verificando o número de linhas após a explosão
display(f"Número de linhas após a explosão: {df_company_exploded.shape[0]}")
# Out:
# 'Número de linhas após a explosão: 77006'

# %% [markdown]
# ### Salvando dados após a explosão da coluna `producer_company`

# %%
# Salvando o DataFrame explodido para análise de produtoras
ds.save_dataset(
    df=df_company_exploded, 
    pasta='../data/processed/movies',
    nome_arquivo='movies_company', 
    tipo_arquivo='parquet'
)
# Out:
# Sucesso! Ficheiro guardado em '..\data\processed\movies\movies_company.parquet'

# %% [markdown]
# ---
# ## Conclusão da Engenharia de Features
#
# Nesta etapa, o dataset previamente limpo foi transformado e modelado para suportar consultas analíticas avançadas e extração de *insights* precisos. As principais refatorações incluíram:
#
# * **Correção de Franquias (Regra de Pareto):** A coluna `belongs_to_collection` foi enriquecida via mapeamento explícito das maiores franquias do cinema, corrigindo ausências sistemáticas do dataset original. A regra preserva vínculos já existentes e aplica correções apenas onde o campo estava ausente — garantindo rastreabilidade e reversibilidade da intervenção.
# * **Deserialização de Colunas JSON:** Colunas armazenadas como strings JSON (`genres`, `production_countries`, `spoken_languages`, `producer_company`) foram convertidas para listas Python nativas, tornando seus valores acessíveis para operações analíticas.
# * **Atomização Categórica (Explode):** Quatro dimensões analíticas foram fatiadas e desmembradas em tabelas independentes, alterando a granularidade do dataset para relações N:M e viabilizando análises isoladas sem mascaramento de dados agrupados.
#
# **Exportação Estratégica:**
# O ecossistema analítico foi exportado com sucesso em quatro artefatos independentes:
#
# | Artefato | Granularidade | Finalidade |
# |---|---|---|
# | `movies_enriched` | 1 linha por filme | Análises financeiras, ROI, comparativo franquia vs. independente |
# | `movies_genres` | 1 linha por filme × gênero | Performance e volume por categoria cinematográfica |
# | `movies_countries` | 1 linha por filme × país | Mapeamento geográfico da indústria |
# | `movies_languages` | 1 linha por filme × idioma | Alcance geolinguístico e bilheteria global |
# | `movies_company` | 1 linha por filme × produtora | Market share e poder de distribuição por estúdio |
#
# <br>
#
# > **Nota Arquitetural:** O projeto adota uma abordagem de *Multi-Dataset*. O arquivo `movies_enriched` é a fonte de verdade para métricas de filme (budget, revenue, is_franchise) — evitando duplicação de valores financeiros. As tabelas dimensão são consumidas via merge seletivo, conforme a pergunta de negócio a ser respondida.
#
# **Próximo Passo:**
# Com as bases prontas e a arquitetura definida, o projeto avança para a **Análise Exploratória de Dados (EDA)** para investigar os direcionadores de bilheteria, ROI e recepção do público no mercado cinematográfico.
#
# ---
