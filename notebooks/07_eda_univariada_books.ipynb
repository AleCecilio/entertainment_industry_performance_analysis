# %% [markdown]
# #  Análise Exploratória de Dados - Análise Univariada: Goodreads Dataset

# %%
# Configuração do Jupyter (Autoreload)
# %load_ext autoreload
# %autoreload 2

# Configuração de Caminho (Path Setup)
import sys
import os

# Adiciona a pasta raiz do projeto (..) ao sistema para liberar os imports locais
sys.path.append(os.path.abspath(os.path.join('..')))


# Importação de Bibliotecas e Módulos
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Nossos módulos customizados da pasta src/
import src.io.data_loader as dl
import src.utils.data_quality as dq
import src.utils.metrics as mt
import src.view.plots as graf
import src.view.tables as tb

# %% [markdown]
# ---
#
# ## Carregando Dados

# %%
caminho = '../data/interim/books/goodreads_books_enriched.parquet'
df_books = dl.load_data(file_path=caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (10897, 18)

# %% [markdown]
# ---
# ## Colunas do DataFrame

# %%
df_colunas = pd.DataFrame({
    "coluna": df_books.columns,
    "dtype_pandas": df_books.dtypes.values,
    "tipo_real": [
        df_books[col].map(type)[0].__name__
        if not df_books[col].dropna().empty else None
        for col in df_books.columns
    ]
})

display(tb.estilizar_tabela(
    df=df_colunas,
    caption="Colunas do dataframe"
))
# Out:
# <style type="text/css">
# #T_ca42c th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_ca42c td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_ca42c caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_ca42c table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_ca42c th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_ca42c td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_ca42c_row0_col0, #T_ca42c_row0_col1, #T_ca42c_row0_col2, #T_ca42c_row1_col0, #T_ca42c_row1_col1, #T_ca42c_row1_col2, #T_ca42c_row2_col0, #T_ca42c_row2_col1, #T_ca42c_row2_col2, #T_ca42c_row3_col0, #T_ca42c_row3_col1, #T_ca42c_row3_col2, #T_ca42c_row4_col0, #T_ca42c_row4_col1, #T_ca42c_row4_col2, #T_ca42c_row5_col0, #T_ca42c_row5_col1, #T_ca42c_row5_col2, #T_ca42c_row6_col0, #T_ca42c_row6_col1, #T_ca42c_row6_col2, #T_ca42c_row7_col0, #T_ca42c_row7_col1, #T_ca42c_row7_col2, #T_ca42c_row8_col0, #T_ca42c_row8_col1, #T_ca42c_row8_col2, #T_ca42c_row9_col0, #T_ca42c_row9_col1, #T_ca42c_row9_col2, #T_ca42c_row10_col0, #T_ca42c_row10_col1, #T_ca42c_row10_col2, #T_ca42c_row11_col0, #T_ca42c_row11_col1, #T_ca42c_row11_col2, #T_ca42c_row12_col0, #T_ca42c_row12_col1, #T_ca42c_row12_col2, #T_ca42c_row13_col0, #T_ca42c_row13_col1, #T_ca42c_row13_col2, #T_ca42c_row14_col0, #T_ca42c_row14_col1, #T_ca42c_row14_col2, #T_ca42c_row15_col0, #T_ca42c_row15_col1, #T_ca42c_row15_col2, #T_ca42c_row16_col0, #T_ca42c_row16_col1, #T_ca42c_row16_col2, #T_ca42c_row17_col0, #T_ca42c_row17_col1, #T_ca42c_row17_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_ca42c">
#   <caption>Colunas do dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca42c_level0_col0" class="col_heading level0 col0" >coluna</th>
#       <th id="T_ca42c_level0_col1" class="col_heading level0 col1" >dtype_pandas</th>
#       <th id="T_ca42c_level0_col2" class="col_heading level0 col2" >tipo_real</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca42c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca42c_row0_col0" class="data row0 col0" >book_id</td>
#       <td id="T_ca42c_row0_col1" class="data row0 col1" >int64</td>
#       <td id="T_ca42c_row0_col2" class="data row0 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca42c_row1_col0" class="data row1 col0" >title</td>
#       <td id="T_ca42c_row1_col1" class="data row1 col1" >object</td>
#       <td id="T_ca42c_row1_col2" class="data row1 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca42c_row2_col0" class="data row2 col0" >author</td>
#       <td id="T_ca42c_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_ca42c_row2_col2" class="data row2 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca42c_row3_col0" class="data row3 col0" >average_rating</td>
#       <td id="T_ca42c_row3_col1" class="data row3 col1" >float64</td>
#       <td id="T_ca42c_row3_col2" class="data row3 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca42c_row4_col0" class="data row4 col0" >isbn</td>
#       <td id="T_ca42c_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_ca42c_row4_col2" class="data row4 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca42c_row5_col0" class="data row5 col0" >original_language</td>
#       <td id="T_ca42c_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_ca42c_row5_col2" class="data row5 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca42c_row6_col0" class="data row6 col0" >num_pages</td>
#       <td id="T_ca42c_row6_col1" class="data row6 col1" >int64</td>
#       <td id="T_ca42c_row6_col2" class="data row6 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ca42c_row7_col0" class="data row7 col0" >total_votes</td>
#       <td id="T_ca42c_row7_col1" class="data row7 col1" >int64</td>
#       <td id="T_ca42c_row7_col2" class="data row7 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ca42c_row8_col0" class="data row8 col0" >text_reviews_count</td>
#       <td id="T_ca42c_row8_col1" class="data row8 col1" >int64</td>
#       <td id="T_ca42c_row8_col2" class="data row8 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ca42c_row9_col0" class="data row9 col0" >release_date</td>
#       <td id="T_ca42c_row9_col1" class="data row9 col1" >datetime64[ns]</td>
#       <td id="T_ca42c_row9_col2" class="data row9 col2" >Timestamp</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ca42c_row10_col0" class="data row10 col0" >producer_company</td>
#       <td id="T_ca42c_row10_col1" class="data row10 col1" >object</td>
#       <td id="T_ca42c_row10_col2" class="data row10 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ca42c_row11_col0" class="data row11 col0" >genres</td>
#       <td id="T_ca42c_row11_col1" class="data row11 col1" >object</td>
#       <td id="T_ca42c_row11_col2" class="data row11 col2" >ndarray</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ca42c_row12_col0" class="data row12 col0" >global_score</td>
#       <td id="T_ca42c_row12_col1" class="data row12 col1" >float64</td>
#       <td id="T_ca42c_row12_col2" class="data row12 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ca42c_row13_col0" class="data row13 col0" >release_year</td>
#       <td id="T_ca42c_row13_col1" class="data row13 col1" >int32</td>
#       <td id="T_ca42c_row13_col2" class="data row13 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ca42c_row14_col0" class="data row14 col0" >decade</td>
#       <td id="T_ca42c_row14_col1" class="data row14 col1" >int32</td>
#       <td id="T_ca42c_row14_col2" class="data row14 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ca42c_row15_col0" class="data row15 col0" >age_years</td>
#       <td id="T_ca42c_row15_col1" class="data row15 col1" >int32</td>
#       <td id="T_ca42c_row15_col2" class="data row15 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ca42c_row16_col0" class="data row16 col0" >votes_per_year</td>
#       <td id="T_ca42c_row16_col1" class="data row16 col1" >float64</td>
#       <td id="T_ca42c_row16_col2" class="data row16 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_ca42c_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ca42c_row17_col0" class="data row17 col0" >popularity_tier</td>
#       <td id="T_ca42c_row17_col1" class="data row17 col1" >object</td>
#       <td id="T_ca42c_row17_col2" class="data row17 col2" >str</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Colunas Numéricas

# %%
# Análisado Colunas Numéricas Individualmente
resumo_cols_numericas = mt.numeric_summary(df_books)
display(
    tb.estilizar_tabela(
        resumo_cols_numericas,
        caption="Relatorio colunas numéricas"
    ).format("{:,.2f}")
)
# Out:
# <style type="text/css">
# #T_5612f th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_5612f td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_5612f caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_5612f table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_5612f th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_5612f td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_5612f_row0_col0, #T_5612f_row0_col1, #T_5612f_row0_col2, #T_5612f_row0_col3, #T_5612f_row0_col4, #T_5612f_row0_col5, #T_5612f_row0_col6, #T_5612f_row0_col7, #T_5612f_row0_col8, #T_5612f_row0_col9, #T_5612f_row1_col0, #T_5612f_row1_col1, #T_5612f_row1_col2, #T_5612f_row1_col3, #T_5612f_row1_col4, #T_5612f_row1_col5, #T_5612f_row1_col6, #T_5612f_row1_col7, #T_5612f_row1_col8, #T_5612f_row1_col9, #T_5612f_row2_col0, #T_5612f_row2_col1, #T_5612f_row2_col2, #T_5612f_row2_col3, #T_5612f_row2_col4, #T_5612f_row2_col5, #T_5612f_row2_col6, #T_5612f_row2_col7, #T_5612f_row2_col8, #T_5612f_row2_col9, #T_5612f_row3_col0, #T_5612f_row3_col1, #T_5612f_row3_col2, #T_5612f_row3_col3, #T_5612f_row3_col4, #T_5612f_row3_col5, #T_5612f_row3_col6, #T_5612f_row3_col7, #T_5612f_row3_col8, #T_5612f_row3_col9, #T_5612f_row4_col0, #T_5612f_row4_col1, #T_5612f_row4_col2, #T_5612f_row4_col3, #T_5612f_row4_col4, #T_5612f_row4_col5, #T_5612f_row4_col6, #T_5612f_row4_col7, #T_5612f_row4_col8, #T_5612f_row4_col9, #T_5612f_row5_col0, #T_5612f_row5_col1, #T_5612f_row5_col2, #T_5612f_row5_col3, #T_5612f_row5_col4, #T_5612f_row5_col5, #T_5612f_row5_col6, #T_5612f_row5_col7, #T_5612f_row5_col8, #T_5612f_row5_col9, #T_5612f_row6_col0, #T_5612f_row6_col1, #T_5612f_row6_col2, #T_5612f_row6_col3, #T_5612f_row6_col4, #T_5612f_row6_col5, #T_5612f_row6_col6, #T_5612f_row6_col7, #T_5612f_row6_col8, #T_5612f_row6_col9, #T_5612f_row7_col0, #T_5612f_row7_col1, #T_5612f_row7_col2, #T_5612f_row7_col3, #T_5612f_row7_col4, #T_5612f_row7_col5, #T_5612f_row7_col6, #T_5612f_row7_col7, #T_5612f_row7_col8, #T_5612f_row7_col9, #T_5612f_row8_col0, #T_5612f_row8_col1, #T_5612f_row8_col2, #T_5612f_row8_col3, #T_5612f_row8_col4, #T_5612f_row8_col5, #T_5612f_row8_col6, #T_5612f_row8_col7, #T_5612f_row8_col8, #T_5612f_row8_col9, #T_5612f_row9_col0, #T_5612f_row9_col1, #T_5612f_row9_col2, #T_5612f_row9_col3, #T_5612f_row9_col4, #T_5612f_row9_col5, #T_5612f_row9_col6, #T_5612f_row9_col7, #T_5612f_row9_col8, #T_5612f_row9_col9 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_5612f">
#   <caption>Relatorio colunas numéricas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5612f_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_5612f_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_5612f_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_5612f_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_5612f_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_5612f_level0_col5" class="col_heading level0 col5" >iqr</th>
#       <th id="T_5612f_level0_col6" class="col_heading level0 col6" >skew</th>
#       <th id="T_5612f_level0_col7" class="col_heading level0 col7" >kurtosis</th>
#       <th id="T_5612f_level0_col8" class="col_heading level0 col8" >outlier_count</th>
#       <th id="T_5612f_level0_col9" class="col_heading level0 col9" >outlier_%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5612f_level0_row0" class="row_heading level0 row0" >book_id</th>
#       <td id="T_5612f_row0_col0" class="data row0 col0" >21,279.17</td>
#       <td id="T_5612f_row0_col1" class="data row0 col1" >20,182.00</td>
#       <td id="T_5612f_row0_col2" class="data row0 col2" >13,093.41</td>
#       <td id="T_5612f_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_5612f_row0_col4" class="data row0 col4" >45,641.00</td>
#       <td id="T_5612f_row0_col5" class="data row0 col5" >21,840.00</td>
#       <td id="T_5612f_row0_col6" class="data row0 col6" >0.15</td>
#       <td id="T_5612f_row0_col7" class="data row0 col7" >-1.15</td>
#       <td id="T_5612f_row0_col8" class="data row0 col8" >0.00</td>
#       <td id="T_5612f_row0_col9" class="data row0 col9" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_5612f_level0_row1" class="row_heading level0 row1" >total_votes</th>
#       <td id="T_5612f_row1_col0" class="data row1 col0" >18,311.30</td>
#       <td id="T_5612f_row1_col1" class="data row1 col1" >797.00</td>
#       <td id="T_5612f_row1_col2" class="data row1 col2" >113,630.33</td>
#       <td id="T_5612f_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_5612f_row1_col4" class="data row1 col4" >4,597,666.00</td>
#       <td id="T_5612f_row1_col5" class="data row1 col5" >5,103.00</td>
#       <td id="T_5612f_row1_col6" class="data row1 col6" >17.52</td>
#       <td id="T_5612f_row1_col7" class="data row1 col7" >433.46</td>
#       <td id="T_5612f_row1_col8" class="data row1 col8" >1,671.00</td>
#       <td id="T_5612f_row1_col9" class="data row1 col9" >15.33</td>
#     </tr>
#     <tr>
#       <th id="T_5612f_level0_row2" class="row_heading level0 row2" >release_year</th>
#       <td id="T_5612f_row2_col0" class="data row2 col0" >2,000.20</td>
#       <td id="T_5612f_row2_col1" class="data row2 col1" >2,003.00</td>
#       <td id="T_5612f_row2_col2" class="data row2 col2" >8.18</td>
#       <td id="T_5612f_row2_col3" class="data row2 col3" >1,900.00</td>
#       <td id="T_5612f_row2_col4" class="data row2 col4" >2,020.00</td>
#       <td id="T_5612f_row2_col5" class="data row2 col5" >7.00</td>
#       <td id="T_5612f_row2_col6" class="data row2 col6" >-2.99</td>
#       <td id="T_5612f_row2_col7" class="data row2 col7" >16.24</td>
#       <td id="T_5612f_row2_col8" class="data row2 col8" >754.00</td>
#       <td id="T_5612f_row2_col9" class="data row2 col9" >6.92</td>
#     </tr>
#     <tr>
#       <th id="T_5612f_level0_row3" class="row_heading level0 row3" >decade</th>
#       <td id="T_5612f_row3_col0" class="data row3 col0" >1,995.73</td>
#       <td id="T_5612f_row3_col1" class="data row3 col1" >2,000.00</td>
#       <td id="T_5612f_row3_col2" class="data row3 col2" >8.41</td>
#       <td id="T_5612f_row3_col3" class="data row3 col3" >1,900.00</td>
#       <td id="T_5612f_row3_col4" class="data row3 col4" >2,020.00</td>
#       <td id="T_5612f_row3_col5" class="data row3 col5" >10.00</td>
#       <td id="T_5612f_row3_col6" class="data row3 col6" >-2.86</td>
#       <td id="T_5612f_row3_col7" class="data row3 col7" >14.39</td>
#       <td id="T_5612f_row3_col8" class="data row3 col8" >317.00</td>
#       <td id="T_5612f_row3_col9" class="data row3 col9" >2.91</td>
#     </tr>
#     <tr>
#       <th id="T_5612f_level0_row4" class="row_heading level0 row4" >votes_per_year</th>
#       <td id="T_5612f_row4_col0" class="data row4 col0" >805.71</td>
#       <td id="T_5612f_row4_col1" class="data row4 col1" >32.29</td>
#       <td id="T_5612f_row4_col2" class="data row4 col2" >5,147.30</td>
#       <td id="T_5612f_row4_col3" class="data row4 col3" >0.02</td>
#       <td id="T_5612f_row4_col4" class="data row4 col4" >229,883.30</td>
#       <td id="T_5612f_row4_col5" class="data row4 col5" >210.14</td>
#       <td id="T_5612f_row4_col6" class="data row4 col6" >19.00</td>
#       <td id="T_5612f_row4_col7" class="data ro

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='global_score', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='nota_100'
)

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='total_votes', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='contagem'
)

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='text_reviews_count', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='contagem'
)

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='num_pages', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True
)

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='average_rating', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='nota_5'
)

# %% [markdown]
# #### Colunas Numéricas Relacionadas ao Tempo

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_books, 
    coluna='votes_per_year', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='contagem'
)

# %%
graf.grafico_top_tempo(df_books, coluna='release_year')

# %%
graf.grafico_top_tempo(df_books, coluna='decade')

# %%
graf.grafico_top_tempo(df_books, coluna='age_years')

# %% [markdown]
# ### Colunas Catategóricas

# %%
# Análisado Colunas Categóricas Individualmente
resumo_cols_categoricas = mt.categorical_summary(df_books)
display(
    tb.estilizar_relatorio_categorias(
        resumo_cols_categoricas,
        caption="Relatorio colunas categoricas"
    )
)
# Out:
# <style type="text/css">
# #T_8a855 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_8a855 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_8a855 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_8a855 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_8a855 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 400px;
# }
# #T_8a855 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 400px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_8a855_row0_col0, #T_8a855_row0_col1, #T_8a855_row0_col2, #T_8a855_row1_col0, #T_8a855_row1_col1, #T_8a855_row1_col2, #T_8a855_row2_col0, #T_8a855_row2_col1, #T_8a855_row2_col2, #T_8a855_row3_col0, #T_8a855_row3_col1, #T_8a855_row3_col2, #T_8a855_row4_col0, #T_8a855_row4_col1, #T_8a855_row4_col2, #T_8a855_row5_col0, #T_8a855_row5_col1, #T_8a855_row5_col2, #T_8a855_row6_col0, #T_8a855_row6_col1, #T_8a855_row6_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_8a855_row0_col3, #T_8a855_row0_col4, #T_8a855_row1_col3, #T_8a855_row1_col4, #T_8a855_row2_col3, #T_8a855_row2_col4, #T_8a855_row3_col3, #T_8a855_row3_col4, #T_8a855_row4_col3, #T_8a855_row4_col4, #T_8a855_row5_col3, #T_8a855_row5_col4, #T_8a855_row6_col3, #T_8a855_row6_col4 {
#   white-space: pre-wrap;
#   text-align: left;
#   text-align: left;
# }
# </style>
# <table id="T_8a855">
#   <caption>Relatorio colunas categoricas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8a855_level0_col0" class="col_heading level0 col0" >total_valid_rows</th>
#       <th id="T_8a855_level0_col1" class="col_heading level0 col1" >unique_categories</th>
#       <th id="T_8a855_level0_col2" class="col_heading level0 col2" >entropy_norm</th>
#       <th id="T_8a855_level0_col3" class="col_heading level0 col3" >top_values_count</th>
#       <th id="T_8a855_level0_col4" class="col_heading level0 col4" >top_values_pct_%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a855_level0_row0" class="row_heading level0 row0" >isbn</th>
#       <td id="T_8a855_row0_col0" class="data row0 col0" >10897</td>
#       <td id="T_8a855_row0_col1" class="data row0 col1" >10897</td>
#       <td id="T_8a855_row0_col2" class="data row0 col2" >1.000000</td>
#       <td id="T_8a855_row0_col3" class="data row0 col3" >• 0439785960 (1)<br>• 0439358078 (1)<br>• 0439554896 (1)<br>• 043965548X (1)<br>• 0439682584 (1)<br>• 0976540606 (1)<br>• 0439827604 (1)<br>• 0517226952 (1)<br>• 0345453743 (1)<br>• 1400052920 (1)</td>
#       <td id="T_8a855_row0_col4" class="data row0 col4" >• 0439785960 (0.0%)<br>• 0439358078 (0.0%)<br>• 0439554896 (0.0%)<br>• 043965548X (0.0%)<br>• 0439682584 (0.0%)<br>• 0976540606 (0.0%)<br>• 0439827604 (0.0%)<br>• 0517226952 (0.0%)<br>• 0345453743 (0.0%)<br>• 1400052920 (0.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row1" class="row_heading level0 row1" >popularity_tier</th>
#       <td id="T_8a855_row1_col0" class="data row1 col0" >10897</td>
#       <td id="T_8a855_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_8a855_row1_col2" class="data row1 col2" >0.999100</td>
#       <td id="T_8a855_row1_col3" class="data row1 col3" >• Mainstream Hit (2894)<br>• Nicho (2806)<br>• Hidden Gem / Cult (2638)<br>• Mass Appeal (2559)</td>
#       <td id="T_8a855_row1_col4" class="data row1 col4" >• Mainstream Hit (26.6%)<br>• Nicho (25.8%)<br>• Hidden Gem / Cult (24.2%)<br>• Mass Appeal (23.5%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row2" class="row_heading level0 row2" >title</th>
#       <td id="T_8a855_row2_col0" class="data row2 col0" >10897</td>
#       <td id="T_8a855_row2_col1" class="data row2 col1" >10142</td>
#       <td id="T_8a855_row2_col2" class="data row2 col2" >0.995200</td>
#       <td id="T_8a855_row2_col3" class="data row2 col3" >• The Iliad (9)<br>• The Brothers Karamazov (9)<br>• The Odyssey (8)<br>• Anna Karenina (8)<br>• A Midsummer Night's Dream (7)<br>• 'Salem's Lot (7)<br>• Gulliver's Travels (7)<br>• The Picture of Dorian Gray (7)<br>• Sense and Sensibility (6)<br>• Jane Eyre (6)</td>
#       <td id="T_8a855_row2_col4" class="data row2 col4" >• The Iliad (0.1%)<br>• The Brothers Karamazov (0.1%)<br>• The Odyssey (0.1%)<br>• Anna Karenina (0.1%)<br>• A Midsummer Night's Dream (0.1%)<br>• 'Salem's Lot (0.1%)<br>• Gulliver's Travels (0.1%)<br>• The Picture of Dorian Gray (0.1%)<br>• Sense and Sensibility (0.1%)<br>• Jane Eyre (0.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row3" class="row_heading level0 row3" >author</th>
#       <td id="T_8a855_row3_col0" class="data row3 col0" >10897</td>
#       <td id="T_8a855_row3_col1" class="data row3 col1" >6491</td>
#       <td id="T_8a855_row3_col2" class="data row3 col2" >0.954100</td>
#       <td id="T_8a855_row3_col3" class="data row3 col3" >• Stephen King (40)<br>• P.G. Wodehouse (40)<br>• Rumiko Takahashi (38)<br>• Orson Scott Card (35)<br>• Agatha Christie (33)<br>• Piers Anthony (30)<br>• Mercedes Lackey (29)<br>• Sandra Brown (29)<br>• Dick Francis (28)<br>• Margaret Weis/Tracy Hickman (23)</td>
#       <td id="T_8a855_row3_col4" class="data row3 col4" >• Stephen King (0.4%)<br>• P.G. Wodehouse (0.4%)<br>• Rumiko Takahashi (0.3%)<br>• Orson Scott Card (0.3%)<br>• Agatha Christie (0.3%)<br>• Piers Anthony (0.3%)<br>• Mercedes Lackey (0.3%)<br>• Sandra Brown (0.3%)<br>• Dick Francis (0.3%)<br>• Margaret Weis/Tracy Hickman (0.2%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row4" class="row_heading level0 row4" >producer_company</th>
#       <td id="T_8a855_row4_col0" class="data row4 col0" >10897</td>
#       <td id="T_8a855_row4_col1" class="data row4 col1" >2221</td>
#       <td id="T_8a855_row4_col2" class="data row4 col2" >0.844500</td>
#       <td id="T_8a855_row4_col3" class="data row4 col3" >• Vintage (318)<br>• Penguin Books (261)<br>• Penguin Classics (184)<br>• Mariner Books (148)<br>• Ballantine Books (143)<br>• HarperCollins (112)<br>• Harper Perennial (112)<br>• Pocket Books (111)<br>• Bantam (110)<br>• VIZ Media LLC (88)</td>
#       <td id="T_8a855_row4_col4" class="data row4 col4" >• Vintage (2.9%)<br>• Penguin Books (2.4%)<br>• Penguin Classics (1.7%)<br>• Mariner Books (1.4%)<br>• Ballantine Books (1.3%)<br>• HarperCollins (1.0%)<br>• Harper Perennial (1.0%)<br>• Pocket Books (1.0%)<br>• Bantam (1.0%)<br>• VIZ Media LLC (0.8%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row5" class="row_heading level0 row5" >genres</th>
#       <td id="T_8a855_row5_col0" class="data row5 col0" >10897</td>
#       <td id="T_8a855_row5_col1" class="data row5 col1" >852</td>
#       <td id="T_8a855_row5_col2" class="data row5 col2" >0.745200</td>
#       <td id="T_8a855_row5_col3" class="data row5 col3" >• Fiction (6801)<br>• Classics (3305)<br>• Nonfiction (3070)<br>• Literature (2829)<br>• Fantasy (2526)<br>• Novels (2509)<br>• Historical,Historical Fiction (1771)<br>• Audiobook (1613)<br>• History (1581)<br>• Mystery (1566)</td>
#       <td id="T_8a855_row5_col4" class="data row5 col4" >• Fiction (62.4%)<br>• Classics (30.3%)<br>• Nonfiction (28.2%)<br>• Literature (26.0%)<br>• Fantasy (23.2%)<br>• Novels (23.0%)<br>• Historical,Historical Fiction (16.3%)<br>• Audiobook (14.8%)<br>• History (14.5%)<br>• Mystery (14.4%)</td>
#     </tr>
#     <tr>
#       <th id="T_8a855_level0_row6" class="row_heading level0 row6" >original_language</th>
#       <td id="T_8a855_row6_col0" class="data row6 col0" >10897</td>
#       <td id="T_8a855_row6_col1" class="data row6 col1" >25</td>
#       <td id="T_8a855_row6_col2" class="data row6 col2" >0.238000</td>
#       <td id="T_8a855_row6_col3" class="dat

# %%
graf.grafico_top_categorias(df_books, 'genres', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_books, 'author', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_books, 'producer_company', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_books, 'original_language', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_books, 'popularity_tier', resumo_cols_categoricas, tamanho_figura=(10, 6), width=0.3)

# %% [markdown]
# ### Colunas de Tempo

# %%
relatorio_cols_date = mt.datetime_summary(df_books)

display(
    tb.estilizar_tabela(
        relatorio_cols_date,
        caption="Relatorio colunas date"
    )
)
# Out:
# <style type="text/css">
# #T_122c3 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_122c3 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_122c3 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_122c3 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_122c3 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 333px;
# }
# #T_122c3 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 333px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_122c3_row0_col0, #T_122c3_row0_col1, #T_122c3_row0_col2, #T_122c3_row0_col3, #T_122c3_row0_col4, #T_122c3_row0_col5 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_122c3">
#   <caption>Relatorio colunas date</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_122c3_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_122c3_level0_col1" class="col_heading level0 col1" >max</th>
#       <th id="T_122c3_level0_col2" class="col_heading level0 col2" >range_years</th>
#       <th id="T_122c3_level0_col3" class="col_heading level0 col3" >unique_dates</th>
#       <th id="T_122c3_level0_col4" class="col_heading level0 col4" >most_frequent_year</th>
#       <th id="T_122c3_level0_col5" class="col_heading level0 col5" >most_frequent_month</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_122c3_level0_row0" class="row_heading level0 row0" >release_date</th>
#       <td id="T_122c3_row0_col0" class="data row0 col0" >1900-01-01</td>
#       <td id="T_122c3_row0_col1" class="data row0 col1" >2020-03-31</td>
#       <td id="T_122c3_row0_col2" class="data row0 col2" >120</td>
#       <td id="T_122c3_row0_col3" class="data row0 col3" >3618</td>
#       <td id="T_122c3_row0_col4" class="data row0 col4" >2006</td>
#       <td id="T_122c3_row0_col5" class="data row0 col5" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_top_tempo(df_books, coluna='release_date', extracao='month')

# %% [markdown]
# # Conclusões da Análise Univariada
#
# ## 1. Variáveis Numéricas
#
# * **`ratings_count` e `text_reviews_count` (Engajamento):** Assimetria extrema (Cauda Longa). A maioria dos livros tem poucos votos (mediana de 784), enquanto uma minoria de best-sellers concentra milhões de avaliações. Escala logarítmica indispensável para visualização.
# * **`num_pages` (Tamanho):** Concentração no padrão de **300 a 338 páginas**. Presença de volumes extremos (até 6.576 páginas) gerando 5.08% de outliers (possíveis boxes/coleções).
# * **`average_rating` (Notas):** Distribuição Normal perfeitamente equilibrada, concentrada entre **3.5 e 4.2** (média 3.94). O público leitor é generoso; notas menores que 2.0 ou perfeitas (5.0) são raras.
#
# ## 2. Variáveis Categorizadas
#
# * **`language_code` (Idioma):** Baixíssima entropia (0.23). Domínio absoluto do inglês (> 94.9%). O português representa apenas 0.1%. Será útil para segmentar o Dashboard por mercado.
# * **`genres` (Gêneros):** Alta entropia (0.74). Mercado bem distribuído. *Fiction* (62.5%) e *Classics* (30.3%) lideram, mas Fantasia, Mistério e Ficção Histórica têm fatias relevantes.
# * **`title` e `Author`:** Alta fragmentação (entropia > 0.95). Stephen King e P.G. Wodehouse lideram com apenas 0.4% do catálogo cada.
#
# ## 3. Variáveis Temporais
# * **Volume por Mês:** O **mês 9 (Setembro)** é o líder em registros, mas o catálogo é homogêneo ao longo do ano (diferença de apenas **~500 livros** entre o maior e o menor mês).
# * **Pico Histórico:** O ano com maior volume de publicações foi **2006**.
# * **Granularidade:** O acervo é altamente pulverizado, contendo **3.632 datas únicas**.
# * **Filtro Inicial (1900):** O limite inferior começa em **1900**. Como o dataset trata de registros comerciais (`isbn`), datas pós-1900 incluem **republicações e novas edições** de livros e clássicos muito mais antigos.
#
# ## 4. Qualidade dos Dados (Auditoria)
#
# * **`isbn`:** Preservado como identificador padrão para futuros cruzamentos externos.
# * **Duplicados:** A coluna `title` possui reedições e formatos diferentes (Paperback/Hardcover) do mesmo livro, gerando repetições legítimas de clássicos.
