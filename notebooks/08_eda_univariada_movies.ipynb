# %% [markdown]
# #  Análise Exploratória de Dados - Análise Univariada: The Movies Dataset

# %%
# Configuração do Jupyter (Autoreload)
# %load_ext autoreload
# %autoreload 2

# Configuração de Caminho (Path Setup)
import sys
import os

# Adiciona a pasta raiz do projeto (..) ao sistema para liberar os imports locais
sys.path.append(os.path.abspath(os.path.join('..')))

# Importação de Bibliotecas e Módulos
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Módulos customizados da pasta src/
import src.io.data_loader as dl
import src.utils.data_quality as dq
import src.utils.metrics as mt
import src.view.plots as graf
import src.view.tables as tb
import src.utils.reshaping as rsh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---
#
# ## Carregando Dados

# %%
caminho = '../data/interim/movies/movies_enriched.parquet'
df_movies = dl.load_data(file_path=caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (41091, 22)

# %% [markdown]
# ---
#
# ## Colunas do DataFrame

# %%
df_colunas = pd.DataFrame({
    "coluna": df_movies.columns,
    "dtype_pandas": df_movies.dtypes.values,
    "tipo_real": [
        df_movies[col].map(type)[0].__name__
        if not df_movies[col].dropna().empty else None
        for col in df_movies.columns
    ]
})

display(tb.estilizar_tabela(
    df=df_colunas,
    caption="Colunas do dataframe"
))
# Out:
# <style type="text/css">
# #T_1ce8a th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_1ce8a td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_1ce8a caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_1ce8a table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_1ce8a th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_1ce8a td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_1ce8a_row0_col0, #T_1ce8a_row0_col1, #T_1ce8a_row0_col2, #T_1ce8a_row1_col0, #T_1ce8a_row1_col1, #T_1ce8a_row1_col2, #T_1ce8a_row2_col0, #T_1ce8a_row2_col1, #T_1ce8a_row2_col2, #T_1ce8a_row3_col0, #T_1ce8a_row3_col1, #T_1ce8a_row3_col2, #T_1ce8a_row4_col0, #T_1ce8a_row4_col1, #T_1ce8a_row4_col2, #T_1ce8a_row5_col0, #T_1ce8a_row5_col1, #T_1ce8a_row5_col2, #T_1ce8a_row6_col0, #T_1ce8a_row6_col1, #T_1ce8a_row6_col2, #T_1ce8a_row7_col0, #T_1ce8a_row7_col1, #T_1ce8a_row7_col2, #T_1ce8a_row8_col0, #T_1ce8a_row8_col1, #T_1ce8a_row8_col2, #T_1ce8a_row9_col0, #T_1ce8a_row9_col1, #T_1ce8a_row9_col2, #T_1ce8a_row10_col0, #T_1ce8a_row10_col1, #T_1ce8a_row10_col2, #T_1ce8a_row11_col0, #T_1ce8a_row11_col1, #T_1ce8a_row11_col2, #T_1ce8a_row12_col0, #T_1ce8a_row12_col1, #T_1ce8a_row12_col2, #T_1ce8a_row13_col0, #T_1ce8a_row13_col1, #T_1ce8a_row13_col2, #T_1ce8a_row14_col0, #T_1ce8a_row14_col1, #T_1ce8a_row14_col2, #T_1ce8a_row15_col0, #T_1ce8a_row15_col1, #T_1ce8a_row15_col2, #T_1ce8a_row16_col0, #T_1ce8a_row16_col1, #T_1ce8a_row16_col2, #T_1ce8a_row17_col0, #T_1ce8a_row17_col1, #T_1ce8a_row17_col2, #T_1ce8a_row18_col0, #T_1ce8a_row18_col1, #T_1ce8a_row18_col2, #T_1ce8a_row19_col0, #T_1ce8a_row19_col1, #T_1ce8a_row19_col2, #T_1ce8a_row20_col0, #T_1ce8a_row20_col1, #T_1ce8a_row20_col2, #T_1ce8a_row21_col0, #T_1ce8a_row21_col1, #T_1ce8a_row21_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_1ce8a">
#   <caption>Colunas do dataframe</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ce8a_level0_col0" class="col_heading level0 col0" >coluna</th>
#       <th id="T_1ce8a_level0_col1" class="col_heading level0 col1" >dtype_pandas</th>
#       <th id="T_1ce8a_level0_col2" class="col_heading level0 col2" >tipo_real</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ce8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ce8a_row0_col0" class="data row0 col0" >belongs_to_collection</td>
#       <td id="T_1ce8a_row0_col1" class="data row0 col1" >object</td>
#       <td id="T_1ce8a_row0_col2" class="data row0 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1ce8a_row1_col0" class="data row1 col0" >budget</td>
#       <td id="T_1ce8a_row1_col1" class="data row1 col1" >float64</td>
#       <td id="T_1ce8a_row1_col2" class="data row1 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1ce8a_row2_col0" class="data row2 col0" >genres</td>
#       <td id="T_1ce8a_row2_col1" class="data row2 col1" >object</td>
#       <td id="T_1ce8a_row2_col2" class="data row2 col2" >ndarray</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1ce8a_row3_col0" class="data row3 col0" >id</td>
#       <td id="T_1ce8a_row3_col1" class="data row3 col1" >int64</td>
#       <td id="T_1ce8a_row3_col2" class="data row3 col2" >int</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1ce8a_row4_col0" class="data row4 col0" >original_language</td>
#       <td id="T_1ce8a_row4_col1" class="data row4 col1" >object</td>
#       <td id="T_1ce8a_row4_col2" class="data row4 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1ce8a_row5_col0" class="data row5 col0" >original_title</td>
#       <td id="T_1ce8a_row5_col1" class="data row5 col1" >object</td>
#       <td id="T_1ce8a_row5_col2" class="data row5 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1ce8a_row6_col0" class="data row6 col0" >popularity</td>
#       <td id="T_1ce8a_row6_col1" class="data row6 col1" >float64</td>
#       <td id="T_1ce8a_row6_col2" class="data row6 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1ce8a_row7_col0" class="data row7 col0" >producer_company</td>
#       <td id="T_1ce8a_row7_col1" class="data row7 col1" >object</td>
#       <td id="T_1ce8a_row7_col2" class="data row7 col2" >ndarray</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1ce8a_row8_col0" class="data row8 col0" >production_countries</td>
#       <td id="T_1ce8a_row8_col1" class="data row8 col1" >object</td>
#       <td id="T_1ce8a_row8_col2" class="data row8 col2" >ndarray</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1ce8a_row9_col0" class="data row9 col0" >release_date</td>
#       <td id="T_1ce8a_row9_col1" class="data row9 col1" >datetime64[ns]</td>
#       <td id="T_1ce8a_row9_col2" class="data row9 col2" >Timestamp</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1ce8a_row10_col0" class="data row10 col0" >revenue</td>
#       <td id="T_1ce8a_row10_col1" class="data row10 col1" >float64</td>
#       <td id="T_1ce8a_row10_col2" class="data row10 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1ce8a_row11_col0" class="data row11 col0" >runtime</td>
#       <td id="T_1ce8a_row11_col1" class="data row11 col1" >float64</td>
#       <td id="T_1ce8a_row11_col2" class="data row11 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1ce8a_row12_col0" class="data row12 col0" >spoken_languages</td>
#       <td id="T_1ce8a_row12_col1" class="data row12 col1" >object</td>
#       <td id="T_1ce8a_row12_col2" class="data row12 col2" >ndarray</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1ce8a_row13_col0" class="data row13 col0" >title</td>
#       <td id="T_1ce8a_row13_col1" class="data row13 col1" >object</td>
#       <td id="T_1ce8a_row13_col2" class="data row13 col2" >str</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1ce8a_row14_col0" class="data row14 col0" >average_rating</td>
#       <td id="T_1ce8a_row14_col1" class="data row14 col1" >float64</td>
#       <td id="T_1ce8a_row14_col2" class="data row14 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1ce8a_row15_col0" class="data row15 col0" >total_votes</td>
#       <td id="T_1ce8a_row15_col1" class="data row15 col1" >float64</td>
#       <td id="T_1ce8a_row15_col2" class="data row15 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1ce8a_row16_col0" class="data row16 col0" >global_score</td>
#       <td id="T_1ce8a_row16_col1" class="data row16 col1" >float64</td>
#       <td id="T_1ce8a_row16_col2" class="data row16 col2" >float</td>
#     </tr>
#     <tr>
#       <th id="T_1ce8a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1ce8a_row17_col0" class="data row17 col0" >release_year</td>
#       <td id="T_1ce8a_row17_col1" class="data row17 col1" >int32</

# %% [markdown]
# ### Colunas Numéricas

# %%
# Análisado Colunas Numéricas Individualmente
resumo_cols_numericas = mt.numeric_summary(df_movies)
display(
    tb.estilizar_tabela(
        resumo_cols_numericas,
        caption="Relatorio colunas numéricas"
    ).format("{:,.2f}")
)
# Out:
# <style type="text/css">
# #T_2ff25 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_2ff25 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_2ff25 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_2ff25 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_2ff25 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_2ff25 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_2ff25_row0_col0, #T_2ff25_row0_col1, #T_2ff25_row0_col2, #T_2ff25_row0_col3, #T_2ff25_row0_col4, #T_2ff25_row0_col5, #T_2ff25_row0_col6, #T_2ff25_row0_col7, #T_2ff25_row0_col8, #T_2ff25_row0_col9, #T_2ff25_row1_col0, #T_2ff25_row1_col1, #T_2ff25_row1_col2, #T_2ff25_row1_col3, #T_2ff25_row1_col4, #T_2ff25_row1_col5, #T_2ff25_row1_col6, #T_2ff25_row1_col7, #T_2ff25_row1_col8, #T_2ff25_row1_col9, #T_2ff25_row2_col0, #T_2ff25_row2_col1, #T_2ff25_row2_col2, #T_2ff25_row2_col3, #T_2ff25_row2_col4, #T_2ff25_row2_col5, #T_2ff25_row2_col6, #T_2ff25_row2_col7, #T_2ff25_row2_col8, #T_2ff25_row2_col9, #T_2ff25_row3_col0, #T_2ff25_row3_col1, #T_2ff25_row3_col2, #T_2ff25_row3_col3, #T_2ff25_row3_col4, #T_2ff25_row3_col5, #T_2ff25_row3_col6, #T_2ff25_row3_col7, #T_2ff25_row3_col8, #T_2ff25_row3_col9, #T_2ff25_row4_col0, #T_2ff25_row4_col1, #T_2ff25_row4_col2, #T_2ff25_row4_col3, #T_2ff25_row4_col4, #T_2ff25_row4_col5, #T_2ff25_row4_col6, #T_2ff25_row4_col7, #T_2ff25_row4_col8, #T_2ff25_row4_col9, #T_2ff25_row5_col0, #T_2ff25_row5_col1, #T_2ff25_row5_col2, #T_2ff25_row5_col3, #T_2ff25_row5_col4, #T_2ff25_row5_col5, #T_2ff25_row5_col6, #T_2ff25_row5_col7, #T_2ff25_row5_col8, #T_2ff25_row5_col9, #T_2ff25_row6_col0, #T_2ff25_row6_col1, #T_2ff25_row6_col2, #T_2ff25_row6_col3, #T_2ff25_row6_col4, #T_2ff25_row6_col5, #T_2ff25_row6_col6, #T_2ff25_row6_col7, #T_2ff25_row6_col8, #T_2ff25_row6_col9, #T_2ff25_row7_col0, #T_2ff25_row7_col1, #T_2ff25_row7_col2, #T_2ff25_row7_col3, #T_2ff25_row7_col4, #T_2ff25_row7_col5, #T_2ff25_row7_col6, #T_2ff25_row7_col7, #T_2ff25_row7_col8, #T_2ff25_row7_col9, #T_2ff25_row8_col0, #T_2ff25_row8_col1, #T_2ff25_row8_col2, #T_2ff25_row8_col3, #T_2ff25_row8_col4, #T_2ff25_row8_col5, #T_2ff25_row8_col6, #T_2ff25_row8_col7, #T_2ff25_row8_col8, #T_2ff25_row8_col9, #T_2ff25_row9_col0, #T_2ff25_row9_col1, #T_2ff25_row9_col2, #T_2ff25_row9_col3, #T_2ff25_row9_col4, #T_2ff25_row9_col5, #T_2ff25_row9_col6, #T_2ff25_row9_col7, #T_2ff25_row9_col8, #T_2ff25_row9_col9, #T_2ff25_row10_col0, #T_2ff25_row10_col1, #T_2ff25_row10_col2, #T_2ff25_row10_col3, #T_2ff25_row10_col4, #T_2ff25_row10_col5, #T_2ff25_row10_col6, #T_2ff25_row10_col7, #T_2ff25_row10_col8, #T_2ff25_row10_col9, #T_2ff25_row11_col0, #T_2ff25_row11_col1, #T_2ff25_row11_col2, #T_2ff25_row11_col3, #T_2ff25_row11_col4, #T_2ff25_row11_col5, #T_2ff25_row11_col6, #T_2ff25_row11_col7, #T_2ff25_row11_col8, #T_2ff25_row11_col9 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_2ff25">
#   <caption>Relatorio colunas numéricas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ff25_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_2ff25_level0_col1" class="col_heading level0 col1" >median</th>
#       <th id="T_2ff25_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_2ff25_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_2ff25_level0_col4" class="col_heading level0 col4" >max</th>
#       <th id="T_2ff25_level0_col5" class="col_heading level0 col5" >iqr</th>
#       <th id="T_2ff25_level0_col6" class="col_heading level0 col6" >skew</th>
#       <th id="T_2ff25_level0_col7" class="col_heading level0 col7" >kurtosis</th>
#       <th id="T_2ff25_level0_col8" class="col_heading level0 col8" >outlier_count</th>
#       <th id="T_2ff25_level0_col9" class="col_heading level0 col9" >outlier_%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ff25_level0_row0" class="row_heading level0 row0" >revenue</th>
#       <td id="T_2ff25_row0_col0" class="data row0 col0" >69,309,229.77</td>
#       <td id="T_2ff25_row0_col1" class="data row0 col1" >17,062,499.00</td>
#       <td id="T_2ff25_row0_col2" class="data row0 col2" >146,886,994.59</td>
#       <td id="T_2ff25_row0_col3" class="data row0 col3" >1.00</td>
#       <td id="T_2ff25_row0_col4" class="data row0 col4" >2,787,965,087.00</td>
#       <td id="T_2ff25_row0_col5" class="data row0 col5" >65,635,038.00</td>
#       <td id="T_2ff25_row0_col6" class="data row0 col6" >5.13</td>
#       <td id="T_2ff25_row0_col7" class="data row0 col7" >42.70</td>
#       <td id="T_2ff25_row0_col8" class="data row0 col8" >831.00</td>
#       <td id="T_2ff25_row0_col9" class="data row0 col9" >11.31</td>
#     </tr>
#     <tr>
#       <th id="T_2ff25_level0_row1" class="row_heading level0 row1" >budget</th>
#       <td id="T_2ff25_row1_col0" class="data row1 col0" >21,956,783.82</td>
#       <td id="T_2ff25_row1_col1" class="data row1 col1" >8,820,000.00</td>
#       <td id="T_2ff25_row1_col2" class="data row1 col2" >34,512,754.61</td>
#       <td id="T_2ff25_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_2ff25_row1_col4" class="data row1 col4" >380,000,000.00</td>
#       <td id="T_2ff25_row1_col5" class="data row1 col5" >23,697,387.00</td>
#       <td id="T_2ff25_row1_col6" class="data row1 col6" >3.10</td>
#       <td id="T_2ff25_row1_col7" class="data row1 col7" >12.57</td>
#       <td id="T_2ff25_row1_col8" class="data row1 col8" >812.00</td>
#       <td id="T_2ff25_row1_col9" class="data row1 col9" >9.30</td>
#     </tr>
#     <tr>
#       <th id="T_2ff25_level0_row2" class="row_heading level0 row2" >id</th>
#       <td id="T_2ff25_row2_col0" class="data row2 col0" >99,432.89</td>
#       <td id="T_2ff25_row2_col1" class="data row2 col1" >52,907.00</td>
#       <td id="T_2ff25_row2_col2" class="data row2 col2" >108,089.16</td>
#       <td id="T_2ff25_row2_col3" class="data row2 col3" >2.00</td>
#       <td id="T_2ff25_row2_col4" class="data row2 col4" >468,707.00</td>
#       <td id="T_2ff25_row2_col5" class="data row2 col5" >108,569.00</td>
#       <td id="T_2ff25_row2_col6" class="data row2 col6" >1.45</td>
#       <td id="T_2ff25_row2_col7" class="data row2 col7" >1.07</td>
#       <td id="T_2ff25_row2_col8" class="data row2 col8" >3,736.00</td>
#       <td id="T_2ff25_row2_col9" class="data row2 col9" >9.09</td>
#     </tr>
#     <tr>
#       <th id="T_2ff25_level0_row3" class="row_heading level0 row3" >release_year</th>
#       <td id="T_2ff25_row3_col0" class="data row3 col0" >1,991.97</td>
#       <td id="T_2ff25_row3_col1" class="data row3 col1" >2,001.00</td>
#       <td id="T_2ff25_row3_col2" class="data row3 col2" >23.99</td>
#       <td id="T_2ff25_row3_col3" class="data row3 col3" >1,874.00</td>
#       <td id="T_2ff25_row3_col4" class="data row3 col4" >2,018.00</td>
#       <td id="T_2ff25_row3_col5" class="data row3 col5" >31.00</td>
#       <td id="T_2ff25_row3_col6" class="data row3 col6" >-1.23</td>
#       <td id="T_2ff25_row3_col7" class="data row3 col7" >0.88</td>
#       <td id="T_2ff25_row3_col8" class="data row3 col8" >977.00</td>
#       <td id="T_2ff25_row3_col9" class="data row3 col9" >2.38</td>
#     </tr>
#     <tr>
#       <th id="T_2ff25_level0_row4" class="row_heading level0 row4" >decade</th>
#       <td id="T_2ff25_row4_col0" class="data row4 col0" >1,987.52</td>

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_movies, 
    coluna='global_score', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='nota_100'
)

# %%
graf.grafico_distribuicao_numerica(
    df_movies, 
    coluna='revenue', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='moeda'
)

# %%
graf.grafico_distribuicao_numerica(
    df_movies, 
    coluna='budget', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='moeda'
)

# %%
graf.grafico_distribuicao_numerica(
    df_movies, 
    coluna='total_votes', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='contagem'
)

# %%
graf.grafico_distribuicao_numerica(
    df_movies, 
    coluna='average_rating', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='nota_10'
)

# %%
graf.grafico_distribuicao_numerica(
    df_movies, 
    coluna='popularity', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True,
    tipo_dado='popularidade'
)

# %% [markdown]
# #### Colunas Numéricas Relacionadas ao Tempo

# %%
graf.grafico_distribuicao_numerica(
    df_plot=df_movies, 
    coluna='votes_per_year', 
    relatorio_df=resumo_cols_numericas, 
    usar_log=True, 
    tipo_dado='contagem'
)

# %%
graf.grafico_top_tempo(df_movies, coluna='release_year')

# %%
graf.grafico_top_tempo(df_movies, coluna='decade')

# %%
graf.grafico_top_tempo(df_movies, coluna='age_years')

# %% [markdown]
# ### Colunas Catategóricas

# %%
# Análisado Colunas Categóricas Individualmente
resumo_cols_categoricas = mt.categorical_summary(df_movies)
display(
    tb.estilizar_relatorio_categorias(
        resumo_cols_categoricas,
        caption="Relatorio colunas categoricas"
    )
)
# Out:
# <style type="text/css">
# #T_22832 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_22832 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_22832 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_22832 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_22832 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 400px;
# }
# #T_22832 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 400px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_22832_row0_col0, #T_22832_row0_col1, #T_22832_row0_col2, #T_22832_row1_col0, #T_22832_row1_col1, #T_22832_row1_col2, #T_22832_row2_col0, #T_22832_row2_col1, #T_22832_row2_col2, #T_22832_row3_col0, #T_22832_row3_col1, #T_22832_row3_col2, #T_22832_row4_col0, #T_22832_row4_col1, #T_22832_row4_col2, #T_22832_row5_col0, #T_22832_row5_col1, #T_22832_row5_col2, #T_22832_row6_col0, #T_22832_row6_col1, #T_22832_row6_col2, #T_22832_row7_col0, #T_22832_row7_col1, #T_22832_row7_col2, #T_22832_row8_col0, #T_22832_row8_col1, #T_22832_row8_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# #T_22832_row0_col3, #T_22832_row0_col4, #T_22832_row1_col3, #T_22832_row1_col4, #T_22832_row2_col3, #T_22832_row2_col4, #T_22832_row3_col3, #T_22832_row3_col4, #T_22832_row4_col3, #T_22832_row4_col4, #T_22832_row5_col3, #T_22832_row5_col4, #T_22832_row6_col3, #T_22832_row6_col4, #T_22832_row7_col3, #T_22832_row7_col4, #T_22832_row8_col3, #T_22832_row8_col4 {
#   white-space: pre-wrap;
#   text-align: left;
#   text-align: left;
# }
# </style>
# <table id="T_22832">
#   <caption>Relatorio colunas categoricas</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22832_level0_col0" class="col_heading level0 col0" >total_valid_rows</th>
#       <th id="T_22832_level0_col1" class="col_heading level0 col1" >unique_categories</th>
#       <th id="T_22832_level0_col2" class="col_heading level0 col2" >entropy_norm</th>
#       <th id="T_22832_level0_col3" class="col_heading level0 col3" >top_values_count</th>
#       <th id="T_22832_level0_col4" class="col_heading level0 col4" >top_values_pct_%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22832_level0_row0" class="row_heading level0 row0" >original_title</th>
#       <td id="T_22832_row0_col0" class="data row0 col0" >41091</td>
#       <td id="T_22832_row0_col1" class="data row0 col1" >39206</td>
#       <td id="T_22832_row0_col2" class="data row0 col2" >0.997900</td>
#       <td id="T_22832_row0_col3" class="data row0 col3" >• Alice in Wonderland (8)<br>• Hamlet (7)<br>• Les Misérables (7)<br>• The Three Musketeers (7)<br>• Cinderella (7)<br>• A Christmas Carol (7)<br>• Macbeth (7)<br>• Wuthering Heights (6)<br>• Heidi (6)<br>• King Lear (6)</td>
#       <td id="T_22832_row0_col4" class="data row0 col4" >• Alice in Wonderland (0.0%)<br>• Hamlet (0.0%)<br>• Les Misérables (0.0%)<br>• The Three Musketeers (0.0%)<br>• Cinderella (0.0%)<br>• A Christmas Carol (0.0%)<br>• Macbeth (0.0%)<br>• Wuthering Heights (0.0%)<br>• Heidi (0.0%)<br>• King Lear (0.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row1" class="row_heading level0 row1" >title</th>
#       <td id="T_22832_row1_col0" class="data row1 col0" >41091</td>
#       <td id="T_22832_row1_col1" class="data row1 col1" >38233</td>
#       <td id="T_22832_row1_col2" class="data row1 col2" >0.996600</td>
#       <td id="T_22832_row1_col3" class="data row1 col3" >• Cinderella (11)<br>• Alice in Wonderland (9)<br>• Hamlet (8)<br>• Les Misérables (7)<br>• Beauty and the Beast (7)<br>• The Three Musketeers (7)<br>• Treasure Island (7)<br>• A Christmas Carol (7)<br>• Blackout (7)<br>• The Hunters (6)</td>
#       <td id="T_22832_row1_col4" class="data row1 col4" >• Cinderella (0.0%)<br>• Alice in Wonderland (0.0%)<br>• Hamlet (0.0%)<br>• Les Misérables (0.0%)<br>• Beauty and the Beast (0.0%)<br>• The Three Musketeers (0.0%)<br>• Treasure Island (0.0%)<br>• A Christmas Carol (0.0%)<br>• Blackout (0.0%)<br>• The Hunters (0.0%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row2" class="row_heading level0 row2" >popularity_tier</th>
#       <td id="T_22832_row2_col0" class="data row2 col0" >41091</td>
#       <td id="T_22832_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_22832_row2_col2" class="data row2 col2" >0.990700</td>
#       <td id="T_22832_row2_col3" class="data row2 col3" >• Mainstream Hit (12233)<br>• Nicho (11545)<br>• Hidden Gem / Cult (8951)<br>• Mass Appeal (8362)</td>
#       <td id="T_22832_row2_col4" class="data row2 col4" >• Mainstream Hit (29.8%)<br>• Nicho (28.1%)<br>• Hidden Gem / Cult (21.8%)<br>• Mass Appeal (20.3%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row3" class="row_heading level0 row3" >genres</th>
#       <td id="T_22832_row3_col0" class="data row3 col0" >41091</td>
#       <td id="T_22832_row3_col1" class="data row3 col1" >21</td>
#       <td id="T_22832_row3_col2" class="data row3 col2" >0.871500</td>
#       <td id="T_22832_row3_col3" class="data row3 col3" >• Drama (19020)<br>• Comedy (12165)<br>• Thriller (7324)<br>• Romance (6367)<br>• Action (6302)<br>• Horror (4526)<br>• Crime (4086)<br>• Adventure (3337)<br>• Documentary (3326)<br>• Science Fiction (2931)</td>
#       <td id="T_22832_row3_col4" class="data row3 col4" >• Drama (46.3%)<br>• Comedy (29.6%)<br>• Thriller (17.8%)<br>• Romance (15.5%)<br>• Action (15.3%)<br>• Horror (11.0%)<br>• Crime (9.9%)<br>• Adventure (8.1%)<br>• Documentary (8.1%)<br>• Science Fiction (7.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row4" class="row_heading level0 row4" >producer_company</th>
#       <td id="T_22832_row4_col0" class="data row4 col0" >41091</td>
#       <td id="T_22832_row4_col1" class="data row4 col1" >22648</td>
#       <td id="T_22832_row4_col2" class="data row4 col2" >0.810000</td>
#       <td id="T_22832_row4_col3" class="data row4 col3" >• Companhia Não Identificada (9318)<br>• Warner Bros. (1183)<br>• Metro-Goldwyn-Mayer (MGM) (993)<br>• Paramount Pictures (972)<br>• Universal Pictures (818)<br>• Twentieth Century Fox Film Corporation (812)<br>• Canal+ (433)<br>• Columbia Pictures Corporation (427)<br>• Columbia Pictures (420)<br>• New Line Cinema (277)</td>
#       <td id="T_22832_row4_col4" class="data row4 col4" >• Companhia Não Identificada (22.7%)<br>• Warner Bros. (2.9%)<br>• Metro-Goldwyn-Mayer (MGM) (2.4%)<br>• Paramount Pictures (2.4%)<br>• Universal Pictures (2.0%)<br>• Twentieth Century Fox Film Corporation (2.0%)<br>• Canal+ (1.1%)<br>• Columbia Pictures Corporation (1.0%)<br>• Columbia Pictures (1.0%)<br>• New Line Cinema (0.7%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row5" class="row_heading level0 row5" >production_countries</th>
#       <td id="T_22832_row5_col0" class="data row5 col0" >41091</td>
#       <td id="T_22832_row5_col1" class="data row5 col1" >159</td>
#       <td id="T_22832_row5_col2" class="data row5 col2" >0.517800</td>
#       <td id="T_22832_row5_col3" class="data row5 col3" >• United States of America (20064)<br>• País Não Identificado (4511)<br>• United Kingdom (3949)<br>• France (3736)<br>• Germany (2096)<br>• Italy (1848)<br>• Canada (1663)<br>• Japan (1560)<br>• Russia (859)<br>• Spain (853)</td>
#       <td id="T_22832_row5_col4" class="data row5 col4" >• United States of America (48.8%)<br>• País Não Identificado (11.0%)<br>• United Kingdom (9.6%)<br>• France (9.1%)<br>• Germany (5.1%)<br>• Italy (4.5%)<br>• Canada (4.0%)<br>• Japan (3.8%)<br>• Russia (2.1%)<br>• Spain (2.1%)</td>
#     </tr>
#     <tr>
#       <th id="T_22832_level0_row6" class="row_heading level0 row6" >spoken_languages<

# %%
graf.grafico_top_categorias(df_movies, 'genres', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_movies, 'production_countries', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_movies, 'spoken_languages', resumo_cols_categoricas)
# Out:
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 26222 (\N{CJK UNIFIED IDEOGRAPH-666E}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Matplotlib currently does not support Devanagari natively.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\src\view\plots\univariados.py:218: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26412 (\N{CJK UNIFIED IDEOGRAPH-672C}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 35486 (\N{CJK UNIFIED IDEOGRAPH-8A9E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 26222 (\N{CJK UNIFIED IDEOGRAPH-666E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 36890 (\N{CJK UNIFIED IDEOGRAPH-901A}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 35805 (\N{CJK UNIFIED IDEOGRAPH-8BDD}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2367 (\N{DEVANAGARI VOWEL SIGN I}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Portfolio\entertainment_industry_performance_analysis\venv\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
graf.grafico_top_categorias(df_movies, 'original_language', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_movies, 'belongs_to_collection', resumo_cols_categoricas)

# %%
graf.grafico_top_categorias(df_movies, 'popularity_tier', resumo_cols_categoricas, tamanho_figura=(10, 6), width=0.3)

# %% [markdown]
# ### Colunas de Tempo

# %%
relatorio_cols_date = mt.datetime_summary(df_movies)

display(
    tb.estilizar_tabela(
        relatorio_cols_date,
        caption="Relatorio colunas date"
    )
)
# Out:
# <style type="text/css">
# #T_b4014 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_b4014 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_b4014 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_b4014 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_b4014 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 333px;
# }
# #T_b4014 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 333px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_b4014_row0_col0, #T_b4014_row0_col1, #T_b4014_row0_col2, #T_b4014_row0_col3, #T_b4014_row0_col4, #T_b4014_row0_col5 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_b4014">
#   <caption>Relatorio colunas date</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4014_level0_col0" class="col_heading level0 col0" >min</th>
#       <th id="T_b4014_level0_col1" class="col_heading level0 col1" >max</th>
#       <th id="T_b4014_level0_col2" class="col_heading level0 col2" >range_years</th>
#       <th id="T_b4014_level0_col3" class="col_heading level0 col3" >unique_dates</th>
#       <th id="T_b4014_level0_col4" class="col_heading level0 col4" >most_frequent_year</th>
#       <th id="T_b4014_level0_col5" class="col_heading level0 col5" >most_frequent_month</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4014_level0_row0" class="row_heading level0 row0" >release_date</th>
#       <td id="T_b4014_row0_col0" class="data row0 col0" >1874-12-09</td>
#       <td id="T_b4014_row0_col1" class="data row0 col1" >2018-04-04</td>
#       <td id="T_b4014_row0_col2" class="data row0 col2" >143</td>
#       <td id="T_b4014_row0_col3" class="data row0 col3" >16394</td>
#       <td id="T_b4014_row0_col4" class="data row0 col4" >2014</td>
#       <td id="T_b4014_row0_col5" class="data row0 col5" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_top_tempo(df_movies, coluna='release_date', extracao='month')

# %% [markdown]
# ## Conclusões da Análise Univariada
#
# ### 1. Diagnóstico Estatístico (Métricas Numéricas)
# * **Finanças e Engajamento (`revenue`, `budget`, `vote_count`):** Distribuição de **cauda longa** com assimetria extrema. O mercado é polarizado: a esmagadora maioria dos filmes tem baixo orçamento, pouca bilheteria e poucas avaliações, enquanto uma elite de blockbusters concentra o dinheiro e a atenção do público.
#
# * **Avaliações (`vote_average`):** Segue uma **Distribuição Normal** perfeita, concentrada entre **6.0 e 7.5**. Notas extremas (0 ou 10) são raridades; a maior parte do catálogo habita a zona do entretenimento aceitável.
#
# ### 2. Padrões Categoriais
# * **Concentração Geográfica e Linguística:** Baixa entropia, evidenciando a dominância absoluta de Hollywood (EUA) e do idioma inglês.
#
# * **Diversidade de Gêneros:** Alta entropia. *Drama* e *Comédia* lideram em volume, mas o ecossistema de gêneros é bem distribuído.
#
# * **Franquias:** Obras isoladas são a regra; coleções são exceções estruturais.
#
# ### 3. Comportamento Temporal
# * **Evolução:** Abrange **143 anos** de cinema (1874 a 2018) com altíssima granularidade (**16.394 datas únicas**), tendo seu **pico histórico em 2014**.
#
# * **Sazonalidade:** O **mês 1 (Janeiro)** lidera os registros, o que indica uma provável padronização de cadastro para filmes antigos, além de festivais e relançamentos.
#
# ### 4. Auditoria de Data Quality
# * **Sujeira nos Dados:** Identificação de orçamentos e faturamentos irreais (ex: \$10), caracterizados como erros de preenchimento do TMDB e não como produções independentes legítimas.
#
# * **Mitigação:** Aplicação de um filtro temporário (`>= 5_000`) para proteger os gráficos atuais, com substituição definitiva desses valores truncados por `NaN` na etapa de *Data Cleaning*.
#
#   * Defesa Metodológica: O Limite de $5.000 (Filtro de Ruído)
#
#      1. **O Limite Físico do "Micro-Budget":** Historicamente, o custo mínimo absoluto para viabilizar e distribuir comercialmente um longa-metragem gravita pouco acima dos $5.000 (como provam os clássicos *Following* com $6.000 e *Primer* com $7.000). Cortar abaixo de 5k garante que essas obras-primas de alta eficiência permaneçam no estudo.
#
#      2. **Padrão de Inserção Falsa (Placeholders):** O TMDB é uma base alimentada por utilizadores. Quando a informação financeira é desconhecida, o erro humano tende a preencher o vazio com escalas logarítmicas preguiçosas ($1, $10, $100, $1.000). O piso de 5.000 dólares atua como um escudo, barrando quase a totalidade desse "ruído branco" sem prejudicar os dados legítimos.
