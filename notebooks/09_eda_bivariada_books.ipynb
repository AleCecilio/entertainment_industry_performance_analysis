# %% [markdown]
# #  Análise Exploratória de Dados - Análise Bivariada: Goodreads Dataset

# %%
# Configuração do Jupyter (Autoreload)
# %load_ext autoreload
# %autoreload 2

# Configuração de Caminho (Path Setup)
import sys
import os

# Adiciona a pasta raiz do projeto (..) ao sistema para liberar os imports locais
sys.path.append(os.path.abspath(os.path.join('..')))


# Importação de Bibliotecas e Módulos
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Nossos módulos customizados da pasta src/
import src.io.data_loader as dl
import src.utils.metrics as mt
import src.view.plots as graf
import src.view.tables as tb

# %% [markdown]
# ---
#
# ## Carregando Dados

# %%
caminho = '../data/interim/books/goodreads_books_enriched.parquet'
df_books = dl.load_data(file_path=caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (10897, 18)

# %% [markdown]
# ---
# ## Numérica VS Numérica

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_books.select_dtypes(include='number')
        .corr(method='pearson')['total_votes']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_books.select_dtypes(include='number')
        .corr(method='spearman')['total_votes']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_49e09 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_49e09 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_49e09 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_49e09 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_49e09 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_49e09 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_49e09_row0_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_49e09_row1_col0 {
#   background-color: #003e32;
#   color: #f1f1f1;
# }
# #T_49e09_row2_col0 {
#   background-color: #01584f;
#   color: #f1f1f1;
# }
# #T_49e09_row3_col0, #T_49e09_row4_col0, #T_49e09_row5_col0, #T_49e09_row6_col0 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_49e09_row7_col0 {
#   background-color: #edf3f2;
#   color: #000000;
# }
# #T_49e09_row8_col0 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_49e09_row9_col0 {
#   background-color: #f5f0e2;
#   color: #000000;
# }
# </style>
# <table id="T_49e09">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49e09_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49e09_level0_row0" class="row_heading level0 row0" >total_votes</th>
#       <td id="T_49e09_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row1" class="row_heading level0 row1" >votes_per_year</th>
#       <td id="T_49e09_row1_col0" class="data row1 col0" >0.990686</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row2" class="row_heading level0 row2" >text_reviews_count</th>
#       <td id="T_49e09_row2_col0" class="data row2 col0" >0.865908</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row3" class="row_heading level0 row3" >release_year</th>
#       <td id="T_49e09_row3_col0" class="data row3 col0" >0.044841</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row4" class="row_heading level0 row4" >decade</th>
#       <td id="T_49e09_row4_col0" class="data row4 col0" >0.042990</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row5" class="row_heading level0 row5" >global_score</th>
#       <td id="T_49e09_row5_col0" class="data row5 col0" >0.041521</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row6" class="row_heading level0 row6" >average_rating</th>
#       <td id="T_49e09_row6_col0" class="data row6 col0" >0.041521</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row7" class="row_heading level0 row7" >num_pages</th>
#       <td id="T_49e09_row7_col0" class="data row7 col0" >0.032434</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row8" class="row_heading level0 row8" >age_years</th>
#       <td id="T_49e09_row8_col0" class="data row8 col0" >-0.044841</td>
#     </tr>
#     <tr>
#       <th id="T_49e09_level0_row9" class="row_heading level0 row9" >book_id</th>
#       <td id="T_49e09_row9_col0" class="data row9 col0" >-0.077257</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7df7c th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_7df7c td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_7df7c caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_7df7c table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_7df7c th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_7df7c td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_7df7c_row0_col0, #T_7df7c_row1_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_7df7c_row2_col0 {
#   background-color: #004439;
#   color: #f1f1f1;
# }
# #T_7df7c_row3_col0 {
#   background-color: #ceece8;
#   color: #000000;
# }
# #T_7df7c_row4_col0 {
#   background-color: #dbefec;
#   color: #000000;
# }
# #T_7df7c_row5_col0 {
#   background-color: #def0ed;
#   color: #000000;
# }
# #T_7df7c_row6_col0, #T_7df7c_row7_col0 {
#   background-color: #e2f0ee;
#   color: #000000;
# }
# #T_7df7c_row8_col0 {
#   background-color: #f5efdc;
#   color: #000000;
# }
# #T_7df7c_row9_col0 {
#   background-color: #f6eed9;
#   color: #000000;
# }
# </style>
# <table id="T_7df7c">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7df7c_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7df7c_level0_row0" class="row_heading level0 row0" >total_votes</th>
#       <td id="T_7df7c_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row1" class="row_heading level0 row1" >votes_per_year</th>
#       <td id="T_7df7c_row1_col0" class="data row1 col0" >0.995311</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row2" class="row_heading level0 row2" >text_reviews_count</th>
#       <td id="T_7df7c_row2_col0" class="data row2 col0" >0.957020</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row3" class="row_heading level0 row3" >num_pages</th>
#       <td id="T_7df7c_row3_col0" class="data row3 col0" >0.165469</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row4" class="row_heading level0 row4" >release_year</th>
#       <td id="T_7df7c_row4_col0" class="data row4 col0" >0.114581</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row5" class="row_heading level0 row5" >decade</th>
#       <td id="T_7df7c_row5_col0" class="data row5 col0" >0.100460</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row6" class="row_heading level0 row6" >global_score</th>
#       <td id="T_7df7c_row6_col0" class="data row6 col0" >0.082008</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row7" class="row_heading level0 row7" >average_rating</th>
#       <td id="T_7df7c_row7_col0" class="data row7 col0" >0.082008</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row8" class="row_heading level0 row8" >book_id</th>
#       <td id="T_7df7c_row8_col0" class="data row8 col0" >-0.098546</td>
#     </tr>
#     <tr>
#       <th id="T_7df7c_level0_row9" class="row_heading level0 row9" >age_years</th>
#       <td id="T_7df7c_row9_col0" class="data row9 col0" >-0.114581</td>
#     </tr>
#   </tbody>
# </table>

# %%
colunas_numericas = df_books.select_dtypes(include='number').columns


graf.grafico_corr_scatter(
    df_plot=df_books,
    coluna_x=colunas_numericas.drop(['total_votes', 'book_id']),
    coluna_y='total_votes',
    titulo='Painel de Variáveis e sua correlação com o Número de Votos',
    quant_grafs=len(colunas_numericas.drop(['total_votes', 'book_id']))
)

# %%
display(tb.estilizar_matriz_correlacao(
    df_corr=df_books
        .select_dtypes(include='number')
        .corr(method='pearson')['average_rating']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Pearson)'
))

display(tb.estilizar_matriz_correlacao(
    df_corr=df_books
        .select_dtypes(include='number')
        .corr(method='spearman')['average_rating']
        .sort_values(ascending=False)
        .to_frame(name='Correlação'),
        caption='Mapa de Relacionamento (Correlação Spearman)'
))
# Out:
# <style type="text/css">
# #T_d3523 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_d3523 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_d3523 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_d3523 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_d3523 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_d3523 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_d3523_row0_col0, #T_d3523_row1_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_d3523_row2_col0 {
#   background-color: #ccebe7;
#   color: #000000;
# }
# #T_d3523_row3_col0, #T_d3523_row4_col0 {
#   background-color: #ebf3f2;
#   color: #000000;
# }
# #T_d3523_row5_col0, #T_d3523_row6_col0 {
#   background-color: #edf3f2;
#   color: #000000;
# }
# #T_d3523_row7_col0, #T_d3523_row8_col0 {
#   background-color: #f5f3ec;
#   color: #000000;
# }
# #T_d3523_row9_col0 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# </style>
# <table id="T_d3523">
#   <caption>Mapa de Relacionamento (Correlação Pearson)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d3523_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d3523_level0_row0" class="row_heading level0 row0" >global_score</th>
#       <td id="T_d3523_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row1" class="row_heading level0 row1" >average_rating</th>
#       <td id="T_d3523_row1_col0" class="data row1 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row2" class="row_heading level0 row2" >num_pages</th>
#       <td id="T_d3523_row2_col0" class="data row2 col0" >0.173256</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row3" class="row_heading level0 row3" >age_years</th>
#       <td id="T_d3523_row3_col0" class="data row3 col0" >0.044348</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row4" class="row_heading level0 row4" >total_votes</th>
#       <td id="T_d3523_row4_col0" class="data row4 col0" >0.041521</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row5" class="row_heading level0 row5" >votes_per_year</th>
#       <td id="T_d3523_row5_col0" class="data row5 col0" >0.038763</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row6" class="row_heading level0 row6" >text_reviews_count</th>
#       <td id="T_d3523_row6_col0" class="data row6 col0" >0.034234</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row7" class="row_heading level0 row7" >decade</th>
#       <td id="T_d3523_row7_col0" class="data row7 col0" >-0.033165</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row8" class="row_heading level0 row8" >book_id</th>
#       <td id="T_d3523_row8_col0" class="data row8 col0" >-0.038005</td>
#     </tr>
#     <tr>
#       <th id="T_d3523_level0_row9" class="row_heading level0 row9" >release_year</th>
#       <td id="T_d3523_row9_col0" class="data row9 col0" >-0.044348</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6bade th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_6bade td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_6bade caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_6bade table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_6bade th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_6bade td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_6bade_row0_col0, #T_6bade_row1_col0 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_6bade_row2_col0 {
#   background-color: #dbefec;
#   color: #000000;
# }
# #T_6bade_row3_col0 {
#   background-color: #e2f0ee;
#   color: #000000;
# }
# #T_6bade_row4_col0 {
#   background-color: #e4f1ef;
#   color: #000000;
# }
# #T_6bade_row5_col0 {
#   background-color: #e9f2f1;
#   color: #000000;
# }
# #T_6bade_row6_col0 {
#   background-color: #eff3f3;
#   color: #000000;
# }
# #T_6bade_row7_col0 {
#   background-color: #f5f3ec;
#   color: #000000;
# }
# #T_6bade_row8_col0 {
#   background-color: #f5f2ea;
#   color: #000000;
# }
# #T_6bade_row9_col0 {
#   background-color: #f5f2e8;
#   color: #000000;
# }
# </style>
# <table id="T_6bade">
#   <caption>Mapa de Relacionamento (Correlação Spearman)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bade_level0_col0" class="col_heading level0 col0" >Correlação</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bade_level0_row0" class="row_heading level0 row0" >average_rating</th>
#       <td id="T_6bade_row0_col0" class="data row0 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row1" class="row_heading level0 row1" >global_score</th>
#       <td id="T_6bade_row1_col0" class="data row1 col0" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row2" class="row_heading level0 row2" >num_pages</th>
#       <td id="T_6bade_row2_col0" class="data row2 col0" >0.113564</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row3" class="row_heading level0 row3" >total_votes</th>
#       <td id="T_6bade_row3_col0" class="data row3 col0" >0.082008</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row4" class="row_heading level0 row4" >votes_per_year</th>
#       <td id="T_6bade_row4_col0" class="data row4 col0" >0.074899</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row5" class="row_heading level0 row5" >age_years</th>
#       <td id="T_6bade_row5_col0" class="data row5 col0" >0.053759</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row6" class="row_heading level0 row6" >text_reviews_count</th>
#       <td id="T_6bade_row6_col0" class="data row6 col0" >0.026812</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row7" class="row_heading level0 row7" >book_id</th>
#       <td id="T_6bade_row7_col0" class="data row7 col0" >-0.036000</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row8" class="row_heading level0 row8" >decade</th>
#       <td id="T_6bade_row8_col0" class="data row8 col0" >-0.040450</td>
#     </tr>
#     <tr>
#       <th id="T_6bade_level0_row9" class="row_heading level0 row9" >release_year</th>
#       <td id="T_6bade_row9_col0" class="data row9 col0" >-0.053759</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_corr_scatter(
    df_plot=df_books,
    coluna_x=colunas_numericas.drop(['average_rating', 'book_id']),
    coluna_y='average_rating',
    titulo='Painel de Variáveis e sua correlação com o Número de Votos',
    quant_grafs=len(colunas_numericas.drop(['average_rating', 'book_id']))
)

# %%
# Verificando a distribuição dos livros com pouquíssimos votos

display(tb.estilizar_tabela(
    df=df_books[df_books['total_votes'] <= 10]['total_votes']
        .value_counts()
        .sort_index()
        .to_frame(name='Contagem'),
    caption="Quantidade de livros por número de votos (de 0 a 10):"
))

# Verificando especificamente quem tem apenas 1 voto
apenas_um = (df_books['total_votes'] == 1).sum()
print(f"\nLivros que possuem exatamente 1 voto: {apenas_um}")
# Out:
# <style type="text/css">
# #T_bef57 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_bef57 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_bef57 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_bef57 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_bef57 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_bef57 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_bef57_row0_col0, #T_bef57_row1_col0, #T_bef57_row2_col0, #T_bef57_row3_col0, #T_bef57_row4_col0, #T_bef57_row5_col0, #T_bef57_row6_col0, #T_bef57_row7_col0, #T_bef57_row8_col0, #T_bef57_row9_col0 {
#   white-space: pre-wrap;
#   text-align: left;
#   background-color: #457B9D;
#   color: white;
# }
# </style>
# <table id="T_bef57">
#   <caption>Quantidade de livros por número de votos (de 0 a 10):</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bef57_level0_col0" class="col_heading level0 col0" >Contagem</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >total_votes</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bef57_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bef57_row0_col0" class="data row0 col0" >62</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bef57_row1_col0" class="data row1 col0" >63</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bef57_row2_col0" class="data row2 col0" >70</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bef57_row3_col0" class="data row3 col0" >62</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bef57_row4_col0" class="data row4 col0" >51</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_bef57_row5_col0" class="data row5 col0" >52</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_bef57_row6_col0" class="data row6 col0" >52</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_bef57_row7_col0" class="data row7 col0" >53</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_bef57_row8_col0" class="data row8 col0" >55</td>
#     </tr>
#     <tr>
#       <th id="T_bef57_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_bef57_row9_col0" class="data row9 col0" >53</td>
#     </tr>
#   </tbody>
# </table>
# Livros que possuem exatamente 1 voto: 62

# %%
print(f"Total de livros com pouquíssimos votos: {
    df_books[df_books['total_votes'] <= 10]['total_votes']
        .values
        .sum()
}")
# Out:
# Total de livros com pouquíssimos votos: 3026

# %%
media = df_books[df_books['total_votes'] <= 10]['average_rating'].mean()

print(f"Média das notas dos livros com pouquíssimos votos (<= 10): {media:.2f}")
# Out:
# Média das notas dos livros com pouquíssimos votos (<= 10): 3.89

# %%
media = df_books[df_books['total_votes'] == 1]['average_rating'].mean()

print(f"Média das notas dos livros com apenas 1 voto: {media:.2f}")
# Out:
# Média das notas dos livros com apenas 1 voto: 3.77

# %% [markdown]
# ---
# ## Categorica VS Categorica

# %% [markdown]
# ### Carregando DataFrame Explodido

# %%
caminho = '../data/processed/books/goodreads_books_exploded.parquet'
df_exploded = dl.load_data(file_path=caminho, tipo_arquivo='parquet')
# Out:
# Dados Parquet carregados! Formato: (94023, 18)

# %% [markdown]
# ### `genres` vs `origina_language`

# %%
# Criar a Tabela de Contingência 

top_genres = df_exploded['genres'].value_counts().head(20).index
top_languages = df_exploded['original_language'].value_counts().head(20).index

contingencia_genres_language = pd.crosstab(
    df_exploded['original_language'], 
    df_exploded['genres']
)

display(tb.estilizar_tabela(
    df=contingencia_genres_language.loc[
        top_languages,
        top_genres
    ],
    caption='Tabela de Contingência (Valores Absolutos): original_language vs genres'
))
# Out:
# <style type="text/css">
# #T_ecad4 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_ecad4 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_ecad4 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_ecad4 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_ecad4 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_ecad4 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_ecad4_row0_col0, #T_ecad4_row0_col1, #T_ecad4_row0_col2, #T_ecad4_row0_col3, #T_ecad4_row0_col4, #T_ecad4_row0_col5, #T_ecad4_row0_col6, #T_ecad4_row0_col7, #T_ecad4_row0_col8, #T_ecad4_row0_col9, #T_ecad4_row0_col10, #T_ecad4_row0_col11, #T_ecad4_row0_col12, #T_ecad4_row0_col13, #T_ecad4_row0_col14, #T_ecad4_row0_col15, #T_ecad4_row0_col16, #T_ecad4_row0_col17, #T_ecad4_row0_col18, #T_ecad4_row0_col19, #T_ecad4_row1_col0, #T_ecad4_row1_col1, #T_ecad4_row1_col2, #T_ecad4_row1_col3, #T_ecad4_row1_col4, #T_ecad4_row1_col5, #T_ecad4_row1_col6, #T_ecad4_row1_col7, #T_ecad4_row1_col8, #T_ecad4_row1_col9, #T_ecad4_row1_col10, #T_ecad4_row1_col11, #T_ecad4_row1_col12, #T_ecad4_row1_col13, #T_ecad4_row1_col14, #T_ecad4_row1_col15, #T_ecad4_row1_col16, #T_ecad4_row1_col17, #T_ecad4_row1_col18, #T_ecad4_row1_col19, #T_ecad4_row2_col0, #T_ecad4_row2_col1, #T_ecad4_row2_col2, #T_ecad4_row2_col3, #T_ecad4_row2_col4, #T_ecad4_row2_col5, #T_ecad4_row2_col6, #T_ecad4_row2_col7, #T_ecad4_row2_col8, #T_ecad4_row2_col9, #T_ecad4_row2_col10, #T_ecad4_row2_col11, #T_ecad4_row2_col12, #T_ecad4_row2_col13, #T_ecad4_row2_col14, #T_ecad4_row2_col15, #T_ecad4_row2_col16, #T_ecad4_row2_col17, #T_ecad4_row2_col18, #T_ecad4_row2_col19, #T_ecad4_row3_col0, #T_ecad4_row3_col1, #T_ecad4_row3_col2, #T_ecad4_row3_col3, #T_ecad4_row3_col4, #T_ecad4_row3_col5, #T_ecad4_row3_col6, #T_ecad4_row3_col7, #T_ecad4_row3_col8, #T_ecad4_row3_col9, #T_ecad4_row3_col10, #T_ecad4_row3_col11, #T_ecad4_row3_col12, #T_ecad4_row3_col13, #T_ecad4_row3_col14, #T_ecad4_row3_col15, #T_ecad4_row3_col16, #T_ecad4_row3_col17, #T_ecad4_row3_col18, #T_ecad4_row3_col19, #T_ecad4_row4_col0, #T_ecad4_row4_col1, #T_ecad4_row4_col2, #T_ecad4_row4_col3, #T_ecad4_row4_col4, #T_ecad4_row4_col5, #T_ecad4_row4_col6, #T_ecad4_row4_col7, #T_ecad4_row4_col8, #T_ecad4_row4_col9, #T_ecad4_row4_col10, #T_ecad4_row4_col11, #T_ecad4_row4_col12, #T_ecad4_row4_col13, #T_ecad4_row4_col14, #T_ecad4_row4_col15, #T_ecad4_row4_col16, #T_ecad4_row4_col17, #T_ecad4_row4_col18, #T_ecad4_row4_col19, #T_ecad4_row5_col0, #T_ecad4_row5_col1, #T_ecad4_row5_col2, #T_ecad4_row5_col3, #T_ecad4_row5_col4, #T_ecad4_row5_col5, #T_ecad4_row5_col6, #T_ecad4_row5_col7, #T_ecad4_row5_col8, #T_ecad4_row5_col9, #T_ecad4_row5_col10, #T_ecad4_row5_col11, #T_ecad4_row5_col12, #T_ecad4_row5_col13, #T_ecad4_row5_col14, #T_ecad4_row5_col15, #T_ecad4_row5_col16, #T_ecad4_row5_col17, #T_ecad4_row5_col18, #T_ecad4_row5_col19, #T_ecad4_row6_col0, #T_ecad4_row6_col1, #T_ecad4_row6_col2, #T_ecad4_row6_col3, #T_ecad4_row6_col4, #T_ecad4_row6_col5, #T_ecad4_row6_col6, #T_ecad4_row6_col7, #T_ecad4_row6_col8, #T_ecad4_row6_col9, #T_ecad4_row6_col10, #T_ecad4_row6_col11, #T_ecad4_row6_col12, #T_ecad4_row6_col13, #T_ecad4_row6_col14, #T_ecad4_row6_col15, #T_ecad4_row6_col16, #T_ecad4_row6_col17, #T_ecad4_row6_col18, #T_ecad4_row6_col19, #T_ecad4_row7_col0, #T_ecad4_row7_col1, #T_ecad4_row7_col2, #T_ecad4_row7_col3, #T_ecad4_row7_col4, #T_ecad4_row7_col5, #T_ecad4_row7_col6, #T_ecad4_row7_col7, #T_ecad4_row7_col8, #T_ecad4_row7_col9, #T_ecad4_row7_col10, #T_ecad4_row7_col11, #T_ecad4_row7_col12, #T_ecad4_row7_col13, #T_ecad4_row7_col14, #T_ecad4_row7_col15, #T_ecad4_row7_col16, #T_ecad4_row7_col17, #T_ecad4_row7_col18, #T_ecad4_row7_col19, #T_ecad4_row8_col0, #T_ecad4_row8_col1, #T_ecad4_row8_col2, #T_ecad4_row8_col3, #T_ecad4_row8_col4, #T_ecad4_row8_col5, #T_ecad4_row8_col6, #T_ecad4_row8_col7, #T_ecad4_row8_col8, #T_ecad4_row8_col9, #T_ecad4_row8_col10, #T_ecad4_row8_col11, #T_ecad4_row8_col12, #T_ecad4_row8_col13, #T_ecad4_row8_col14, #T_ecad4_row8_col15, #T_ecad4_row8_col16, #T_ecad4_row8_col17, #T_ecad4_row8_col18, #T_ecad4_row8_col19, #T_ecad4_row9_col0, #T_ecad4_row9_col1, #T_ecad4_row9_col2, #T_ecad4_row9_col3, #T_ecad4_row9_col4, #T_ecad4_row9_col5, #T_ecad4_row9_col6, #T_ecad4_row9_col7, #T_ecad4_row9_col8, #T_ecad4_row9_col9, #T_ecad4_row9_col10, #T_ecad4_row9_col11, #T_ecad4_row9_col12, #T_ecad4_row9_col13, #T_ecad4_row9_col14, #T_ec ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_genres_language = mt.testar_dependencia_categorica(
    contingencia_genres_language
)

display(tb.estilizar_tabela(
    df=resultado_genres_language,
    caption='Relatório: language_code vs genres'
))
# Out:
# <style type="text/css">
# #T_77b4f th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_77b4f td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_77b4f caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_77b4f table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_77b4f th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_77b4f td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_77b4f_row0_col0, #T_77b4f_row0_col1, #T_77b4f_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_77b4f">
#   <caption>Relatório: language_code vs genres</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_77b4f_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_77b4f_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_77b4f_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_77b4f_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_77b4f_row0_col0" class="data row0 col0" >49404.154639</td>
#       <td id="T_77b4f_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_77b4f_row0_col2" class="data row0 col2" >20424</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_genres_language,
    chi2=resultado_genres_language['Qui-Quadrado'].iloc[0],
    p_valor=resultado_genres_language['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ### `genres` vs `producer_company`

# %%
# Criar a Tabela de Contingência 

top_genres = df_exploded['genres'].value_counts().head(20).index
top_publishers = df_exploded['producer_company'].value_counts().head(20).index

contingencia_genres_publisher = pd.crosstab(
    df_exploded['producer_company'], 
    df_exploded['genres']
)

display(tb.estilizar_tabela(
    df=contingencia_genres_publisher.loc[
        top_publishers,
        top_genres
    ],
    caption='Tabela de Contingência (Valores Absolutos): producer_company vs genres'
))
# Out:
# <style type="text/css">
# #T_438fb th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_438fb td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_438fb caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_438fb table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_438fb th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_438fb td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_438fb_row0_col0, #T_438fb_row0_col1, #T_438fb_row0_col2, #T_438fb_row0_col3, #T_438fb_row0_col4, #T_438fb_row0_col5, #T_438fb_row0_col6, #T_438fb_row0_col7, #T_438fb_row0_col8, #T_438fb_row0_col9, #T_438fb_row0_col10, #T_438fb_row0_col11, #T_438fb_row0_col12, #T_438fb_row0_col13, #T_438fb_row0_col14, #T_438fb_row0_col15, #T_438fb_row0_col16, #T_438fb_row0_col17, #T_438fb_row0_col18, #T_438fb_row0_col19, #T_438fb_row1_col0, #T_438fb_row1_col1, #T_438fb_row1_col2, #T_438fb_row1_col3, #T_438fb_row1_col4, #T_438fb_row1_col5, #T_438fb_row1_col6, #T_438fb_row1_col7, #T_438fb_row1_col8, #T_438fb_row1_col9, #T_438fb_row1_col10, #T_438fb_row1_col11, #T_438fb_row1_col12, #T_438fb_row1_col13, #T_438fb_row1_col14, #T_438fb_row1_col15, #T_438fb_row1_col16, #T_438fb_row1_col17, #T_438fb_row1_col18, #T_438fb_row1_col19, #T_438fb_row2_col0, #T_438fb_row2_col1, #T_438fb_row2_col2, #T_438fb_row2_col3, #T_438fb_row2_col4, #T_438fb_row2_col5, #T_438fb_row2_col6, #T_438fb_row2_col7, #T_438fb_row2_col8, #T_438fb_row2_col9, #T_438fb_row2_col10, #T_438fb_row2_col11, #T_438fb_row2_col12, #T_438fb_row2_col13, #T_438fb_row2_col14, #T_438fb_row2_col15, #T_438fb_row2_col16, #T_438fb_row2_col17, #T_438fb_row2_col18, #T_438fb_row2_col19, #T_438fb_row3_col0, #T_438fb_row3_col1, #T_438fb_row3_col2, #T_438fb_row3_col3, #T_438fb_row3_col4, #T_438fb_row3_col5, #T_438fb_row3_col6, #T_438fb_row3_col7, #T_438fb_row3_col8, #T_438fb_row3_col9, #T_438fb_row3_col10, #T_438fb_row3_col11, #T_438fb_row3_col12, #T_438fb_row3_col13, #T_438fb_row3_col14, #T_438fb_row3_col15, #T_438fb_row3_col16, #T_438fb_row3_col17, #T_438fb_row3_col18, #T_438fb_row3_col19, #T_438fb_row4_col0, #T_438fb_row4_col1, #T_438fb_row4_col2, #T_438fb_row4_col3, #T_438fb_row4_col4, #T_438fb_row4_col5, #T_438fb_row4_col6, #T_438fb_row4_col7, #T_438fb_row4_col8, #T_438fb_row4_col9, #T_438fb_row4_col10, #T_438fb_row4_col11, #T_438fb_row4_col12, #T_438fb_row4_col13, #T_438fb_row4_col14, #T_438fb_row4_col15, #T_438fb_row4_col16, #T_438fb_row4_col17, #T_438fb_row4_col18, #T_438fb_row4_col19, #T_438fb_row5_col0, #T_438fb_row5_col1, #T_438fb_row5_col2, #T_438fb_row5_col3, #T_438fb_row5_col4, #T_438fb_row5_col5, #T_438fb_row5_col6, #T_438fb_row5_col7, #T_438fb_row5_col8, #T_438fb_row5_col9, #T_438fb_row5_col10, #T_438fb_row5_col11, #T_438fb_row5_col12, #T_438fb_row5_col13, #T_438fb_row5_col14, #T_438fb_row5_col15, #T_438fb_row5_col16, #T_438fb_row5_col17, #T_438fb_row5_col18, #T_438fb_row5_col19, #T_438fb_row6_col0, #T_438fb_row6_col1, #T_438fb_row6_col2, #T_438fb_row6_col3, #T_438fb_row6_col4, #T_438fb_row6_col5, #T_438fb_row6_col6, #T_438fb_row6_col7, #T_438fb_row6_col8, #T_438fb_row6_col9, #T_438fb_row6_col10, #T_438fb_row6_col11, #T_438fb_row6_col12, #T_438fb_row6_col13, #T_438fb_row6_col14, #T_438fb_row6_col15, #T_438fb_row6_col16, #T_438fb_row6_col17, #T_438fb_row6_col18, #T_438fb_row6_col19, #T_438fb_row7_col0, #T_438fb_row7_col1, #T_438fb_row7_col2, #T_438fb_row7_col3, #T_438fb_row7_col4, #T_438fb_row7_col5, #T_438fb_row7_col6, #T_438fb_row7_col7, #T_438fb_row7_col8, #T_438fb_row7_col9, #T_438fb_row7_col10, #T_438fb_row7_col11, #T_438fb_row7_col12, #T_438fb_row7_col13, #T_438fb_row7_col14, #T_438fb_row7_col15, #T_438fb_row7_col16, #T_438fb_row7_col17, #T_438fb_row7_col18, #T_438fb_row7_col19, #T_438fb_row8_col0, #T_438fb_row8_col1, #T_438fb_row8_col2, #T_438fb_row8_col3, #T_438fb_row8_col4, #T_438fb_row8_col5, #T_438fb_row8_col6, #T_438fb_row8_col7, #T_438fb_row8_col8, #T_438fb_row8_col9, #T_438fb_row8_col10, #T_438fb_row8_col11, #T_438fb_row8_col12, #T_438fb_row8_col13, #T_438fb_row8_col14, #T_438fb_row8_col15, #T_438fb_row8_col16, #T_438fb_row8_col17, #T_438fb_row8_col18, #T_438fb_row8_col19, #T_438fb_row9_col0, #T_438fb_row9_col1, #T_438fb_row9_col2, #T_438fb_row9_col3, #T_438fb_row9_col4, #T_438fb_row9_col5, #T_438fb_row9_col6, #T_438fb_row9_col7, #T_438fb_row9_col8, #T_438fb_row9_col9, #T_438fb_row9_col10, #T_438fb_row9_col11, #T_438fb_row9_col12, #T_438fb_row9_col13, #T_438fb_row9_col14, #T_43 ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_genres_publisher = mt.testar_dependencia_categorica(
    contingencia_genres_publisher
)

display(tb.estilizar_tabela(
    df=resultado_genres_publisher,
    caption='Relatório: publisher_code vs genres'
))
# Out:
# <style type="text/css">
# #T_bc160 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_bc160 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_bc160 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_bc160 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_bc160 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_bc160 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_bc160_row0_col0, #T_bc160_row0_col1, #T_bc160_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_bc160">
#   <caption>Relatório: publisher_code vs genres</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc160_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_bc160_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_bc160_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc160_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_bc160_row0_col0" class="data row0 col0" >3535008.573057</td>
#       <td id="T_bc160_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_bc160_row0_col2" class="data row0 col2" >1889220</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_genres_publisher,
    chi2=resultado_genres_publisher['Qui-Quadrado'].iloc[0],
    p_valor=resultado_genres_publisher['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ### `original_language` vs `producer_company`

# %%
# Criar a Tabela de Contingência 

top_languages = df_exploded['original_language'].value_counts().head(20).index
top_publishers = df_exploded['producer_company'].value_counts().head(20).index

contingencia_language_publisher = pd.crosstab(
    df_exploded['original_language'], 
    df_exploded['producer_company']
)

display(tb.estilizar_tabela(
    df=contingencia_language_publisher.loc[
        top_languages,
        top_publishers,
    ],
    caption='Tabela de Contingência (Valores Absolutos): producer_company vs original_language'
))
# Out:
# <style type="text/css">
# #T_e70b5 th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_e70b5 td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_e70b5 caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_e70b5 table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_e70b5 th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 300px;
# }
# #T_e70b5 td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 300px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_e70b5_row0_col0, #T_e70b5_row0_col1, #T_e70b5_row0_col2, #T_e70b5_row0_col3, #T_e70b5_row0_col4, #T_e70b5_row0_col5, #T_e70b5_row0_col6, #T_e70b5_row0_col7, #T_e70b5_row0_col8, #T_e70b5_row0_col9, #T_e70b5_row0_col10, #T_e70b5_row0_col11, #T_e70b5_row0_col12, #T_e70b5_row0_col13, #T_e70b5_row0_col14, #T_e70b5_row0_col15, #T_e70b5_row0_col16, #T_e70b5_row0_col17, #T_e70b5_row0_col18, #T_e70b5_row0_col19, #T_e70b5_row1_col0, #T_e70b5_row1_col1, #T_e70b5_row1_col2, #T_e70b5_row1_col3, #T_e70b5_row1_col4, #T_e70b5_row1_col5, #T_e70b5_row1_col6, #T_e70b5_row1_col7, #T_e70b5_row1_col8, #T_e70b5_row1_col9, #T_e70b5_row1_col10, #T_e70b5_row1_col11, #T_e70b5_row1_col12, #T_e70b5_row1_col13, #T_e70b5_row1_col14, #T_e70b5_row1_col15, #T_e70b5_row1_col16, #T_e70b5_row1_col17, #T_e70b5_row1_col18, #T_e70b5_row1_col19, #T_e70b5_row2_col0, #T_e70b5_row2_col1, #T_e70b5_row2_col2, #T_e70b5_row2_col3, #T_e70b5_row2_col4, #T_e70b5_row2_col5, #T_e70b5_row2_col6, #T_e70b5_row2_col7, #T_e70b5_row2_col8, #T_e70b5_row2_col9, #T_e70b5_row2_col10, #T_e70b5_row2_col11, #T_e70b5_row2_col12, #T_e70b5_row2_col13, #T_e70b5_row2_col14, #T_e70b5_row2_col15, #T_e70b5_row2_col16, #T_e70b5_row2_col17, #T_e70b5_row2_col18, #T_e70b5_row2_col19, #T_e70b5_row3_col0, #T_e70b5_row3_col1, #T_e70b5_row3_col2, #T_e70b5_row3_col3, #T_e70b5_row3_col4, #T_e70b5_row3_col5, #T_e70b5_row3_col6, #T_e70b5_row3_col7, #T_e70b5_row3_col8, #T_e70b5_row3_col9, #T_e70b5_row3_col10, #T_e70b5_row3_col11, #T_e70b5_row3_col12, #T_e70b5_row3_col13, #T_e70b5_row3_col14, #T_e70b5_row3_col15, #T_e70b5_row3_col16, #T_e70b5_row3_col17, #T_e70b5_row3_col18, #T_e70b5_row3_col19, #T_e70b5_row4_col0, #T_e70b5_row4_col1, #T_e70b5_row4_col2, #T_e70b5_row4_col3, #T_e70b5_row4_col4, #T_e70b5_row4_col5, #T_e70b5_row4_col6, #T_e70b5_row4_col7, #T_e70b5_row4_col8, #T_e70b5_row4_col9, #T_e70b5_row4_col10, #T_e70b5_row4_col11, #T_e70b5_row4_col12, #T_e70b5_row4_col13, #T_e70b5_row4_col14, #T_e70b5_row4_col15, #T_e70b5_row4_col16, #T_e70b5_row4_col17, #T_e70b5_row4_col18, #T_e70b5_row4_col19, #T_e70b5_row5_col0, #T_e70b5_row5_col1, #T_e70b5_row5_col2, #T_e70b5_row5_col3, #T_e70b5_row5_col4, #T_e70b5_row5_col5, #T_e70b5_row5_col6, #T_e70b5_row5_col7, #T_e70b5_row5_col8, #T_e70b5_row5_col9, #T_e70b5_row5_col10, #T_e70b5_row5_col11, #T_e70b5_row5_col12, #T_e70b5_row5_col13, #T_e70b5_row5_col14, #T_e70b5_row5_col15, #T_e70b5_row5_col16, #T_e70b5_row5_col17, #T_e70b5_row5_col18, #T_e70b5_row5_col19, #T_e70b5_row6_col0, #T_e70b5_row6_col1, #T_e70b5_row6_col2, #T_e70b5_row6_col3, #T_e70b5_row6_col4, #T_e70b5_row6_col5, #T_e70b5_row6_col6, #T_e70b5_row6_col7, #T_e70b5_row6_col8, #T_e70b5_row6_col9, #T_e70b5_row6_col10, #T_e70b5_row6_col11, #T_e70b5_row6_col12, #T_e70b5_row6_col13, #T_e70b5_row6_col14, #T_e70b5_row6_col15, #T_e70b5_row6_col16, #T_e70b5_row6_col17, #T_e70b5_row6_col18, #T_e70b5_row6_col19, #T_e70b5_row7_col0, #T_e70b5_row7_col1, #T_e70b5_row7_col2, #T_e70b5_row7_col3, #T_e70b5_row7_col4, #T_e70b5_row7_col5, #T_e70b5_row7_col6, #T_e70b5_row7_col7, #T_e70b5_row7_col8, #T_e70b5_row7_col9, #T_e70b5_row7_col10, #T_e70b5_row7_col11, #T_e70b5_row7_col12, #T_e70b5_row7_col13, #T_e70b5_row7_col14, #T_e70b5_row7_col15, #T_e70b5_row7_col16, #T_e70b5_row7_col17, #T_e70b5_row7_col18, #T_e70b5_row7_col19, #T_e70b5_row8_col0, #T_e70b5_row8_col1, #T_e70b5_row8_col2, #T_e70b5_row8_col3, #T_e70b5_row8_col4, #T_e70b5_row8_col5, #T_e70b5_row8_col6, #T_e70b5_row8_col7, #T_e70b5_row8_col8, #T_e70b5_row8_col9, #T_e70b5_row8_col10, #T_e70b5_row8_col11, #T_e70b5_row8_col12, #T_e70b5_row8_col13, #T_e70b5_row8_col14, #T_e70b5_row8_col15, #T_e70b5_row8_col16, #T_e70b5_row8_col17, #T_e70b5_row8_col18, #T_e70b5_row8_col19, #T_e70b5_row9_col0, #T_e70b5_row9_col1, #T_e70b5_row9_col2, #T_e70b5_row9_col3, #T_e70b5_row9_col4, #T_e70b5_row9_col5, #T_e70b5_row9_col6, #T_e70b5_row9_col7, #T_e70b5_row9_col8, #T_e70b5_row9_col9, #T_e70b5_row9_col10, #T_e70b5_row9_col11, #T_e70b5_row9_col12, #T_e70b5_row9_col13, #T_e70b5_row9_col14, #T_e7 ...

# %%
# Executando o Teste do Qui-Quadrado
resultado_language_publisher = mt.testar_dependencia_categorica(
    contingencia_language_publisher
)

display(tb.estilizar_tabela(
    df=resultado_language_publisher,
    caption='Relatório: publisher_code vs language_code'
))
# Out:
# <style type="text/css">
# #T_b72de th {
#   background-color: #2B2D42;
#   color: white;
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
# }
# #T_b72de td {
#   text-align: left;
#   padding: 8px 15px;
# }
# #T_b72de caption {
#   font-weight: bold;
#   font-size: 14px;
#   text-align: left;
#   padding-bottom: 8px;
# }
# #T_b72de table {
#   table-layout: auto;
#   width: 100%;
#   border-collapse: collapse;
#   margin: 10px 0;
# }
# #T_b72de th {
#   text-align: left;
#   font-weight: bold;
#   padding: 10px 15px;
#   min-width: 100px;
#   max-width: 600px;
# }
# #T_b72de td {
#   text-align: left;
#   padding: 8px 15px;
#   max-width: 600px;
#   white-space: nowrap;
#   text-overflow: ellipsis;
#   overflow: hidden;
# }
# #T_b72de_row0_col0, #T_b72de_row0_col1, #T_b72de_row0_col2 {
#   white-space: pre-wrap;
#   text-align: left;
# }
# </style>
# <table id="T_b72de">
#   <caption>Relatório: publisher_code vs language_code</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b72de_level0_col0" class="col_heading level0 col0" >Qui-Quadrado</th>
#       <th id="T_b72de_level0_col1" class="col_heading level0 col1" >p-valor</th>
#       <th id="T_b72de_level0_col2" class="col_heading level0 col2" >Graus de Liberdade</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Hipótese Nula ($H_0$)</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b72de_level0_row0" class="row_heading level0 row0" >REJEITADA</th>
#       <td id="T_b72de_row0_col0" class="data row0 col0" >1530418.642898</td>
#       <td id="T_b72de_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_b72de_row0_col2" class="data row0 col2" >53280</td>
#     </tr>
#   </tbody>
# </table>

# %%
graf.grafico_dependencia_categorica(
    tabela_absoluta=contingencia_language_publisher,
    chi2=resultado_language_publisher['Qui-Quadrado'].iloc[0],
    p_valor=resultado_language_publisher['p-valor'].iloc[0],
    top_n=20
)

# %% [markdown]
# ---
# ## Categorica VS Numérica

# %% [markdown]
# #### `genre` vs `global_score`

# %%
top_genres = df_exploded['genres'].value_counts().head(20).index

contingencia_genres_publisher = pd.crosstab(
    df_exploded['global_score'], 
    df_exploded['genres']
)

graf.grafico_cat_vs_num_boxplot(
    df_plot=df_exploded,              
    cat_col='genres',              
    num_col='global_score',      
    top_n_cats=10,                 
    tipo_dado='nota_100'            
)

# Para plotar o Violinplot
graf.grafico_cat_vs_num_violinplot(
    df_plot=df_exploded,              
    cat_col='genres',              
    num_col='global_score',      
    top_n_cats=10,                 
    tipo_dado='nota_100'            
)
